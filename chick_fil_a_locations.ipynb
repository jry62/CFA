# %%
import requests
response = requests.get("https://www.chick-fil-a.com/locations/browse/al")
print(response.text)
# Out:
# <!DOCTYPE html>
# <!--[if gt IE 9]><!-->
# <html lang="en">
# <!--<![endif]-->
# <head>
#
#
#
#
#
#
#
# <meta charset="utf-8">
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
# <meta name="keywords" content="">
# <meta name="description" content="Explore the different Chick-fil-A locations in AL for address, phone number, menu, and website information today.">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1.0, user-scalable=yes" />
# <meta name="server" content="I-064ADEB9A2331" />
# <meta name="serverzone" content="0.0" />
# <meta name="site" content="CFACOM" />
# <meta name='bsk' content='80dd234943647559a245be654346b81f'/>
# <meta name='bskv' content='2.1.2111-stageb'/>
# 	<link rel="canonical" href="https://www.chick-fil-a.com/locations/browse/al">
#
# <link rel="shortcut icon" href="/Assets/Theming/favicon.ico" type="image/x-icon">
#
# <title>AL Locations and Information | Chick-fil-A</title>
#
# 		<link href="https://d2wl1kt18tqdum.cloudfront.net/v2.1.2111-stageb/Assets/Theming/css/cfacom.css" rel="stylesheet" type="text/css" />
#
#
#
#
# 	<!-- Google Tag Manager -->
# 	<script>
# 		(function (w, d, s, l, i) {
# 			w[l] = w[l] || [];
# 			w[l].push({
# 				'gtm.start' :
# 					new Date().getTime(),
# 				event : 'gtm.js'
# 			});
# 			var f = d.getElementsByTagName(s)[0],
# 				j = d.createElement(s),
# 				dl = l != 'dataLayer' ? '&l=' + l : '';
# 			j.async = true;
# 			j.src =
# 				'//www.googletagmanager.com/gtm.js?id=' + i + dl;
# 			f.parentNode.insertBefore(j, f);
# 		})(window, document, 'script', 'dataLayer', 'GTM-NXDPGM');
# 	</script>
# 	<!-- End Google Tag Manager -->
#
#     <script>
#         function getExperienceType () {
#             var experienceType = "Desktop";
#
#             if (Number(document.documentElement.clientWidth) < 960) {
#                 experienceType = "Mobile";
#             } else if (window.matchMedia("(orientation: landscape)") && (Number(document.documentElement.clientHeight) < 960)) {
#                 experienceType = "Mobile";
#             }
#
#             return experienceType;
#         }
#
#         window.digitalData =
#         {
#             'page' : {
#                 'category' : {
#                     'pageType': 'Location Browse'
#                 },
#                 'pageInfo' : {
#                     'destinationURL' : 'http://www.chick-fil-a.com/locations/browse/al',
#                     'experienceType' : getExperienceType(),
#                     'pageName' : 'Locations List',
#                     'sysEnv' : 'Prod'
#                 }
#             },
#             'user' : {
#                 'profile' : {
#                     'profileInfo' : {
#                         'loginStatus' : 'not-logged-in',
#                         'profileID' : ''
#                     }
#                 }
#             }
#         };
#     </script>
#
#             <!-- Schema.org markup for Google+ -->
#             <meta itemprop="name" content="Location listings">
#             <meta itemprop="description" content="Browse">
#             <meta itemprop="image" content="http://www.chick-fil-a.com/-/media/images/cfacom/default-images/chick-fil-a-logo-vector.ashx">
#             <!-- Twitter Card data -->
#             <meta name="twitter:card" content="summary_large_image">
#             <meta name="twitter:site" content="@ChickfilA">
#             <meta name="twitter:title" content="Location listings">
#             <meta name="twitter:description" content="Browse">
#             <meta name="twitter:creator" content="@ChickfilA">
#             <meta name="twitter:image:src" content="http://www.chick-fil-a.com/-/media/images/cfacom/default-images/chick-fil-a-logo-vector.ashx">
#             <!-- Open Graph data -->
#             <meta property="og:title" content="Location listings"/>
#             <meta property="og:type" content="article"/>
#             <meta property="og:url" content="https://www.chick-fil-a.com/locations/browse/al"/>
#             <meta property="og:description" content="Browse"/>
#             <meta property="og:site_name" content="Chick-fil-A"/>
#             <meta property="article:tag" content=""/>
#             <meta property="og:image" content="http://www.chick-fil-a.com/-/media/images/cfacom/default-images/chick-fil-a-logo-vector.ashx"/>
#                 <meta property="og:image:width" content="693"/>
#                 <meta property="og:image:height" content="390"/>
#
#
#
#
#
# </head>
# <body>
#
#
#
# 	<!-- Google Tag Manager -->
# 	<noscript>
# 		<iframe src="//www.googletagmanager.com/ns.html?id=GTM-NXDPGM"
# 						height="0"
# 						width="0"
# 						style="display: none; visibility: hidden;"></iframe>
# 	</noscript>
# 	<!-- End Google Tag Manager -->
#
#
# 		<a class="visually-hidden skip-link" href="#top-hero">Skip to main content</a>
#
#
#
# 	<div class="location-listings">
#
#
#
#
#
#
# <div class="header-frame" data-sticky-position="true" data-sticky-priority="1">
#
# 	<header data-component="MainNav">
# 		<div class="nav-frame">
# 			<div class="header-components flex">
# 				<a href="/" class="icon-logo-desktop logo"><span>Chick-Fil-A</span></a>
#
#
#
# <div class="location-tools" data-component="locationTools" data-modal-id="pwo-modal" data-has-favorited-restaurants="false">
# 	<div class="current-location" data-populate="current-location-menu-id">
# 		<div class="icon-location-off"></div>
# 		<button data-element="findRestaurant" type="button">
# 			Find a restaurant
# 		</button>
# 	</div>
# </div>
#
#
# <a href="https://order.chick-fil-a.com/get-started" class="order-now" title="Order Now" >Order Now</a>
#
#
# <div class="nav-toggle" data-component="NavToggle">
# 	<a data-action="toggle nav" href="#" class="icon-nav-toggle-off">
# 		<span>Close Main Nav</span>
# 	</a>
# </div>
#
#
# 				<nav class="main-nav" role="navigation" aria-label="Main menu">
# 					<ul class="flex">
#
#
#
#
#
#
#
# 	<li id="navitem-menu"
# 			class="navitem-hoverable navitem-hoverable--menu">
#
# <a href="https://www.chick-fil-a.com/menu" aria-disabled="true" role="button" >			<span>Menu</span>
# 				<span class="icon-arrow-down" aria-expanded="false"></span>
# </a>
#
# 			<div class="subnav">
#
#
# 				<ul id="menusubcategoricalid"
# 						class="menusubcategories"
# 						aria-label="Menu subcategories'">
#
# 						<li>
#
# 									<a href="/menu#breakfast" title="Breakfast" >Breakfast</a>
#
# 						</li>
# 						<li>
#
# 									<a href="/menu#entrees" >Entr&#233;es</a>
#
# 						</li>
# 						<li>
#
# 									<a href="/menu#salads" >Salads</a>
#
# 						</li>
# 						<li>
#
# 									<a href="/menu#sides" >Sides</a>
#
# 						</li>
# 						<li>
#
# 									<a href="/menu#kidsmeals" >Kid&#39;s Meals</a>
#
# 						</li>
# 						<li>
#
# 									<a href="/menu#treats" >Treats</a>
#
# 						</li>
# 						<li>
#
# 									<a href="/menu#beverages" >Drinks</a>
#
# 						</li>
# 						<li>
#
# 									<a href="/menu#sauces" >Dipping Sauces and Dressings</a>
#
# 						</li>
# 						<li>
#
# 									<a href="/catering" >Catering</a>
#
# 						</li>
# 				</ul>
# 			</div>
# 	</li>
#                <li id="navitem-stories" class="navitem-hoverable navitem-hoverable--stories">
#                 <a href="https://www.chick-fil-a.com/stories" id="stories-id" class="">
#                     <span>Stories</span> <span class="icon-arrow-down" aria-expanded="false"></span>
#                 </a>
#                 <div class="subnav">
#                     <ul>
#                         <li class="mobile-only">
#                             <a href="https://www.chick-fil-a.com/stories">All Stories</a>
#                         </li>
#                             <li>
#                                 <a href="https://www.chick-fil-a.com/stories/food" id="food-id" class="food ">Food</a>
#                             </li>
#                             <li>
#                                 <a href="https://www.chick-fil-a.com/stories/lifestyle" id="lifestyle-id" class="lifestyle ">Lifestyle</a>
#                             </li>
#                             <li>
#                                 <a href="https://www.chick-fil-a.com/stories/inside-chick-fil-a" id="cfa-stories-id" class="cfa-stories ">Inside <span class="nowrap">Chick-fil-A</span></a>
#                             </li>
#                             <li>
#                                 <a href="https://www.chick-fil-a.com/stories/press-room" id="news-id" class="news ">News</a>
#                             </li>
#                     </ul>
#                     <div class="stories-feature shared">
#                         <div class="wrapper flex">
#                             <div>
#                                 <div class="cs"> <span class="visually-hidden">The Chicken Wire</span></div>
#                                 <a href="https://www.chick-fil-a.com/stories">View All Stories</a>
#                             </div>
# 		                                <div class="food">
#                                             <h2 class="tag">Food</h2>
#                                             <div class="story-img ">
#                                             <img src="https://d1fd34dzzl09j.cloudfront.net/2022/04/Cloudberry%20Updates/sunjoy.jpg?h=850&amp;w=680&amp;la=en" alt="" />
#                                             </div>
#                                             <p>
#                                                 <a href="https://www.chick-fil-a.com/stories/food/introducing-cloudberry-sunjoy">A berry refreshing flavor: The Cloudberry Sunjoy<sup>&reg;&nbsp;</sup></a>
#                                             </p>
#                                         </div>
# 		                                <div class="lifestyle">
#                                             <h2 class="tag">Lifestyle</h2>
#                                             <div class="story-img ">
#                                             <img src="https://d1fd34dzzl09j.cloudfront.net/2022/04/Spring%20Activities/SmileStand_heade_new.jpg?h=530&amp;w=747&amp;la=en" alt="" />
#                                             </div>
#                                             <p>
#                                                 <a href="https://www.chick-fil-a.com/stories/lifestyle/family-activities-for-spring">5 fun family activities for spring</a>
#                                             </p>
#                                         </div>
# 		                                <div class="cfa-stories">
#                                             <h2 class="tag">Inside <span class="nowrap">Chick-fil-A</span></h2>
#                                             <div class="story-img ">
#                                             <img src="https://d1fd34dzzl09j.cloudfront.net/2022/04/big-Sustainability_Compressed.jpg/large-Sustainability_Compressed.jpg?h=666&amp;w=1000&amp;la=en" alt="" />
#                                             </div>
#                                             <p>
#                                                 <a href="https://www.chick-fil-a.com/stories/inside-chick-fil-a/how-chick-fil-a-is-creating-a-more-sustainable-workplace">How Chick-fil-A is creating a more sustainable workplace</a>
#                                             </p>
#                                         </div>
# 		                                <div class="news">
#                                             <h2 class="tag">News</h2>
#                                             <div class="story-img ">
#                                             <img src="https://d1fd34dzzl09j.cloudfront.net/2022/03/CFA%202022%20Scholarship%20Recipients/CFA%20Scholars%202022_Winners%206_1000.jpg?h=712&amp;w=1025&amp;la=en" alt="CFA Scholars 2022" />
#                                             </div>
#                                             <p>
#                                                 <a href="https://www.chick-fil-a.com/stories/news/chick-fil-a-awards-24-million-in-scholarships-to-restaurant-team-members-nationwide">Chick-fil-A Awards $24 Million in Scholarships to Restaurant Team Members Nationwide</a>
#                                             </p>
#                                         </div>
#                         </div>
#                     </div><!-- /stories-feature -->
#                 </div><!-- /subnav -->
#             </li>
#
#
#
# 	<li id="navitem-about"
# 			class="navitem-hoverable navitem-hoverable--about">
#
# <a href="/about/who-we-are" aria-disabled="true" role="button" >			<span>About</span>
# 				<span class="icon-arrow-down" aria-expanded="false"></span>
# </a>
#
# 			<div class="subnav">
#
#
# 				<ul id="menusubcategoricalid"
# 						class="menusubcategories"
# 						aria-label="Menu subcategories'">
#
# 						<li>
#
# 									<a href="/about/who-we-are" >Who We Are</a>
#
# 						</li>
# 						<li>
#
# 									<a href="/about/great-food" >Great Food</a>
#
# 						</li>
# 						<li>
#
# 									<a href="/about/giving-back-old" >Giving Back</a>
#
# 						</li>
# 						<li>
#
# 									<a href="/about/history" >History</a>
#
# 						</li>
# 						<li>
#
# 									<a href="/about/s-truett-cathy-brand-restaurants" title="S. Truett Cathy Brands" >S. Truett Cathy Brands</a>
#
# 						</li>
# 				</ul>
# 			</div>
# 	</li>
#
#
#
# 	<li id="navitem-about"
# 			class="navitem-hoverable navitem-hoverable--about">
#
# <a href="/careers" aria-disabled="true" role="button" title="Delivery" >			<span>Careers</span>
# </a>
#
# 	</li>
#
# 					</ul>
#
#
#
#
# 	<div class="cfa-one" id="navitem-cfaone">
#
# 				<a
# 					href="http://one.chick-fil-a.com"
# 					target="">Chick-fil-A One</a>
#
# <form action="https://www.chick-fil-a.com/identity/externallogin?authenticationType=Crn&amp;ReturnUrl=%2fidentity%2fexternallogincallback%3fReturnUrl%3dhttp%253a%252f%252fwww.chick-fil-a.com%252flocations%252fbrowse%252fal%26sc_site%3dCFACOM%26authenticationSource%3dDefault&amp;sc_site=CFACOM&amp;signup_redirect_uri=http%3a%2f%2fwww.chick-fil-a.com%2flocations%2fbrowse%2fal" class="sign-in" id="toolbar-menu-signin" method="post">					(
# 					<button type="submit">Sign In</button>
# 					)
# </form>	</div>
#
#
#
#
# <div class="location-tools" data-component="locationTools" data-modal-id="pwo-modal" data-has-favorited-restaurants="false">
# 	<div class="current-location" data-populate="current-location-menu-id">
# 		<div class="icon-location-off"></div>
# 		<button data-element="findRestaurant" type="button">
# 			Find a restaurant
# 		</button>
# 	</div>
# </div>
#
#
#
#
# <div class="search" id="navitem-search">
# 	<form class="site-search">
#
# <div id="search-form"
# 		 class="yext-search-form "
# 		 data-component="yextSearch"
# 		 data-api-key="71620ba70d81b48c7c72331e25462ebc"
# 		 data-business-id="2192285"
# 		 data-locale="en"
# 		 data-experience-key="cfa-answers"
# 		 data-experience-version="PRODUCTION"
# 		 data-placeholder-text="Try: Nutrition and allergens"
# 		 data-redirect-url="http://search.chick-fil-a.com/"
# 		 data-source-id="39335374-a80c-4a4e-bdc8-070135e262a4"></div>
#
#
# 		<button type="submit" class="icon-search-off">
# 			<span>Search</span>
# 		</button>
# 	</form>
#
# 	<span role="button"
# 				tabindex="0"
# 				aria-label="Click here to close the site search"
# 				class="icon-close"></span>
# </div>
#
#
# 					<div class="order-button-group flex">
# <a href="https://order.chick-fil-a.com/get-started" class="btn-round btn-round--red" >Order food</a>
# <a href="https://order.chick-fil-a.com/get-started/catering" class="btn-round btn-round--white" target="|Custom" title="Order Catering" >Order Catering</a>					</div>
# 				</nav>
#
# 			</div>
# 		</div>
# 	</header>
# </div>
#
# <div id="favorited-restaurants-yext"
# 		 data-source="ae7b2b27-b853-46d3-b9f7-b98e2dd1fbe9"
# 		 class="pwo-modal mfp-hide   ">
# 	<button class="mfp-close"></button>
# 	<div class="content">
# <h2>
# 	Find a Restaurant
# </h2>
#
# 	<form class="pwo-modal-search" action="/locations" method="post">
# 		<div class="search-container" data-element="pwoSearchContainer">
# 			<div class="pwo-modals-form-error" data-element="formErrorMsg" role="alert">
# 				<p>
# 					Please enter an address
# 				</p>
# 			</div>
# 			<img src="/-/media/images/cfa/feature/page-content/defaultimages/pwo/pwo-modals/search-icon.ashx?la=en&amp;hash=B242FD403BEB46FFDAA5F7367E443740" alt="Search Icon" />
# 			<input class="user-input"
# 						 type="text"
# 						 name="locationsearch"
# 						 placeholder="Enter address, city and state, or zip"
# 						 aria-label="Enter address, city and state, or zip"
# 						 data-element="pwoSearchInput"
# 						 data-pwo="false">
# 		</div>
# 		<input class="btn-round"
# 					 type="submit"
# 					 value="Search"
# 					 aria-label="Search">
# 	</form>
# 		<form action="/locations" method="post" class="use-location use-location-form" data-component="geoLocation">
# 			<img src="/-/media/images/cfa/feature/page-content/defaultimages/pwo/pwo-modals/use-my-location-icon.ashx?la=en&amp;hash=2441EF1B39331BBB17269D2B7EA274FB" alt="Use My Location Icon" />
# 			<a href="">
# 				Use my location
# 			</a>
#
# 			<input type="hidden" id="loclatitude" name="latitude" value="0">
# 			<input type="hidden" id="loclongitude" name="longitude" value="0">
# 		</form>
#
# 	</div>
# </div>
#
# <div id="find-restaurants-modal"
# 		 data-source="0cc5ac81-a983-4001-a526-7129aecdaadf"
# 		 class="pwo-modal mfp-hide   ">
# 	<button class="mfp-close"></button>
# 	<div class="content">
# <h2>
# 	Find a Restaurant
# </h2>
#
# 	<form class="pwo-modal-search" action="/locations" method="post">
# 		<div class="search-container" data-element="pwoSearchContainer">
# 			<div class="pwo-modals-form-error" data-element="formErrorMsg" role="alert">
# 				<p>
# 					Please enter an address
# 				</p>
# 			</div>
# 			<img src="/-/media/images/cfa/feature/page-content/defaultimages/pwo/pwo-modals/search-icon.ashx?la=en&amp;hash=B242FD403BEB46FFDAA5F7367E443740" alt="Search Icon" />
# 			<input class="user-input"
# 						 type="text"
# 						 name="locationsearch"
# 						 placeholder="Enter address, city and state, or zip"
# 						 aria-label="Enter address, city and state, or zip"
# 						 data-element="pwoSearchInput"
# 						 data-pwo="false">
# 		</div>
# 		<input class="btn-round"
# 					 type="submit"
# 					 value="Search"
# 					 aria-label="Search">
# 	</form>
# 		<form action="/locations" method="post" class="use-location use-location-form" data-component="geoLocation">
# 			<img src="/-/media/images/cfa/feature/page-content/defaultimages/pwo/pwo-modals/use-my-location-icon.ashx?la=en&amp;hash=2441EF1B39331BBB17269D2B7EA274FB" alt="Use My Location Icon" />
# 			<a href="">
# 				Use my location
# 			</a>
#
# 			<input type="hidden" id="loclatitude" name="latitude" value="0">
# 			<input type="hidden" id="loclongitude" name="longitude" value="0">
# 		</form>
#
# 	</div>
# </div>
#
#
# <!-- Page content -->
# <div class="frame" id="LocationFrameId">
#
#
# <div class="top-hero" id="top-hero">
#     <div class="wrapper">
#         <h1>Location listings</h1>
#     </div><!-- /wrapper -->
#     <div class="hero-img">
#         <img src="" alt="" class="sml-img">
#         <img src="https://d1fd34dzzl09j.cloudfront.net/Images/CFACOM/Location%20Images/mapsml-fpo_Dark.jpg" alt="map" class="lrg-img">
#     </div><!-- /hero-img -->
# </div><!-- /top-hero -->
#     <article class="wrapper">
#             <h1>Locations in al</h1>
# 						<div class="state-locations-list">
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/5-points-in-line">5 Points In-Line</a>
# 													</h2>
#
# 													<p>
# 															2000 Highland Ave S
# 															<br />Birmingham, AL 35205
# 																	<br />
# (205) 930-8000													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/airport-blvd-al">Airport Blvd (AL)</a>
# 													</h2>
#
# 													<p>
# 															4707 Airport Blvd
# 															<br />Mobile, AL 36608
# 																	<br />
# (251) 461-9933													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/alabama-am-university">Alabama A&amp;M University</a>
# 													</h2>
#
# 													<p>
# 															4900 Meridian St NW
# 															<br />Huntsville, AL 35762
# 													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/alabama-power">Alabama Power</a>
# 													</h2>
#
# 													<p>
# 															600 18th St N
# 															<br />Birmingham, AL 35203
# 																	<br />
# (205) 257-1688													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/alabama-state-university">Alabama State University</a>
# 													</h2>
#
# 													<p>
# 															1055 Tullibody Dr
# 																	<br />
# John Garrick Hardy Student Center															<br />Montgomery, AL 36104
# 																	<br />
# (334) 497-0292													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/alabaster">Alabaster</a>
# 													</h2>
#
# 													<p>
# 															125 Colonial Promenade Pkwy
# 															<br />Alabaster, AL 35007
# 																	<br />
# (205) 685-1190													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/alexander-city-al">Alexander City [AL]</a>
# 													</h2>
#
# 													<p>
# 															3899 Hwy 280
# 															<br />Alexander City, AL 35010
# 																	<br />
# (938) 867-4825													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/ann-street">Ann Street</a>
# 													</h2>
#
# 													<p>
# 															915 Ann St
# 															<br />Montgomery, AL 36107
# 																	<br />
# (334) 262-2017													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/athens-al">Athens (AL)</a>
# 													</h2>
#
# 													<p>
# 															1291 US Highway 72 E
# 															<br />Athens, AL 35611
# 																	<br />
# (256) 233-8900													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/auburn-in-line-dt">Auburn In-Line DT</a>
# 													</h2>
#
# 													<p>
# 															326 W Magnolia Ave
# 															<br />Auburn, AL 36832
# 																	<br />
# (334) 826-7630													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/auburn-mall">Auburn Mall</a>
# 													</h2>
#
# 													<p>
# 															1627 Opelika Rd Ste 54
# 															<br />Auburn, AL 36830
# 																	<br />
# (334) 887-5429													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/auburn-university">Auburn University</a>
# 													</h2>
#
# 													<p>
# 															255 Heisman Dr
# 																	<br />
# Stdent Center															<br />Auburn, AL 36849
# 																	<br />
# (334) 844-1284													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/auburn-university-arena-concessions">Auburn University - ARENA Concessions</a>
# 													</h2>
#
# 													<p>
# 															250 Beard-Eves Ct
# 																	<br />
# Aurburn Arena															<br />Auburn, AL 36849
# 																	<br />
# (334) 844-8815													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/auburn-university-village-dining">Auburn University - Village Dining</a>
# 													</h2>
#
# 													<p>
# 															230 Beard-Eaves Ct
# 																	<br />
# The Village View Dining Facility															<br />Auburn, AL 36849
# 																	<br />
# (334) 844-1284													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/bel-air-mall">Bel Air Mall</a>
# 													</h2>
#
# 													<p>
# 															3215C Bel Air Mall
# 															<br />Mobile, AL 36606
# 																	<br />
# (251) 476-8361													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/birmingham-shuttlesworth-international-airport">Birmingham-Shuttlesworth International Airport</a>
# 													</h2>
#
# 													<p>
# 															5900 Messer Airport Hwy
# 																	<br />
# Suite #0034															<br />Birmingham, AL 35212
# 																	<br />
# (205) 592-4362													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/cahaba-heights">Cahaba Heights</a>
# 													</h2>
#
# 													<p>
# 															3949 Crosshaven Dr
# 															<br />Vestavia, AL 35243
# 																	<br />
# (205) 871-1398													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/calera">Calera</a>
# 													</h2>
#
# 													<p>
# 															64 Highway 304
# 															<br />Calera, AL 35040
# 																	<br />
# (205) 668-7483													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/cullman">Cullman</a>
# 													</h2>
#
# 													<p>
# 															1830 Cherokee Ave SW
# 															<br />Cullman, AL 35055
# 																	<br />
# (256) 735-1650													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/daphne">Daphne</a>
# 													</h2>
#
# 													<p>
# 															1682 US Highway 98
# 															<br />Daphne, AL 36526
# 																	<br />
# (251) 621-3215													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/dauphin-street">Dauphin Street</a>
# 													</h2>
#
# 													<p>
# 															3244 Dauphin St
# 															<br />Mobile, AL 36606
# 																	<br />
# (251) 476-0320													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/east-dothan">East Dothan</a>
# 													</h2>
#
# 													<p>
# 															1905 E Main St
# 															<br />Dothan, AL 36301
# 																	<br />
# (334) 792-2498													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/eastchase">EastChase</a>
# 													</h2>
#
# 													<p>
# 															6921 Eastchase Loop
# 															<br />Montgomery, AL 36117
# 																	<br />
# (334) 271-1095													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/eastwood-village">Eastwood Village</a>
# 													</h2>
#
# 													<p>
# 															1648 Montclair Rd
# 															<br />Irondale, AL 35210
# 																	<br />
# (205) 957-2229													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/enterprise-al">Enterprise (AL)</a>
# 													</h2>
#
# 													<p>
# 															626 Boll Weevil Cir
# 															<br />Enterprise, AL 36330
# 																	<br />
# (334) 347-4747													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/eufaula-al">Eufaula [AL]</a>
# 													</h2>
#
# 													<p>
# 															900 S Eufaula Ave
# 															<br />Eufaula, AL 36027
# 																	<br />
# (334) 687-8999													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/florence">Florence</a>
# 													</h2>
#
# 													<p>
# 															341 Cox Creek Pkwy
# 															<br />Florence, AL 35630
# 																	<br />
# (256) 764-0535													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/foley">Foley</a>
# 													</h2>
#
# 													<p>
# 															3013 S McKenzie St
# 															<br />Foley, AL 36535
# 																	<br />
# (251) 971-6505													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/fort-payne">Fort Payne</a>
# 													</h2>
#
# 													<p>
# 															1824 Glenn Blvd SW
# 															<br />Fort Payne, AL 35968
# 																	<br />
# (256) 844-8384													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/fultondale">Fultondale</a>
# 													</h2>
#
# 													<p>
# 															215 Howell St
# 															<br />Fultondale, AL 35068
# 																	<br />
# (205) 841-1777													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/gadsden-at-4th-street">Gadsden at 4th Street</a>
# 													</h2>
#
# 													<p>
# 															1008 S 4th St
# 															<br />Gadsden, AL 35901
# 																	<br />
# (256) 543-7770													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/gadsden-mall">Gadsden Mall</a>
# 													</h2>
#
# 													<p>
# 															1001 Rainbow Dr Ste 61
# 															<br />Gadsden, AL 35901
# 																	<br />
# (256) 547-4447													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/gardendale">Gardendale</a>
# 													</h2>
#
# 													<p>
# 															385 Fieldstown Rd
# 															<br />Gardendale, AL 35071
# 																	<br />
# (205) 608-3488													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/governors-drive">Governors Drive</a>
# 													</h2>
#
# 													<p>
# 															402 Governors Dr SW
# 															<br />Huntsville, AL 35801
# 																	<br />
# (256) 536-5150													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/greystone">Greystone</a>
# 													</h2>
#
# 													<p>
# 															5375 Highway 280
# 															<br />Birmingham, AL 35242
# 																	<br />
# (205) 995-8333													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/guntersville">Guntersville</a>
# 													</h2>
#
# 													<p>
# 															11488 US Highway 431
# 															<br />Guntersville, AL 35976
# 																	<br />
# (256) 894-8303													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/hampton-cove-in-line-dt">Hampton Cove In-Line DT</a>
# 													</h2>
#
# 													<p>
# 															6599 Highway 431 S
# 															<br />Owens Cross Roads, AL 35763
# 																	<br />
# (256) 288-0007													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/helena-al">Helena (AL)</a>
# 													</h2>
#
# 													<p>
# 															2432 Helena Rd
# 															<br />Helena, AL 35080
# 																	<br />
# (205) 922-1153													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/hoover-commons">Hoover Commons</a>
# 													</h2>
#
# 													<p>
# 															1609 Montgomery Hwy
# 															<br />Hoover, AL 35216
# 																	<br />
# (205) 979-9990													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/inverness">Inverness</a>
# 													</h2>
#
# 													<p>
# 															4620 US 280 South
# 															<br />Birmingham, AL 35242
# 																	<br />
# (205) 995-9925													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/jacksonville-al">Jacksonville [AL]</a>
# 													</h2>
#
# 													<p>
# 															500 Pelham Rd S
# 															<br />Jacksonville, AL 36265
# 																	<br />
# (256) 782-0900													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/jacksonville-state-university">Jacksonville State University</a>
# 													</h2>
#
# 													<p>
# 															700 Pelham Rd N
# 															<br />Jacksonville, AL 36265
# 																	<br />
# (256) 782-5554													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/jasper">Jasper</a>
# 													</h2>
#
# 													<p>
# 															1812 Highway 78 E
# 															<br />Jasper, AL 35501
# 																	<br />
# (205) 221-0308													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/leeds">Leeds</a>
# 													</h2>
#
# 													<p>
# 															1808 Ashville Rd
# 															<br />Leeds, AL 35094
# 																	<br />
# (205) 699-1118													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/madison-al">Madison (AL)</a>
# 													</h2>
#
# 													<p>
# 															8300 Highway 72 W
# 															<br />Madison, AL 35758
# 																	<br />
# (256) 837-7020													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/mccalla">McCalla</a>
# 													</h2>
#
# 													<p>
# 															6000 Harris Ln
# 															<br />Bessemer, AL 35022
# 																	<br />
# (205) 426-3190													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/midtown-plaza-in-line">Midtown Plaza In-Line</a>
# 													</h2>
#
# 													<p>
# 															1913 5th Ave N
# 															<br />Birmingham, AL 35203
# 																	<br />
# (205) 324-6161													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/montgomery-promenade">Montgomery-Promenade</a>
# 													</h2>
#
# 													<p>
# 															2682 Eastern Blvd
# 															<br />Montgomery, AL 36117
# 																	<br />
# (334) 271-0104													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/muscle-shoals">Muscle Shoals</a>
# 													</h2>
#
# 													<p>
# 															511 Avalon Ave
# 															<br />Muscle Shoals, AL 35661
# 																	<br />
# (256) 386-5442													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/northport">Northport</a>
# 													</h2>
#
# 													<p>
# 															1620 McFarland Blvd
# 															<br />Northport, AL 35476
# 																	<br />
# (205) 330-1110													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/oak-mountain">Oak Mountain</a>
# 													</h2>
#
# 													<p>
# 															320 Cahaba Valley Rd
# 															<br />Pelham, AL 35124
# 																	<br />
# (205) 403-3223													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/oxford">Oxford</a>
# 													</h2>
#
# 													<p>
# 															201 Oxford Exchange Blvd
# 															<br />Oxford, AL 36203
# 																	<br />
# (256) 835-6009													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/oxford-mall">Oxford Mall</a>
# 													</h2>
#
# 													<p>
# 															700 Quintard Dr Ste FC8
# 															<br />Oxford, AL 36203
# 																	<br />
# (256) 835-1887													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/parkway-east">Parkway East</a>
# 													</h2>
#
# 													<p>
# 															9345 Parkway E
# 															<br />Birmingham, AL 35215
# 																	<br />
# (205) 836-0003													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/parkway-place">Parkway Place</a>
# 													</h2>
#
# 													<p>
# 															2801 Memorial Pkwy SW Ste 70
# 															<br />Huntsville, AL 35801
# 																	<br />
# (256) 533-9206													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/patton-creek">Patton Creek</a>
# 													</h2>
#
# 													<p>
# 															3020 John Hawkins Pkwy
# 															<br />Hoover, AL 35244
# 																	<br />
# (205) 987-7568													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/pell-city">Pell City</a>
# 													</h2>
#
# 													<p>
# 															1653 Martin St N
# 															<br />Pell City, AL 35125
# 																	<br />
# (205) 525-0539													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/phenix-city">Phenix City</a>
# 													</h2>
#
# 													<p>
# 															3711 U S Hwy 280
# 															<br />Phenix City, AL 36867
# 																	<br />
# (334) 214-5599													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/prattville">Prattville</a>
# 													</h2>
#
# 													<p>
# 															1967 Cobbs Ford Rd
# 															<br />Prattville, AL 36066
# 																	<br />
# (334) 365-8222													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/riverchase-galleria">Riverchase Galleria</a>
# 													</h2>
#
# 													<p>
# 															2000 Riverchase Galleria Ste 158B
# 															<br />Hoover, AL 35244
# 																	<br />
# (205) 987-2244													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/ross-clark-circle">Ross Clark Circle</a>
# 													</h2>
#
# 													<p>
# 															3418 Ross Clark Cir
# 															<br />Dothan, AL 36303
# 																	<br />
# (334) 712-4849													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/rsa-battlehouse">RSA Battlehouse</a>
# 													</h2>
#
# 													<p>
# 															12 N Royal St
# 															<br />Mobile, AL 36602
# 																	<br />
# (251) 434-9768													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/rsa-regions-tower">RSA Regions Tower</a>
# 													</h2>
#
# 													<p>
# 															201 Monroe St
# 																	<br />
# Suite 162															<br />Montgomery, AL 36104
# 																	<br />
# (334) 293-4773													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/samford-university">Samford University</a>
# 													</h2>
#
# 													<p>
# 															800 Lakeshore Dr
# 															<br />Birmingham, AL 35229
# 																	<br />
# (205) 726-2637													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/schillinger-road">Schillinger Road</a>
# 													</h2>
#
# 													<p>
# 															435 Schillinger Rd S
# 															<br />Mobile, AL 36695
# 																	<br />
# (251) 639-1163													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/south-memorial-parkway">South Memorial Parkway</a>
# 													</h2>
#
# 													<p>
# 															11820 Memorial Pkwy SW
# 															<br />Huntsville, AL 35803
# 																	<br />
# (256) 650-7014													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/southeast-decatur">Southeast Decatur</a>
# 													</h2>
#
# 													<p>
# 															2502 Highway 31 S
# 															<br />Decatur, AL 35603
# 																	<br />
# (256) 822-1014													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/southwest-decatur">Southwest Decatur</a>
# 													</h2>
#
# 													<p>
# 															1809 Beltline Rd SW
# 															<br />Decatur, AL 35601
# 																	<br />
# (256) 355-3035													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/spanish-fort">Spanish Fort</a>
# 													</h2>
#
# 													<p>
# 															30500 SR 181 Suite B
# 															<br />Spanish Fort, AL 36527
# 																	<br />
# (251) 621-3020													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/sylacauga-al">Sylacauga [AL]</a>
# 													</h2>
#
# 													<p>
# 															75 MCS Blvd
# 															<br />Sylacauga, AL 35150
# 																	<br />
# (256) 245-0096													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/the-grove">The Grove</a>
# 													</h2>
#
# 													<p>
# 															5658 Grove Blvd
# 															<br />Hoover, AL 35226
# 																	<br />
# (205) 989-1701													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/tigertown">TigerTown</a>
# 													</h2>
#
# 													<p>
# 															2052 Tiger Town Pkwy
# 															<br />Opelika, AL 36801
# 																	<br />
# (334) 741-7112													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/troy-al">Troy (AL)</a>
# 													</h2>
#
# 													<p>
# 															1121 Highway 231 S
# 															<br />Troy, AL 36081
# 																	<br />
# (334) 566-0505													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/troy-university">Troy University</a>
# 													</h2>
#
# 													<p>
# 															214 Adams Ctr
# 															<br />Troy, AL 36082
# 																	<br />
# (334) 670-5858													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/trussville-al">Trussville (AL)</a>
# 													</h2>
#
# 													<p>
# 															5886 Trussville Crossings Pkwy
# 															<br />Birmingham, AL 35235
# 																	<br />
# (205) 661-0544													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/tuscaloosa-drive-thru-only">Tuscaloosa Drive-Thru Only</a>
# 													</h2>
#
# 													<p>
# 															2014 McFarland Blvd E
# 															<br />Tuscaloosa, AL 35404
# 																	<br />
# (205) 752-9999													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/tuscaloosa-south">Tuscaloosa South</a>
# 													</h2>
#
# 													<p>
# 															4900 Old Greensboro Rd
# 															<br />Tuscaloosa, AL 35405
# 																	<br />
# (205) 247-9980													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/tuskegee-university">Tuskegee University</a>
# 													</h2>
#
# 													<p>
# 															1200 W Montgomery Rd
# 															<br />Tuskegee Institute, AL 36088
# 													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/university-drive">University Drive</a>
# 													</h2>
#
# 													<p>
# 															4733 University Dr NW
# 															<br />Huntsville, AL 35816
# 																	<br />
# (256) 837-1315													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/university-mall-al">University Mall (AL)</a>
# 													</h2>
#
# 													<p>
# 															1701 McFarland Blvd E Ste 190
# 															<br />Tuscaloosa, AL 35404
# 																	<br />
# (205) 553-9195													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/university-of-alabama">University of Alabama</a>
# 													</h2>
#
# 													<p>
# 															Bama Dining Services
# 																	<br />
# Ferguson Center															<br />Tuscaloosa, AL 35487
# 																	<br />
# (205) 348-6816													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/university-of-alabama-huntsville">University of Alabama - Huntsville</a>
# 													</h2>
#
# 													<p>
# 															507 John Wright Dr
# 															<br />Huntsville, AL 35805
# 																	<br />
# (256) 824-5124													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/university-of-alabama-birmingham">University of Alabama Birmingham</a>
# 													</h2>
#
# 													<p>
# 															1000 14th Ave S
# 															<br />Birmingham, AL 35205
# 													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/university-of-alabama-birmingham-hospital">University of Alabama Birmingham Hospital</a>
# 													</h2>
#
# 													<p>
# 															625 19th St S
# 																	<br />
# Jefferson Tower															<br />Birmingham, AL 35233
# 																	<br />
# (205) 502-7005													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/university-of-alabama-lloyd-hall">University of Alabama-Lloyd Hall</a>
# 													</h2>
#
# 													<p>
# 															503 6th Ave
# 																	<br />
# Lloyd Hall															<br />Tuscaloosa, AL 35404
# 																	<br />
# (205) 348-6429													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/university-of-north-alabama">University of North Alabama</a>
# 													</h2>
#
# 													<p>
# 															1 Harrison Plz
# 																	<br />
# Student Commons Building															<br />Florence, AL 35632
# 																	<br />
# (256) 765-5667													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/university-of-south-alabama">University of South Alabama</a>
# 													</h2>
#
# 													<p>
# 															350 Campus Dr
# 																	<br />
# Student Center															<br />Mobile, AL 36608
# 																	<br />
# (251) 460-6296													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/vestavia-hills">Vestavia Hills</a>
# 													</h2>
#
# 													<p>
# 															513 Montgomery Hwy
# 															<br />Vestavia Hills, AL 35216
# 																	<br />
# (205) 824-3540													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/whitesburg-drive">Whitesburg Drive</a>
# 													</h2>
#
# 													<p>
# 															4751 Whitesburg Dr SE
# 															<br />Huntsville, AL 35802
# 																	<br />
# (256) 880-4080													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/wildwood-centre">Wildwood Centre</a>
# 													</h2>
#
# 													<p>
# 															211 Lakeshore Pkwy
# 															<br />Homewood, AL 35209
# 																	<br />
# (205) 945-6062													</p>
# 											</div>
# 						</div>
#     </article>
#
#
# 	<div class="footer">
# 		<footer>
# 	<div class="lrg-app-banner">
# 		<div id="CFAOneBanner" class="wrapper account-offers">
# 			<img src="/-/media/images/cfacom/cfa-one/cfa_one_red_pms.ashx?h=99&amp;w=316&amp;la=en&amp;hash=C85A056E5C62AA3053CD497DA971E577" alt="Chick-fil-A One" />
# 			<h2 class="tagline">
# 				Join Chick-fil-A One<sup>&reg;</sup>. Earn points with every qualifying purchase. Redeem available rewards of your choice.
# 			</h2>
#
# 			<p class="disclaimer-txt">
# 				<span>The <span class="nowrap">Chick-fil-A</span>&nbsp;App is not presently accepted at <span class="nowrap">Chick-fil-A</span> Express&trade; and <span class="nowrap">Chick-fil-A</span> licensed locations such as those in airports and college campuses. These locations are operated by professional third-party food contractors and their operating systems do not currently offer guests the ability to earn points or redeem rewards through the <span class="nowrap">Chick-fil-A App.</span></span>
# 			</p>
#
# 			<div class="app-stores">
# 				<a href="https://itunes.apple.com/us/app/chick-fil-a/id488818252" class="apple cfa-one-app-goal" rel="noopener noreferrer" target="_blank" title="Download on the App Store" >Download on the App Store</a>
# 				<a href="https://play.google.com/store/apps/details?id=com.chickfila.cfaflagship" class="google cfa-one-app-goal" rel="noopener noreferrer" target="_blank" >Get it on Google Play</a>
# 			</div>
#
# 			<a href="https://www.chick-fil-a.com/One" class="btn--vis" title="Learn more about the Chick-fil-A One program" >Learn more</a>
#
# 			<div class="signin-wrapper">
# 				<p>Already have an account? </p>
#
# <form action="/identity/externallogin?authenticationType=Crn&amp;ReturnUrl=%2fidentity%2fexternallogincallback%3fReturnUrl%3d%252f%26sc_site%3dCFACOM%26authenticationSource%3dDefault&amp;sc_site=CFACOM&amp;signup_redirect_uri=%2f" method="post">					<button type="submit">
# 						Sign-in
# 					</button>
# </form>			</div>
# 		</div>
#
# 		<div class="app-banner-image">
# 			<img src="https://d1fd34dzzl09j.cloudfront.net/Images/CFACOM/Footer%20Images/footer-burger-phone-desktop-new-3.jpg" alt="CFA One" class="lrg-img">
# 			<img src="https://d1fd34dzzl09j.cloudfront.net/Images/CFACOM/Footer%20Images/footer-burger-phone-mobile-new-3.jpg" alt="CFA One" class="sml-img">
# 		</div>
# 	</div>
#
#
# 			<div class="footer-modules wrapper">
# 				<nav class="footer-nav" aria-label="footer">
# 						<ul aria-label="">
#         <li>
# <a href="/nutrition-allergens" title="Click here to view Chick-fil-A&#39;s Nutrition and Allergens information" >Nutrition &amp; Allergens</a>        </li>
#         <li>
# <a href="/customer-support" >Customer Support</a>        </li>
#         <li>
# <a href="/careers" >Careers</a>        </li>
#         <li>
# <a href="/franchising" >Franchising</a>        </li>
#         <li>
# <a href="https://www.cfaapparel.com/" >Merchandise</a>        </li>
#         <li>
# <a href="https://www.chick-fil-a.com/stories/press-room" >Press Room</a>        </li>
#
#
# 			<li>
# 				<ul>
#         <li>
# <a href="/do-business-with-us" >Do business with us</a>        </li>
#         <li>
# <a href="https://www.chick-fil-a.com/legal#terms_and_conditions" >Terms and Conditions of Use</a>        </li>
#         <li>
# <a href="https://www.chick-fil-a.com/legal#privacy_policy" >Privacy Policy</a>        </li>
#         <li>
# <a href="https://www.chick-fil-a.com/legal#chick-fil-a_cookie_and_interest-based_advertising_policy" >Cookie and Internet-Based Advertising Policy</a>        </li>
#         <li>
# <a href="#ot-sdk-show-settings" class="ot-sdk-show-settings" title="Cookie Preference Center" >Cookie Preference Center</a>        </li>
#         <li>
# <a href="https://www.chick-fil-a.com/legal#accessibility" >Accessibility</a>        </li>
#         <li>
# <a href="/locations/browse" >Locations listing</a>        </li>
#         <li>
# <a href="/legal" >Legal</a>        </li>
#         <li>
# &#169; 2022 CFA Properties, Inc. All rights reserved.        </li>
#
# 				</ul>
# 			</li>
# 	</ul>
#
#
#
# 				</nav><!-- /footer-nav -->
# 				<div class="social">
# 						<ul class="social-icons" aria-label="">
#         <li>
# <a href="https://www.facebook.com/ChickfilA/" class="icon-facebook-over" rel="noopener noreferrer" target="_blank" >                        <span>Facebook</span>
# </a>        </li>
#         <li>
# <a href="https://www.instagram.com/chickfila/" class="icon-instagram-over" rel="noopener noreferrer" target="_blank" >                        <span>Instagram</span>
# </a>        </li>
#         <li>
# <a href="https://twitter.com/ChickfilA" class="icon-twitter-over" rel="noopener noreferrer" target="_blank" >                        <span>Twitter</span>
# </a>        </li>
#         <li>
# <a href="https://www.youtube.com/user/chickfila" class="icon-youtube-over" rel="noopener noreferrer" target="_blank" >                        <span>YouTube</span>
# </a>        </li>
#         <li>
# <a href="https://www.linkedin.com/company/chick-fil-a-corporate/jobs/" class="icon-linkedin-over" rel="noopener noreferrer" target="_blank" >                        <span>LinkedIn</span>
# </a>        </li>
#
#
# 	</ul>
#
#
#
# 				</div><!-- /social-->
# 			</div><!-- /footer-modules -->
# 		</footer>
# 	</div>
#
#
# </div>
#
# 	</div>
# 	<!-- /Page content -->
#
#
# <div class="print-footer">
#     <div class="icon-logo-desktop"></div>
#
# </div><!-- /print-footer -->
#
# <script
# 	src="https://code.jquery.com/jquery-3.4.1.min.js"
# 	integrity="sha256-CSXorXvZcTkaix6Yvo6HppcZGetbYMGWSFlBw8HfCJo="
# 	crossorigin="anonymous"></script>
#
# <script>
# 	window.jQuery || document.write('<script src="https://d2wl1kt18tqdum.cloudfront.net/v2.1.2111-stageb/Assets/Theming/js/lib/jquery.js"><\/script>');
# </script>
#
# <script src="https://d2wl1kt18tqdum.cloudfront.net/v2.1.2111-stageb/Assets/Theming/js/vendor-js.js"></script>
# <script src="https://d2wl1kt18tqdum.cloudfront.net/v2.1.2111-stageb/Assets/Theming/js/CFACom.js"></script>
# <script src="https://d2wl1kt18tqdum.cloudfront.net/v2.1.2111-stageb/Assets/Theming/js/menu-js.js"></script>
#
#
#
#
#
#
# 	<div id="defaultsiteoverlay" class="lightbox mfp-hide"></div>
#
# 	<div class="rt-placeholder hidden"></div>
#
#
#
#
# </body>
# </html>

# %%
form_data = {'key1': 'value1', 'key2': 'value2'}
response = requests.post("https://www.chick-fil-a.com/locations/browse/al", data=form_data)
print(response.text)
# Out:
# <!DOCTYPE html>
# <!--[if gt IE 9]><!-->
# <html lang="en">
# <!--<![endif]-->
# <head>
#
#
#
#
#
#
#
# <meta charset="utf-8">
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
# <meta name="keywords" content="">
# <meta name="description" content="Explore the different Chick-fil-A locations in AL for address, phone number, menu, and website information today.">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1.0, user-scalable=yes" />
# <meta name="server" content="I-082868D024A0F" />
# <meta name="serverzone" content="0.0" />
# <meta name="site" content="CFACOM" />
# <meta name='bsk' content='80dd234943647559a245be654346b81f'/>
# <meta name='bskv' content='2.1.2111-stageb'/>
# 	<link rel="canonical" href="https://www.chick-fil-a.com/locations/browse/al">
#
# <link rel="shortcut icon" href="/Assets/Theming/favicon.ico" type="image/x-icon">
#
# <title>AL Locations and Information | Chick-fil-A</title>
#
# 		<link href="https://d2wl1kt18tqdum.cloudfront.net/v2.1.2111-stageb/Assets/Theming/css/cfacom.css" rel="stylesheet" type="text/css" />
#
#
#
#
# 	<!-- Google Tag Manager -->
# 	<script>
# 		(function (w, d, s, l, i) {
# 			w[l] = w[l] || [];
# 			w[l].push({
# 				'gtm.start' :
# 					new Date().getTime(),
# 				event : 'gtm.js'
# 			});
# 			var f = d.getElementsByTagName(s)[0],
# 				j = d.createElement(s),
# 				dl = l != 'dataLayer' ? '&l=' + l : '';
# 			j.async = true;
# 			j.src =
# 				'//www.googletagmanager.com/gtm.js?id=' + i + dl;
# 			f.parentNode.insertBefore(j, f);
# 		})(window, document, 'script', 'dataLayer', 'GTM-NXDPGM');
# 	</script>
# 	<!-- End Google Tag Manager -->
#
#     <script>
#         function getExperienceType () {
#             var experienceType = "Desktop";
#
#             if (Number(document.documentElement.clientWidth) < 960) {
#                 experienceType = "Mobile";
#             } else if (window.matchMedia("(orientation: landscape)") && (Number(document.documentElement.clientHeight) < 960)) {
#                 experienceType = "Mobile";
#             }
#
#             return experienceType;
#         }
#
#         window.digitalData =
#         {
#             'page' : {
#                 'category' : {
#                     'pageType': 'Location Browse'
#                 },
#                 'pageInfo' : {
#                     'destinationURL' : 'http://www.chick-fil-a.com/locations/browse/al',
#                     'experienceType' : getExperienceType(),
#                     'pageName' : 'Locations List',
#                     'sysEnv' : 'Prod'
#                 }
#             },
#             'user' : {
#                 'profile' : {
#                     'profileInfo' : {
#                         'loginStatus' : 'not-logged-in',
#                         'profileID' : ''
#                     }
#                 }
#             }
#         };
#     </script>
#
#             <!-- Schema.org markup for Google+ -->
#             <meta itemprop="name" content="Location listings">
#             <meta itemprop="description" content="Browse">
#             <meta itemprop="image" content="http://www.chick-fil-a.com/-/media/images/cfacom/default-images/chick-fil-a-logo-vector.ashx">
#             <!-- Twitter Card data -->
#             <meta name="twitter:card" content="summary_large_image">
#             <meta name="twitter:site" content="@ChickfilA">
#             <meta name="twitter:title" content="Location listings">
#             <meta name="twitter:description" content="Browse">
#             <meta name="twitter:creator" content="@ChickfilA">
#             <meta name="twitter:image:src" content="http://www.chick-fil-a.com/-/media/images/cfacom/default-images/chick-fil-a-logo-vector.ashx">
#             <!-- Open Graph data -->
#             <meta property="og:title" content="Location listings"/>
#             <meta property="og:type" content="article"/>
#             <meta property="og:url" content="https://www.chick-fil-a.com/locations/browse/al"/>
#             <meta property="og:description" content="Browse"/>
#             <meta property="og:site_name" content="Chick-fil-A"/>
#             <meta property="article:tag" content=""/>
#             <meta property="og:image" content="http://www.chick-fil-a.com/-/media/images/cfacom/default-images/chick-fil-a-logo-vector.ashx"/>
#                 <meta property="og:image:width" content="693"/>
#                 <meta property="og:image:height" content="390"/>
#
#
#
#
#
# </head>
# <body>
#
#
#
# 	<!-- Google Tag Manager -->
# 	<noscript>
# 		<iframe src="//www.googletagmanager.com/ns.html?id=GTM-NXDPGM"
# 						height="0"
# 						width="0"
# 						style="display: none; visibility: hidden;"></iframe>
# 	</noscript>
# 	<!-- End Google Tag Manager -->
#
#
# 		<a class="visually-hidden skip-link" href="#top-hero">Skip to main content</a>
#
#
#
# 	<div class="location-listings">
#
#
#
#
#
#
# <div class="header-frame" data-sticky-position="true" data-sticky-priority="1">
#
# 	<header data-component="MainNav">
# 		<div class="nav-frame">
# 			<div class="header-components flex">
# 				<a href="/" class="icon-logo-desktop logo"><span>Chick-Fil-A</span></a>
#
#
#
# <div class="location-tools" data-component="locationTools" data-modal-id="pwo-modal" data-has-favorited-restaurants="false">
# 	<div class="current-location" data-populate="current-location-menu-id">
# 		<div class="icon-location-off"></div>
# 		<button data-element="findRestaurant" type="button">
# 			Find a restaurant
# 		</button>
# 	</div>
# </div>
#
#
# <a href="https://order.chick-fil-a.com/get-started" class="order-now" title="Order Now" >Order Now</a>
#
#
# <div class="nav-toggle" data-component="NavToggle">
# 	<a data-action="toggle nav" href="#" class="icon-nav-toggle-off">
# 		<span>Close Main Nav</span>
# 	</a>
# </div>
#
#
# 				<nav class="main-nav" role="navigation" aria-label="Main menu">
# 					<ul class="flex">
#
#
#
#
#
#
#
# 	<li id="navitem-menu"
# 			class="navitem-hoverable navitem-hoverable--menu">
#
# <a href="https://www.chick-fil-a.com/menu" aria-disabled="true" role="button" >			<span>Menu</span>
# 				<span class="icon-arrow-down" aria-expanded="false"></span>
# </a>
#
# 			<div class="subnav">
#
#
# 				<ul id="menusubcategoricalid"
# 						class="menusubcategories"
# 						aria-label="Menu subcategories'">
#
# 						<li>
#
# 									<a href="/menu#breakfast" title="Breakfast" >Breakfast</a>
#
# 						</li>
# 						<li>
#
# 									<a href="/menu#entrees" >Entr&#233;es</a>
#
# 						</li>
# 						<li>
#
# 									<a href="/menu#salads" >Salads</a>
#
# 						</li>
# 						<li>
#
# 									<a href="/menu#sides" >Sides</a>
#
# 						</li>
# 						<li>
#
# 									<a href="/menu#kidsmeals" >Kid&#39;s Meals</a>
#
# 						</li>
# 						<li>
#
# 									<a href="/menu#treats" >Treats</a>
#
# 						</li>
# 						<li>
#
# 									<a href="/menu#beverages" >Drinks</a>
#
# 						</li>
# 						<li>
#
# 									<a href="/menu#sauces" >Dipping Sauces and Dressings</a>
#
# 						</li>
# 						<li>
#
# 									<a href="/catering" >Catering</a>
#
# 						</li>
# 				</ul>
# 			</div>
# 	</li>
#                <li id="navitem-stories" class="navitem-hoverable navitem-hoverable--stories">
#                 <a href="https://www.chick-fil-a.com/stories" id="stories-id" class="">
#                     <span>Stories</span> <span class="icon-arrow-down" aria-expanded="false"></span>
#                 </a>
#                 <div class="subnav">
#                     <ul>
#                         <li class="mobile-only">
#                             <a href="https://www.chick-fil-a.com/stories">All Stories</a>
#                         </li>
#                             <li>
#                                 <a href="https://www.chick-fil-a.com/stories/food" id="food-id" class="food ">Food</a>
#                             </li>
#                             <li>
#                                 <a href="https://www.chick-fil-a.com/stories/lifestyle" id="lifestyle-id" class="lifestyle ">Lifestyle</a>
#                             </li>
#                             <li>
#                                 <a href="https://www.chick-fil-a.com/stories/inside-chick-fil-a" id="cfa-stories-id" class="cfa-stories ">Inside <span class="nowrap">Chick-fil-A</span></a>
#                             </li>
#                             <li>
#                                 <a href="https://www.chick-fil-a.com/stories/press-room" id="news-id" class="news ">News</a>
#                             </li>
#                     </ul>
#                     <div class="stories-feature shared">
#                         <div class="wrapper flex">
#                             <div>
#                                 <div class="cs"> <span class="visually-hidden">The Chicken Wire</span></div>
#                                 <a href="https://www.chick-fil-a.com/stories">View All Stories</a>
#                             </div>
#                         </div>
#                     </div><!-- /stories-feature -->
#                 </div><!-- /subnav -->
#             </li>
#
#
#
# 	<li id="navitem-about"
# 			class="navitem-hoverable navitem-hoverable--about">
#
# <a href="/about/who-we-are" aria-disabled="true" role="button" >			<span>About</span>
# 				<span class="icon-arrow-down" aria-expanded="false"></span>
# </a>
#
# 			<div class="subnav">
#
#
# 				<ul id="menusubcategoricalid"
# 						class="menusubcategories"
# 						aria-label="Menu subcategories'">
#
# 						<li>
#
# 									<a href="/about/who-we-are" >Who We Are</a>
#
# 						</li>
# 						<li>
#
# 									<a href="/about/great-food" >Great Food</a>
#
# 						</li>
# 						<li>
#
# 									<a href="/about/giving-back-old" >Giving Back</a>
#
# 						</li>
# 						<li>
#
# 									<a href="/about/history" >History</a>
#
# 						</li>
# 						<li>
#
# 									<a href="/about/s-truett-cathy-brand-restaurants" title="S. Truett Cathy Brands" >S. Truett Cathy Brands</a>
#
# 						</li>
# 				</ul>
# 			</div>
# 	</li>
#
#
#
# 	<li id="navitem-about"
# 			class="navitem-hoverable navitem-hoverable--about">
#
# <a href="/careers" aria-disabled="true" role="button" title="Delivery" >			<span>Careers</span>
# </a>
#
# 	</li>
#
# 					</ul>
#
#
#
#
# 	<div class="cfa-one" id="navitem-cfaone">
#
# 				<a
# 					href="http://one.chick-fil-a.com"
# 					target="">Chick-fil-A One</a>
#
# <form action="https://www.chick-fil-a.com/identity/externallogin?authenticationType=Crn&amp;ReturnUrl=%2fidentity%2fexternallogincallback%3fReturnUrl%3dhttp%253a%252f%252fwww.chick-fil-a.com%252flocations%252fbrowse%252fal%26sc_site%3dCFACOM%26authenticationSource%3dDefault&amp;sc_site=CFACOM&amp;signup_redirect_uri=http%3a%2f%2fwww.chick-fil-a.com%2flocations%2fbrowse%2fal" class="sign-in" id="toolbar-menu-signin" method="post">					(
# 					<button type="submit">Sign In</button>
# 					)
# </form>	</div>
#
#
#
#
# <div class="location-tools" data-component="locationTools" data-modal-id="pwo-modal" data-has-favorited-restaurants="false">
# 	<div class="current-location" data-populate="current-location-menu-id">
# 		<div class="icon-location-off"></div>
# 		<button data-element="findRestaurant" type="button">
# 			Find a restaurant
# 		</button>
# 	</div>
# </div>
#
#
#
#
# <div class="search" id="navitem-search">
# 	<form class="site-search">
#
# <div id="search-form"
# 		 class="yext-search-form "
# 		 data-component="yextSearch"
# 		 data-api-key="71620ba70d81b48c7c72331e25462ebc"
# 		 data-business-id="2192285"
# 		 data-locale="en"
# 		 data-experience-key="cfa-answers"
# 		 data-experience-version="PRODUCTION"
# 		 data-placeholder-text="Try: Nutrition and allergens"
# 		 data-redirect-url="http://search.chick-fil-a.com/"
# 		 data-source-id="39335374-a80c-4a4e-bdc8-070135e262a4"></div>
#
#
# 		<button type="submit" class="icon-search-off">
# 			<span>Search</span>
# 		</button>
# 	</form>
#
# 	<span role="button"
# 				tabindex="0"
# 				aria-label="Click here to close the site search"
# 				class="icon-close"></span>
# </div>
#
#
# 					<div class="order-button-group flex">
# <a href="https://order.chick-fil-a.com/get-started" class="btn-round btn-round--red" >Order food</a>
# <a href="https://order.chick-fil-a.com/get-started/catering" class="btn-round btn-round--white" target="|Custom" title="Order Catering" >Order Catering</a>					</div>
# 				</nav>
#
# 			</div>
# 		</div>
# 	</header>
# </div>
#
# <div id="favorited-restaurants-yext"
# 		 data-source="ae7b2b27-b853-46d3-b9f7-b98e2dd1fbe9"
# 		 class="pwo-modal mfp-hide   ">
# 	<button class="mfp-close"></button>
# 	<div class="content">
# <h2>
# 	Find a Restaurant
# </h2>
#
# 	<form class="pwo-modal-search" action="/locations" method="post">
# 		<div class="search-container" data-element="pwoSearchContainer">
# 			<div class="pwo-modals-form-error" data-element="formErrorMsg" role="alert">
# 				<p>
# 					Please enter an address
# 				</p>
# 			</div>
# 			<img src="/-/media/images/cfa/feature/page-content/defaultimages/pwo/pwo-modals/search-icon.ashx?la=en&amp;hash=B242FD403BEB46FFDAA5F7367E443740" alt="Search Icon" />
# 			<input class="user-input"
# 						 type="text"
# 						 name="locationsearch"
# 						 placeholder="Enter address, city and state, or zip"
# 						 aria-label="Enter address, city and state, or zip"
# 						 data-element="pwoSearchInput"
# 						 data-pwo="false">
# 		</div>
# 		<input class="btn-round"
# 					 type="submit"
# 					 value="Search"
# 					 aria-label="Search">
# 	</form>
# 		<form action="/locations" method="post" class="use-location use-location-form" data-component="geoLocation">
# 			<img src="/-/media/images/cfa/feature/page-content/defaultimages/pwo/pwo-modals/use-my-location-icon.ashx?la=en&amp;hash=2441EF1B39331BBB17269D2B7EA274FB" alt="Use My Location Icon" />
# 			<a href="">
# 				Use my location
# 			</a>
#
# 			<input type="hidden" id="loclatitude" name="latitude" value="0">
# 			<input type="hidden" id="loclongitude" name="longitude" value="0">
# 		</form>
#
# 	</div>
# </div>
#
# <div id="find-restaurants-modal"
# 		 data-source="0cc5ac81-a983-4001-a526-7129aecdaadf"
# 		 class="pwo-modal mfp-hide   ">
# 	<button class="mfp-close"></button>
# 	<div class="content">
# <h2>
# 	Find a Restaurant
# </h2>
#
# 	<form class="pwo-modal-search" action="/locations" method="post">
# 		<div class="search-container" data-element="pwoSearchContainer">
# 			<div class="pwo-modals-form-error" data-element="formErrorMsg" role="alert">
# 				<p>
# 					Please enter an address
# 				</p>
# 			</div>
# 			<img src="/-/media/images/cfa/feature/page-content/defaultimages/pwo/pwo-modals/search-icon.ashx?la=en&amp;hash=B242FD403BEB46FFDAA5F7367E443740" alt="Search Icon" />
# 			<input class="user-input"
# 						 type="text"
# 						 name="locationsearch"
# 						 placeholder="Enter address, city and state, or zip"
# 						 aria-label="Enter address, city and state, or zip"
# 						 data-element="pwoSearchInput"
# 						 data-pwo="false">
# 		</div>
# 		<input class="btn-round"
# 					 type="submit"
# 					 value="Search"
# 					 aria-label="Search">
# 	</form>
# 		<form action="/locations" method="post" class="use-location use-location-form" data-component="geoLocation">
# 			<img src="/-/media/images/cfa/feature/page-content/defaultimages/pwo/pwo-modals/use-my-location-icon.ashx?la=en&amp;hash=2441EF1B39331BBB17269D2B7EA274FB" alt="Use My Location Icon" />
# 			<a href="">
# 				Use my location
# 			</a>
#
# 			<input type="hidden" id="loclatitude" name="latitude" value="0">
# 			<input type="hidden" id="loclongitude" name="longitude" value="0">
# 		</form>
#
# 	</div>
# </div>
#
#
# <!-- Page content -->
# <div class="frame" id="LocationFrameId">
#
#
# <div class="top-hero" id="top-hero">
#     <div class="wrapper">
#         <h1>Location listings</h1>
#     </div><!-- /wrapper -->
#     <div class="hero-img">
#         <img src="" alt="" class="sml-img">
#         <img src="https://d1fd34dzzl09j.cloudfront.net/Images/CFACOM/Location%20Images/mapsml-fpo_Dark.jpg" alt="map" class="lrg-img">
#     </div><!-- /hero-img -->
# </div><!-- /top-hero -->
#     <article class="wrapper">
#             <h1>Locations in al</h1>
# 						<div class="state-locations-list">
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/5-points-in-line">5 Points In-Line</a>
# 													</h2>
#
# 													<p>
# 															2000 Highland Ave S
# 															<br />Birmingham, AL 35205
# 																	<br />
# (205) 930-8000													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/airport-blvd-al">Airport Blvd (AL)</a>
# 													</h2>
#
# 													<p>
# 															4707 Airport Blvd
# 															<br />Mobile, AL 36608
# 																	<br />
# (251) 461-9933													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/alabama-am-university">Alabama A&amp;M University</a>
# 													</h2>
#
# 													<p>
# 															4900 Meridian St NW
# 															<br />Huntsville, AL 35762
# 													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/alabama-power">Alabama Power</a>
# 													</h2>
#
# 													<p>
# 															600 18th St N
# 															<br />Birmingham, AL 35203
# 																	<br />
# (205) 257-1688													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/alabama-state-university">Alabama State University</a>
# 													</h2>
#
# 													<p>
# 															1055 Tullibody Dr
# 																	<br />
# John Garrick Hardy Student Center															<br />Montgomery, AL 36104
# 																	<br />
# (334) 497-0292													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/alabaster">Alabaster</a>
# 													</h2>
#
# 													<p>
# 															125 Colonial Promenade Pkwy
# 															<br />Alabaster, AL 35007
# 																	<br />
# (205) 685-1190													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/alexander-city-al">Alexander City [AL]</a>
# 													</h2>
#
# 													<p>
# 															3899 Hwy 280
# 															<br />Alexander City, AL 35010
# 																	<br />
# (938) 867-4825													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/ann-street">Ann Street</a>
# 													</h2>
#
# 													<p>
# 															915 Ann St
# 															<br />Montgomery, AL 36107
# 																	<br />
# (334) 262-2017													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/athens-al">Athens (AL)</a>
# 													</h2>
#
# 													<p>
# 															1291 US Highway 72 E
# 															<br />Athens, AL 35611
# 																	<br />
# (256) 233-8900													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/auburn-in-line-dt">Auburn In-Line DT</a>
# 													</h2>
#
# 													<p>
# 															326 W Magnolia Ave
# 															<br />Auburn, AL 36832
# 																	<br />
# (334) 826-7630													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/auburn-mall">Auburn Mall</a>
# 													</h2>
#
# 													<p>
# 															1627 Opelika Rd Ste 54
# 															<br />Auburn, AL 36830
# 																	<br />
# (334) 887-5429													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/auburn-university">Auburn University</a>
# 													</h2>
#
# 													<p>
# 															255 Heisman Dr
# 																	<br />
# Stdent Center															<br />Auburn, AL 36849
# 																	<br />
# (334) 844-1284													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/auburn-university-arena-concessions">Auburn University - ARENA Concessions</a>
# 													</h2>
#
# 													<p>
# 															250 Beard-Eves Ct
# 																	<br />
# Aurburn Arena															<br />Auburn, AL 36849
# 																	<br />
# (334) 844-8815													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/auburn-university-village-dining">Auburn University - Village Dining</a>
# 													</h2>
#
# 													<p>
# 															230 Beard-Eaves Ct
# 																	<br />
# The Village View Dining Facility															<br />Auburn, AL 36849
# 																	<br />
# (334) 844-1284													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/bel-air-mall">Bel Air Mall</a>
# 													</h2>
#
# 													<p>
# 															3215C Bel Air Mall
# 															<br />Mobile, AL 36606
# 																	<br />
# (251) 476-8361													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/birmingham-shuttlesworth-international-airport">Birmingham-Shuttlesworth International Airport</a>
# 													</h2>
#
# 													<p>
# 															5900 Messer Airport Hwy
# 																	<br />
# Suite #0034															<br />Birmingham, AL 35212
# 																	<br />
# (205) 592-4362													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/cahaba-heights">Cahaba Heights</a>
# 													</h2>
#
# 													<p>
# 															3949 Crosshaven Dr
# 															<br />Vestavia, AL 35243
# 																	<br />
# (205) 871-1398													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/calera">Calera</a>
# 													</h2>
#
# 													<p>
# 															64 Highway 304
# 															<br />Calera, AL 35040
# 																	<br />
# (205) 668-7483													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/cullman">Cullman</a>
# 													</h2>
#
# 													<p>
# 															1830 Cherokee Ave SW
# 															<br />Cullman, AL 35055
# 																	<br />
# (256) 735-1650													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/daphne">Daphne</a>
# 													</h2>
#
# 													<p>
# 															1682 US Highway 98
# 															<br />Daphne, AL 36526
# 																	<br />
# (251) 621-3215													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/dauphin-street">Dauphin Street</a>
# 													</h2>
#
# 													<p>
# 															3244 Dauphin St
# 															<br />Mobile, AL 36606
# 																	<br />
# (251) 476-0320													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/east-dothan">East Dothan</a>
# 													</h2>
#
# 													<p>
# 															1905 E Main St
# 															<br />Dothan, AL 36301
# 																	<br />
# (334) 792-2498													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/eastchase">EastChase</a>
# 													</h2>
#
# 													<p>
# 															6921 Eastchase Loop
# 															<br />Montgomery, AL 36117
# 																	<br />
# (334) 271-1095													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/eastwood-village">Eastwood Village</a>
# 													</h2>
#
# 													<p>
# 															1648 Montclair Rd
# 															<br />Irondale, AL 35210
# 																	<br />
# (205) 957-2229													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/enterprise-al">Enterprise (AL)</a>
# 													</h2>
#
# 													<p>
# 															626 Boll Weevil Cir
# 															<br />Enterprise, AL 36330
# 																	<br />
# (334) 347-4747													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/eufaula-al">Eufaula [AL]</a>
# 													</h2>
#
# 													<p>
# 															900 S Eufaula Ave
# 															<br />Eufaula, AL 36027
# 																	<br />
# (334) 687-8999													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/florence">Florence</a>
# 													</h2>
#
# 													<p>
# 															341 Cox Creek Pkwy
# 															<br />Florence, AL 35630
# 																	<br />
# (256) 764-0535													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/foley">Foley</a>
# 													</h2>
#
# 													<p>
# 															3013 S McKenzie St
# 															<br />Foley, AL 36535
# 																	<br />
# (251) 971-6505													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/fort-payne">Fort Payne</a>
# 													</h2>
#
# 													<p>
# 															1824 Glenn Blvd SW
# 															<br />Fort Payne, AL 35968
# 																	<br />
# (256) 844-8384													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/fultondale">Fultondale</a>
# 													</h2>
#
# 													<p>
# 															215 Howell St
# 															<br />Fultondale, AL 35068
# 																	<br />
# (205) 841-1777													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/gadsden-at-4th-street">Gadsden at 4th Street</a>
# 													</h2>
#
# 													<p>
# 															1008 S 4th St
# 															<br />Gadsden, AL 35901
# 																	<br />
# (256) 543-7770													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/gadsden-mall">Gadsden Mall</a>
# 													</h2>
#
# 													<p>
# 															1001 Rainbow Dr Ste 61
# 															<br />Gadsden, AL 35901
# 																	<br />
# (256) 547-4447													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/gardendale">Gardendale</a>
# 													</h2>
#
# 													<p>
# 															385 Fieldstown Rd
# 															<br />Gardendale, AL 35071
# 																	<br />
# (205) 608-3488													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/governors-drive">Governors Drive</a>
# 													</h2>
#
# 													<p>
# 															402 Governors Dr SW
# 															<br />Huntsville, AL 35801
# 																	<br />
# (256) 536-5150													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/greystone">Greystone</a>
# 													</h2>
#
# 													<p>
# 															5375 Highway 280
# 															<br />Birmingham, AL 35242
# 																	<br />
# (205) 995-8333													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/guntersville">Guntersville</a>
# 													</h2>
#
# 													<p>
# 															11488 US Highway 431
# 															<br />Guntersville, AL 35976
# 																	<br />
# (256) 894-8303													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/hampton-cove-in-line-dt">Hampton Cove In-Line DT</a>
# 													</h2>
#
# 													<p>
# 															6599 Highway 431 S
# 															<br />Owens Cross Roads, AL 35763
# 																	<br />
# (256) 288-0007													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/helena-al">Helena (AL)</a>
# 													</h2>
#
# 													<p>
# 															2432 Helena Rd
# 															<br />Helena, AL 35080
# 																	<br />
# (205) 922-1153													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/hoover-commons">Hoover Commons</a>
# 													</h2>
#
# 													<p>
# 															1609 Montgomery Hwy
# 															<br />Hoover, AL 35216
# 																	<br />
# (205) 979-9990													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/inverness">Inverness</a>
# 													</h2>
#
# 													<p>
# 															4620 US 280 South
# 															<br />Birmingham, AL 35242
# 																	<br />
# (205) 995-9925													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/jacksonville-al">Jacksonville [AL]</a>
# 													</h2>
#
# 													<p>
# 															500 Pelham Rd S
# 															<br />Jacksonville, AL 36265
# 																	<br />
# (256) 782-0900													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/jacksonville-state-university">Jacksonville State University</a>
# 													</h2>
#
# 													<p>
# 															700 Pelham Rd N
# 															<br />Jacksonville, AL 36265
# 																	<br />
# (256) 782-5554													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/jasper">Jasper</a>
# 													</h2>
#
# 													<p>
# 															1812 Highway 78 E
# 															<br />Jasper, AL 35501
# 																	<br />
# (205) 221-0308													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/leeds">Leeds</a>
# 													</h2>
#
# 													<p>
# 															1808 Ashville Rd
# 															<br />Leeds, AL 35094
# 																	<br />
# (205) 699-1118													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/madison-al">Madison (AL)</a>
# 													</h2>
#
# 													<p>
# 															8300 Highway 72 W
# 															<br />Madison, AL 35758
# 																	<br />
# (256) 837-7020													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/mccalla">McCalla</a>
# 													</h2>
#
# 													<p>
# 															6000 Harris Ln
# 															<br />Bessemer, AL 35022
# 																	<br />
# (205) 426-3190													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/midtown-plaza-in-line">Midtown Plaza In-Line</a>
# 													</h2>
#
# 													<p>
# 															1913 5th Ave N
# 															<br />Birmingham, AL 35203
# 																	<br />
# (205) 324-6161													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/montgomery-promenade">Montgomery-Promenade</a>
# 													</h2>
#
# 													<p>
# 															2682 Eastern Blvd
# 															<br />Montgomery, AL 36117
# 																	<br />
# (334) 271-0104													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/muscle-shoals">Muscle Shoals</a>
# 													</h2>
#
# 													<p>
# 															511 Avalon Ave
# 															<br />Muscle Shoals, AL 35661
# 																	<br />
# (256) 386-5442													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/northport">Northport</a>
# 													</h2>
#
# 													<p>
# 															1620 McFarland Blvd
# 															<br />Northport, AL 35476
# 																	<br />
# (205) 330-1110													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/oak-mountain">Oak Mountain</a>
# 													</h2>
#
# 													<p>
# 															320 Cahaba Valley Rd
# 															<br />Pelham, AL 35124
# 																	<br />
# (205) 403-3223													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/oxford">Oxford</a>
# 													</h2>
#
# 													<p>
# 															201 Oxford Exchange Blvd
# 															<br />Oxford, AL 36203
# 																	<br />
# (256) 835-6009													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/oxford-mall">Oxford Mall</a>
# 													</h2>
#
# 													<p>
# 															700 Quintard Dr Ste FC8
# 															<br />Oxford, AL 36203
# 																	<br />
# (256) 835-1887													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/parkway-east">Parkway East</a>
# 													</h2>
#
# 													<p>
# 															9345 Parkway E
# 															<br />Birmingham, AL 35215
# 																	<br />
# (205) 836-0003													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/parkway-place">Parkway Place</a>
# 													</h2>
#
# 													<p>
# 															2801 Memorial Pkwy SW Ste 70
# 															<br />Huntsville, AL 35801
# 																	<br />
# (256) 533-9206													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/patton-creek">Patton Creek</a>
# 													</h2>
#
# 													<p>
# 															3020 John Hawkins Pkwy
# 															<br />Hoover, AL 35244
# 																	<br />
# (205) 987-7568													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/pell-city">Pell City</a>
# 													</h2>
#
# 													<p>
# 															1653 Martin St N
# 															<br />Pell City, AL 35125
# 																	<br />
# (205) 525-0539													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/phenix-city">Phenix City</a>
# 													</h2>
#
# 													<p>
# 															3711 U S Hwy 280
# 															<br />Phenix City, AL 36867
# 																	<br />
# (334) 214-5599													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/prattville">Prattville</a>
# 													</h2>
#
# 													<p>
# 															1967 Cobbs Ford Rd
# 															<br />Prattville, AL 36066
# 																	<br />
# (334) 365-8222													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/riverchase-galleria">Riverchase Galleria</a>
# 													</h2>
#
# 													<p>
# 															2000 Riverchase Galleria Ste 158B
# 															<br />Hoover, AL 35244
# 																	<br />
# (205) 987-2244													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/ross-clark-circle">Ross Clark Circle</a>
# 													</h2>
#
# 													<p>
# 															3418 Ross Clark Cir
# 															<br />Dothan, AL 36303
# 																	<br />
# (334) 712-4849													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/rsa-battlehouse">RSA Battlehouse</a>
# 													</h2>
#
# 													<p>
# 															12 N Royal St
# 															<br />Mobile, AL 36602
# 																	<br />
# (251) 434-9768													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/rsa-regions-tower">RSA Regions Tower</a>
# 													</h2>
#
# 													<p>
# 															201 Monroe St
# 																	<br />
# Suite 162															<br />Montgomery, AL 36104
# 																	<br />
# (334) 293-4773													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/samford-university">Samford University</a>
# 													</h2>
#
# 													<p>
# 															800 Lakeshore Dr
# 															<br />Birmingham, AL 35229
# 																	<br />
# (205) 726-2637													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/schillinger-road">Schillinger Road</a>
# 													</h2>
#
# 													<p>
# 															435 Schillinger Rd S
# 															<br />Mobile, AL 36695
# 																	<br />
# (251) 639-1163													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/south-memorial-parkway">South Memorial Parkway</a>
# 													</h2>
#
# 													<p>
# 															11820 Memorial Pkwy SW
# 															<br />Huntsville, AL 35803
# 																	<br />
# (256) 650-7014													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/southeast-decatur">Southeast Decatur</a>
# 													</h2>
#
# 													<p>
# 															2502 Highway 31 S
# 															<br />Decatur, AL 35603
# 																	<br />
# (256) 822-1014													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/southwest-decatur">Southwest Decatur</a>
# 													</h2>
#
# 													<p>
# 															1809 Beltline Rd SW
# 															<br />Decatur, AL 35601
# 																	<br />
# (256) 355-3035													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/spanish-fort">Spanish Fort</a>
# 													</h2>
#
# 													<p>
# 															30500 SR 181 Suite B
# 															<br />Spanish Fort, AL 36527
# 																	<br />
# (251) 621-3020													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/sylacauga-al">Sylacauga [AL]</a>
# 													</h2>
#
# 													<p>
# 															75 MCS Blvd
# 															<br />Sylacauga, AL 35150
# 																	<br />
# (256) 245-0096													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/the-grove">The Grove</a>
# 													</h2>
#
# 													<p>
# 															5658 Grove Blvd
# 															<br />Hoover, AL 35226
# 																	<br />
# (205) 989-1701													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/tigertown">TigerTown</a>
# 													</h2>
#
# 													<p>
# 															2052 Tiger Town Pkwy
# 															<br />Opelika, AL 36801
# 																	<br />
# (334) 741-7112													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/troy-al">Troy (AL)</a>
# 													</h2>
#
# 													<p>
# 															1121 Highway 231 S
# 															<br />Troy, AL 36081
# 																	<br />
# (334) 566-0505													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/troy-university">Troy University</a>
# 													</h2>
#
# 													<p>
# 															214 Adams Ctr
# 															<br />Troy, AL 36082
# 																	<br />
# (334) 670-5858													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/trussville-al">Trussville (AL)</a>
# 													</h2>
#
# 													<p>
# 															5886 Trussville Crossings Pkwy
# 															<br />Birmingham, AL 35235
# 																	<br />
# (205) 661-0544													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/tuscaloosa-drive-thru-only">Tuscaloosa Drive-Thru Only</a>
# 													</h2>
#
# 													<p>
# 															2014 McFarland Blvd E
# 															<br />Tuscaloosa, AL 35404
# 																	<br />
# (205) 752-9999													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/tuscaloosa-south">Tuscaloosa South</a>
# 													</h2>
#
# 													<p>
# 															4900 Old Greensboro Rd
# 															<br />Tuscaloosa, AL 35405
# 																	<br />
# (205) 247-9980													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/tuskegee-university">Tuskegee University</a>
# 													</h2>
#
# 													<p>
# 															1200 W Montgomery Rd
# 															<br />Tuskegee Institute, AL 36088
# 													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/university-drive">University Drive</a>
# 													</h2>
#
# 													<p>
# 															4733 University Dr NW
# 															<br />Huntsville, AL 35816
# 																	<br />
# (256) 837-1315													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/university-mall-al">University Mall (AL)</a>
# 													</h2>
#
# 													<p>
# 															1701 McFarland Blvd E Ste 190
# 															<br />Tuscaloosa, AL 35404
# 																	<br />
# (205) 553-9195													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/university-of-alabama">University of Alabama</a>
# 													</h2>
#
# 													<p>
# 															Bama Dining Services
# 																	<br />
# Ferguson Center															<br />Tuscaloosa, AL 35487
# 																	<br />
# (205) 348-6816													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/university-of-alabama-huntsville">University of Alabama - Huntsville</a>
# 													</h2>
#
# 													<p>
# 															507 John Wright Dr
# 															<br />Huntsville, AL 35805
# 																	<br />
# (256) 824-5124													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/university-of-alabama-birmingham">University of Alabama Birmingham</a>
# 													</h2>
#
# 													<p>
# 															1000 14th Ave S
# 															<br />Birmingham, AL 35205
# 													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/university-of-alabama-birmingham-hospital">University of Alabama Birmingham Hospital</a>
# 													</h2>
#
# 													<p>
# 															625 19th St S
# 																	<br />
# Jefferson Tower															<br />Birmingham, AL 35233
# 																	<br />
# (205) 502-7005													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/university-of-alabama-lloyd-hall">University of Alabama-Lloyd Hall</a>
# 													</h2>
#
# 													<p>
# 															503 6th Ave
# 																	<br />
# Lloyd Hall															<br />Tuscaloosa, AL 35404
# 																	<br />
# (205) 348-6429													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/university-of-north-alabama">University of North Alabama</a>
# 													</h2>
#
# 													<p>
# 															1 Harrison Plz
# 																	<br />
# Student Commons Building															<br />Florence, AL 35632
# 																	<br />
# (256) 765-5667													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/university-of-south-alabama">University of South Alabama</a>
# 													</h2>
#
# 													<p>
# 															350 Campus Dr
# 																	<br />
# Student Center															<br />Mobile, AL 36608
# 																	<br />
# (251) 460-6296													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/vestavia-hills">Vestavia Hills</a>
# 													</h2>
#
# 													<p>
# 															513 Montgomery Hwy
# 															<br />Vestavia Hills, AL 35216
# 																	<br />
# (205) 824-3540													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/whitesburg-drive">Whitesburg Drive</a>
# 													</h2>
#
# 													<p>
# 															4751 Whitesburg Dr SE
# 															<br />Huntsville, AL 35802
# 																	<br />
# (256) 880-4080													</p>
# 											</div>
# 											<div class="location">
# 													<h2>
#
# 															<a href="/locations/al/wildwood-centre">Wildwood Centre</a>
# 													</h2>
#
# 													<p>
# 															211 Lakeshore Pkwy
# 															<br />Homewood, AL 35209
# 																	<br />
# (205) 945-6062													</p>
# 											</div>
# 						</div>
#     </article>
#
#
# 	<div class="footer">
# 		<footer>
# 	<div class="lrg-app-banner">
# 		<div id="CFAOneBanner" class="wrapper account-offers">
# 			<img src="/-/media/images/cfacom/cfa-one/cfa_one_red_pms.ashx?h=99&amp;w=316&amp;la=en&amp;hash=C85A056E5C62AA3053CD497DA971E577" alt="Chick-fil-A One" />
# 			<h2 class="tagline">
# 				Join Chick-fil-A One<sup>&reg;</sup>. Earn points with every qualifying purchase. Redeem available rewards of your choice.
# 			</h2>
#
# 			<p class="disclaimer-txt">
# 				<span>The <span class="nowrap">Chick-fil-A</span>&nbsp;App is not presently accepted at <span class="nowrap">Chick-fil-A</span> Express&trade; and <span class="nowrap">Chick-fil-A</span> licensed locations such as those in airports and college campuses. These locations are operated by professional third-party food contractors and their operating systems do not currently offer guests the ability to earn points or redeem rewards through the <span class="nowrap">Chick-fil-A App.</span></span>
# 			</p>
#
# 			<div class="app-stores">
# 				<a href="https://itunes.apple.com/us/app/chick-fil-a/id488818252" class="apple cfa-one-app-goal" rel="noopener noreferrer" target="_blank" title="Download on the App Store" >Download on the App Store</a>
# 				<a href="https://play.google.com/store/apps/details?id=com.chickfila.cfaflagship" class="google cfa-one-app-goal" rel="noopener noreferrer" target="_blank" >Get it on Google Play</a>
# 			</div>
#
# 			<a href="https://www.chick-fil-a.com/One" class="btn--vis" title="Learn more about the Chick-fil-A One program" >Learn more</a>
#
# 			<div class="signin-wrapper">
# 				<p>Already have an account? </p>
#
# <form action="/identity/externallogin?authenticationType=Crn&amp;ReturnUrl=%2fidentity%2fexternallogincallback%3fReturnUrl%3d%252f%26sc_site%3dCFACOM%26authenticationSource%3dDefault&amp;sc_site=CFACOM&amp;signup_redirect_uri=%2f" method="post">					<button type="submit">
# 						Sign-in
# 					</button>
# </form>			</div>
# 		</div>
#
# 		<div class="app-banner-image">
# 			<img src="https://d1fd34dzzl09j.cloudfront.net/Images/CFACOM/Footer%20Images/footer-burger-phone-desktop-new-3.jpg" alt="CFA One" class="lrg-img">
# 			<img src="https://d1fd34dzzl09j.cloudfront.net/Images/CFACOM/Footer%20Images/footer-burger-phone-mobile-new-3.jpg" alt="CFA One" class="sml-img">
# 		</div>
# 	</div>
#
#
# 			<div class="footer-modules wrapper">
# 				<nav class="footer-nav" aria-label="footer">
# 						<ul aria-label="">
#         <li>
# <a href="/nutrition-allergens" title="Click here to view Chick-fil-A&#39;s Nutrition and Allergens information" >Nutrition &amp; Allergens</a>        </li>
#         <li>
# <a href="/customer-support" >Customer Support</a>        </li>
#         <li>
# <a href="/careers" >Careers</a>        </li>
#         <li>
# <a href="/franchising" >Franchising</a>        </li>
#         <li>
# <a href="https://www.cfaapparel.com/" >Merchandise</a>        </li>
#         <li>
# <a href="https://www.chick-fil-a.com/stories/press-room" >Press Room</a>        </li>
#
#
# 			<li>
# 				<ul>
#         <li>
# <a href="/do-business-with-us" >Do business with us</a>        </li>
#         <li>
# <a href="https://www.chick-fil-a.com/legal#terms_and_conditions" >Terms and Conditions of Use</a>        </li>
#         <li>
# <a href="https://www.chick-fil-a.com/legal#privacy_policy" >Privacy Policy</a>        </li>
#         <li>
# <a href="https://www.chick-fil-a.com/legal#chick-fil-a_cookie_and_interest-based_advertising_policy" >Cookie and Internet-Based Advertising Policy</a>        </li>
#         <li>
# <a href="#ot-sdk-show-settings" class="ot-sdk-show-settings" title="Cookie Preference Center" >Cookie Preference Center</a>        </li>
#         <li>
# <a href="https://www.chick-fil-a.com/legal#accessibility" >Accessibility</a>        </li>
#         <li>
# <a href="/locations/browse" >Locations listing</a>        </li>
#         <li>
# <a href="/legal" >Legal</a>        </li>
#         <li>
# &#169; 2022 CFA Properties, Inc. All rights reserved.        </li>
#
# 				</ul>
# 			</li>
# 	</ul>
#
#
#
# 				</nav><!-- /footer-nav -->
# 				<div class="social">
# 						<ul class="social-icons" aria-label="">
#         <li>
# <a href="https://www.facebook.com/ChickfilA/" class="icon-facebook-over" rel="noopener noreferrer" target="_blank" >                        <span>Facebook</span>
# </a>        </li>
#         <li>
# <a href="https://www.instagram.com/chickfila/" class="icon-instagram-over" rel="noopener noreferrer" target="_blank" >                        <span>Instagram</span>
# </a>        </li>
#         <li>
# <a href="https://twitter.com/ChickfilA" class="icon-twitter-over" rel="noopener noreferrer" target="_blank" >                        <span>Twitter</span>
# </a>        </li>
#         <li>
# <a href="https://www.youtube.com/user/chickfila" class="icon-youtube-over" rel="noopener noreferrer" target="_blank" >                        <span>YouTube</span>
# </a>        </li>
#         <li>
# <a href="https://www.linkedin.com/company/chick-fil-a-corporate/jobs/" class="icon-linkedin-over" rel="noopener noreferrer" target="_blank" >                        <span>LinkedIn</span>
# </a>        </li>
#
#
# 	</ul>
#
#
#
# 				</div><!-- /social-->
# 			</div><!-- /footer-modules -->
# 		</footer>
# 	</div>
#
#
# </div>
#
# 	</div>
# 	<!-- /Page content -->
#
#
# <div class="print-footer">
#     <div class="icon-logo-desktop"></div>
#
# </div><!-- /print-footer -->
#
# <script
# 	src="https://code.jquery.com/jquery-3.4.1.min.js"
# 	integrity="sha256-CSXorXvZcTkaix6Yvo6HppcZGetbYMGWSFlBw8HfCJo="
# 	crossorigin="anonymous"></script>
#
# <script>
# 	window.jQuery || document.write('<script src="https://d2wl1kt18tqdum.cloudfront.net/v2.1.2111-stageb/Assets/Theming/js/lib/jquery.js"><\/script>');
# </script>
#
# <script src="https://d2wl1kt18tqdum.cloudfront.net/v2.1.2111-stageb/Assets/Theming/js/vendor-js.js"></script>
# <script src="https://d2wl1kt18tqdum.cloudfront.net/v2.1.2111-stageb/Assets/Theming/js/CFACom.js"></script>
# <script src="https://d2wl1kt18tqdum.cloudfront.net/v2.1.2111-stageb/Assets/Theming/js/menu-js.js"></script>
#
#
#
#
#
#
# 	<div id="defaultsiteoverlay" class="lightbox mfp-hide"></div>
#
# 	<div class="rt-placeholder hidden"></div>
#
#
#
#
# </body>
# </html>

# %%
import requests
url='https://www.chick-fil-a.com/locations/browse/al'
response = requests.get(url)

from bs4 import BeautifulSoup
soup = BeautifulSoup(response.text, 'html.parser')
print(soup.title)
# Out:
# <title>AL Locations and Information | Chick-fil-A</title>

# %%
from selenium.webdriver import Chrome
driver = Chrome(executable_path='/path/to/driver')

driver.get('https://oxylabs.io/blog')

blog_titles = driver.get_elements_by_css_selector(' h2.blog-card__content-title')
for title in blog_tiles:
    print(title.text)
driver.quit() # closing the browser
# Out:
# C:\Users\PeeCee\AppData\Local\Temp/ipykernel_24208/1319085849.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = Chrome(executable_path='/path/to/driver')
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\selenium\webdriver\common\service.py in start(self)
#      70             cmd.extend(self.command_line_args())
# ---> 71             self.process = subprocess.Popen(cmd, env=self.env,
#      72                                             close_fds=system() != 'Windows',
#
# ~\anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#     950
# --> 951             self._execute_child(args, executable, preexec_fn, close_fds,
#     952                                 pass_fds, cwd, env,
#
# ~\anaconda3\lib\subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session)
#    1419             try:
# -> 1420                 hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1421                                          # no special security
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified
#
# During handling of the above exception, another exception occurred:
#
# WebDriverException                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24208/1319085849.py in <module>
#       1 from selenium.webdriver import Chrome
# ----> 2 driver = Chrome(executable_path='/path/to/driver')
#       3
#       4 driver.get('https://oxylabs.io/blog')
#       5
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\chrome\webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, service, keep_alive)
#      68             service = Service(executable_path, port, service_args, service_log_path)
#      69
# ---> 70         super(WebDriver, self).__init__(DesiredCapabilities.CHROME['browserName'], "goog",
#      71                                         port, options,
#      72                                         service_args, desired_capabilities,
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\chromium\webdriver.py in __init__(self, browser_name, vendor_prefix, port, options, service_args, desired_capabilities, service_log_path, service, keep_alive)
#      87
#      88         self.service = service
# ---> 89         self.service.start()
#      90
#      91         try:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\common\service.py in start(self)
#      79         except OSError as err:
#      80             if err.errno == errno.ENOENT:
# ---> 81                 raise WebDriverException(
#      82                     "'%s' executable needs to be in PATH. %s" % (
#      83                         os.path.basename(self.path), self.start_error_message)
#
# WebDriverException: Message: 'driver' executable needs to be in PATH. Please see https://chromedriver.chromium.org/home

# %%
import requests
 
# Making a GET request
r = requests.get('https://www.geeksforgeeks.org/python-programming-language/')
 
# check status code for response received
# success code - 200
print(r.url)
 
# print content of request
print(r.status_code)
# Out:
# https://www.geeksforgeeks.org/python-programming-language/
# 200

# %%
import requests
from bs4 import BeautifulSoup
 
 
# Making a GET request
r = requests.get('https://www.geeksforgeeks.org/python-programming-language/')
 
# check status code for response received
# success code - 200
print(r)
 
# Parsing the HTML
soup = BeautifulSoup(r.content, 'html.parser')
print(soup.prettify())
# Out:
# <Response [200]>
# <!DOCTYPE html>
# <html lang="en-us" prefix="og: http://ogp.me/ns#">
#  <meta charset="utf-8"/>
#  <meta content="width=device-width,initial-scale=1,maximum-scale=1" name="viewport"/>
#  <link href="https://media.geeksforgeeks.org/wp-content/cdn-uploads/gfg_favicon.png" rel="shortcut icon" type="image/x-icon"/>
#  <meta content="#308D46" name="theme-color"/>
#  <meta content="https://media.geeksforgeeks.org/wp-content/cdn-uploads/gfg_200x200-min.png" name="image" property="og:image"/>
#  <meta content="image/png" property="og:image:type"/>
#  <meta content="200" property="og:image:width"/>
#  <meta content="200" property="og:image:height"/>
#  <script defer="" src="https://apis.google.com/js/platform.js">
#  </script>
#  <script async="" src="//cdnjs.cloudflare.com/ajax/libs/require.js/2.1.14/require.min.js">
#  </script>
#  <title>
#   Python Programming Language - GeeksforGeeks
#  </title>
#  <link href="http://gmpg.org/xfn/11" rel="profile"/>
#  <link href="" rel="pingback"/>
#  <script type="application/ld+json">
#   {
#         "@context" : "http://schema.org",
#         "@type" : "Organization",
#         "name" : "GeeksforGeeks",
#         "url" : "https://www.geeksforgeeks.org/",
#         "logo" : "https://media.geeksforgeeks.org/wp-content/cdn-uploads/20200817185016/gfg_complete_logo_2x-min.png",
#         "description" : "A computer science portal for geeks. It contains well written, well thought and well explained computer science and programming articles, quizzes and practice/competitive programming/company interview Questions.",
#         "founder": [
#             {
#                 "@type" : "Person",
#                 "name" : "Sandeep Jain",
#                 "url" : "https://in.linkedin.com/in/sandeep-jain-b3940815"
#             }
#         ],
#         "sameAs" : [ "https://www.facebook.com/geeksforgeeks.org/",
#             "https://twitter.com/geeksforgeeks",
#             "https://www.linkedin.com/company/1299009",
#             "https://www.youtube.com/geeksforgeeksvideos/"
#         ]
#     }
#  </script>
#  <script>
#   var arrPostCat = new Array();
#         var tIds = "";
#     var domain = 1;
#     var arrPost = new Array();
#     var post_id = "136942";
#     var post_type = "page";
#     var post_slug = window.location.href;
#     var ip = "35.167.56.225";
#     var post_title = "Python Programming Language";
#     var post_status = "publish";
#     var post_date = "2016-02-21 16:24:47";
#     var commentSysUrl = "https://discuss.geeksforgeeks.org/commentEmbedV2.js";
#
#     var link_on_code_run = '<br><br><a href="https://practice.geeksforgeeks.org/explore?page=1&sortBy=submissions&utm_source=practice&utm_medium=IDE&utm_campaign=practice-IDE">Improve your Coding Skills with Practice</a>';
#             var isAdminLoggedIn = 0;
#
#         var postAdApiUrlString = '';
#  </script>
#  <meta content="Python is a widely used, high-level programming language. Geeksforgeeks Python tutorial will help you learn Python with help of high quality examples." name="description"/>
#  <link href="https://www.geeksforgeeks.org/python-programming-language/" rel="canonical"/>
#  <meta content="en_US" property="og:locale"/>
#  <meta content="article" property="og:type"/>
#  <meta content="Python Programming Language - GeeksforGeeks" property="og:title"/>
#  <meta content="Python is a widely used, high-level programming language. Geeksforgeeks Python tutorial will help you learn Python with help of high quality examples." property="og:description"/>
#  <meta content="https://www.geeksforgeeks.org/python-programming-language/" property="og:url"/>
#  <meta content="GeeksforGeeks" property="og:site_name"/>
#  <meta content="https://media.geeksforgeeks.org/wp-content/cdn-uploads/20200711122552/Python-Programming-Language.png" property="og:image"/>
#  <meta content="https://media.geeksforgeeks.org/wp-content/cdn-uploads/20200711122552/Python-Programming-Language.png" property="og:image:secure_url"/>
#  <meta content="1200" property="og:image:width"/>
#  <meta content="400" property="og:image:height"/>
#  <meta content="https://media.geeksforgeeks.org/wp-content/cdn-uploads/20220512163303/Python-Foundation-Course.png" property="og:image"/>
#  <meta content="https://media.geeksforgeeks.org/wp-content/cdn-uploads/20220512163303/Python-Foundation-Course.png" property="og:image:secure_url"/>
#  <meta content="1200" property="og:image:width"/>
#  <meta content="306" property="og:image:height"/>
#  <meta content="Python-Foundation-Course" property="og:image:alt"/>
#  <script type="application/ld+json">
#   {"@context":"https:\/\/schema.org","@type":"Organization","url":"https:\/\/www.geeksforgeeks.org\/","sameAs":[],"@id":"https:\/\/www.geeksforgeeks.org\/#organization","name":"GeeksforGeeks","logo":"http:\/\/www.geeksforgeeks.org\/wp-content\/uploads\/gfg_200X200-1.png"}
#  </script>
#  <link href="//www.geeksforgeeks.org" rel="dns-prefetch"/>
#  <link href="//s.w.org" rel="dns-prefetch"/>
#  <link href="https://www.geeksforgeeks.org/feed/" rel="alternate" title="GeeksforGeeks » Feed" type="application/rss+xml"/>
#  <link href="https://www.geeksforgeeks.org/comments/feed/" rel="alternate" title="GeeksforGeeks » Comments Feed" type="application/rss+xml"/>
#  <script>
#   window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/11\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/11\/svg\/","svgExt":".svg","source":{"concatemoji":"https:\/\/www.geeksforgeeks.org\/wp-includes\/js\/wp-emoji-release.min.js?ver=4.9.8"}};
# 			!function(a,b,c){function d(a,b){var c=String.fromCharCode;l.clearRect(0,0,k.width,k.height),l.fillText(c.apply(this,a),0,0);var d=k.toDataURL();l.clearRect(0,0,k.width,k.height),l.fillText(c.apply(this,b),0,0);var e=k.toDataURL();return d===e}function e(a){var b;if(!l||!l.fillText)return!1;switch(l.textBaseline="top",l.font="600 32px Arial",a){case"flag":return!(b=d([55356,56826,55356,56819],[55356,56826,8203,55356,56819]))&&(b=d([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]),!b);case"emoji":return b=d([55358,56760,9792,65039],[55358,56760,8203,9792,65039]),!b}return!1}function f(a){var c=b.createElement("script");c.src=a,c.defer=c.type="text/javascript",b.getElementsByTagName("head")[0].appendChild(c)}var g,h,i,j,k=b.createElement("canvas"),l=k.getContext&&k.getContext("2d");for(j=Array("flag","emoji"),c.supports={everything:!0,everythingExceptFlag:!0},i=0;i<j.length;i++)c.supports[j[i]]=e(j[i]),c.supports.everything=c.supports.everything&&c.supports[j[i]],"flag"!==j[i]&&(c.supports.everythingExceptFlag=c.supports.everythingExceptFlag&&c.supports[j[i]]);c.supports.everythingExceptFlag=c.supports.everythingExceptFlag&&!c.supports.flag,c.DOMReady=!1,c.readyCallback=function(){c.DOMReady=!0},c.supports.everything||(h=function(){c.readyCallback()},b.addEventListener?(b.addEventListener("DOMContentLoaded",h,!1),a.addEventListener("load",h,!1)):(a.attachEvent("onload",h),b.attachEvent("onreadystatechange",function(){"complete"===b.readyState&&c.readyCallback()})),g=c.source||{},g.concatemoji?f(g.concatemoji):g.wpemoji&&g.twemoji&&(f(g.twemoji),f(g.wpemoji)))}(window,document,window._wpemojiSettings);
#  </script>
#  <style>
#   img.wp-smiley,img.emoji{display:inline!important;border:none!important;box-shadow:none!important;height:1em!important;width:1em!important;margin:0 .07em!important;vertical-align:-.1em!important;background:0 0!important;padding:0!important}
#  </style>
#  <link href="https://www.geeksforgeeks.org/wp-content/themes/iconic-one/css/gfg.min.css?ver=8.90" id="custom-style-css" media="all" rel="stylesheet"/>
#  <script src="https://code.jquery.com/jquery-3.1.1.min.js?ver=3.1.1">
#  </script>
#  <script src="https://code.jquery.com/jquery-migrate-3.0.0.min.js?ver=3.0.0">
#  </script>
#  <script>
#   /* <![CDATA[ */
# var gfgObject = {"authUrl":"https:\/\/auth.geeksforgeeks.org\/","writeApiUrl":"https:\/\/apiwrite.geeksforgeeks.org\/","writeUrl":"https:\/\/write.geeksforgeeks.org\/","utilUrl":"https:\/\/util.geeksforgeeks.org\/","apiUrl":"https:\/\/api.geeksforgeeks.org\/","cfApiUrl":"https:\/\/gfgapi.geeksforgeeks.org\/"};
# /* ]]> */
#  </script>
#  <script async="" src="https://www.geeksforgeeks.org/wp-content/themes/iconic-one/js/gfg.min.js?ver=11.10">
#  </script>
#  <link href="https://www.geeksforgeeks.org/wp-json/" rel="https://api.w.org/"/>
#  <link href="https://www.cdn.geeksforgeeks.org/xmlrpc.php?rsd" rel="edituri" title="RSD" type="application/rsd+xml"/>
#  <link href="https://www.cdn.geeksforgeeks.org/wp-includes/wlwmanifest.xml" rel="wlwmanifest" type="application/wlwmanifest+xml"/>
#  <meta content="WordPress 4.9.8" name="generator"/>
#  <link href="https://www.geeksforgeeks.org/?p=136942" rel="shortlink"/>
#  <link href="https://www.geeksforgeeks.org/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fwww.geeksforgeeks.org%2Fpython-programming-language%2F" rel="alternate" type="application/json+oembed"/>
#  <link href="https://www.geeksforgeeks.org/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fwww.geeksforgeeks.org%2Fpython-programming-language%2F&amp;format=xml" rel="alternate" type="text/xml+oembed"/>
#  <style>
#   #wpadminbar{background:red!important}
#  </style>
#  <style id="custom-background-css">
#   body.custom-background{background-color:#fff}
#  </style>
#  <style id="syntaxhighlighteranchor">
#  </style>
#  <link href="https://www.geeksforgeeks.org/wp-content/uploads/gfg_200X200-100x100.png" rel="icon" sizes="32x32"/>
#  <link href="https://www.geeksforgeeks.org/wp-content/uploads/gfg_200X200.png" rel="icon" sizes="192x192"/>
#  <link href="https://www.geeksforgeeks.org/wp-content/uploads/gfg_200X200.png" rel="apple-touch-icon-precomposed"/>
#  <meta content="https://www.geeksforgeeks.org/wp-content/uploads/gfg_200X200.png" name="msapplication-TileImage"/>
#  <script async="" src="https://www.googletagservices.com/tag/js/gpt.js">
#  </script>
#  <script async="" src="https://www.geeksforgeeks.org/wp-content/themes/iconic-one/js/prebid.js?ver=0.3">
#  </script>
#  <script async="" src="https://cdnads.geeksforgeeks.org/gfg_ads.min.js?ver=0.1">
#  </script>
#  <style>
#   @media(max-width:1043px) and (min-width:992px){.hide-1043992{display:none!important}}
#  </style>
#  <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-DWCCJLKX3X">
#  </script>
#  <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#   gtag('config', 'AW-474915276');
#   gtag('config', 'G-DWCCJLKX3X');
#   gtag('config', 'AW-796001856');
#  </script>
#  <body class="page-template-default page page-id-136942 page-parent custom-background custom-background-white">
#   <script>
#    // Dark mode script
#         const gfgThemeList = Object.freeze({
#             LIGHT: "gfgThemeLight",
#             DARK: "gfgThemeDark"
#         })
#         const getThemeFromCookie = () => {
#             let gfg_def_theme = "";
#             let cookies = document.cookie;
#             let cooks = cookies.split(";");
#
#             for (let i = 0; i < cooks.length; i++) {
#                 let icook = cooks[i].split("=");
#                 if (icook[0].trim() == "gfg_theme") {
#                     gfg_def_theme = icook[1].trim();
#                 }
#             }
#             return gfg_def_theme
#         }
#         const toggleNineDotMenuImages = theme => {
#             jQuery(".nineDot-menu_left .nineDot-menu_item").each((e, element) => {
#                 let item = jQuery(element).find("img")
#                 let imageSrc = item.attr("src")
#                 let [mainImg, extractImage] = /(.*)\.svg/g.exec(imageSrc)
#                 if (!mainImg.includes("%40dark") && theme === gfgThemeList.DARK) {
#                     mainImg = `${extractImage}%40dark.svg`;
#                 }
#                 else if(mainImg.includes("%40dark") && theme === gfgThemeList.LIGHT) {
#                     mainImg = `${extractImage.substr(0, extractImage.length - 7)}.svg`;
#                 }
#                 item.attr("src", mainImg)
#             })
#         }
#
#         var isDarkMode = getThemeFromCookie() == gfgThemeList.DARK ? true : false;
#         document.querySelector("body").setAttribute("data-dark-mode", isDarkMode);
#   </script>
#   <div class="header-main__wrapper">
#    <a class="gfg-stc" href="#main" style="top:0">
#     Skip to content
#    </a>
#    <a aria-label="Logo" class="header-main__logo" href="https://www.geeksforgeeks.org/">
#     <div class="_logo">
#      <svg height="39.026" viewbox="0 0 76.533 39.026" width="76.533" xmlns="http://www.w3.org/2000/svg">
#       <path d="M2380.7 6597.866a12.252 12.252.0 00-.261-1.513l-30.726-.027a12.545 12.545.0 01.908-3.443 12.337 12.337.0 012.739-4.044 12.151 12.151.0 014.018-2.581 12.634 12.634.0 0114.3 3.051l4.852-4.748a18.176 18.176.0 00-6.131-4.331 20.037 20.037.0 00-8.112-1.564 20.25 20.25.0 00-7.671 1.459 19.158 19.158.0 00-6.261 4.07 19.584 19.584.0 00-4.226 6.184 18.7 18.7.0 00-1.487 5.947h-.2a18.674 18.674.0 00-1.489-5.947 19.544 19.544.0 00-4.226-6.184 19.133 19.133.0 00-6.261-4.07 21.354 21.354.0 00-15.783.1 18.2 18.2.0 00-6.131 4.331l4.853 4.748a13.264 13.264.0 0114.3-3.051 12.131 12.131.0 014.017 2.581 12.323 12.323.0 012.74 4.044 12.527 12.527.0 01.908 3.443l-30.726.027a12.256 12.256.0 00-.261 1.513 15 15 0 00-.1 1.773 20.713 20.713.0 001.1 6.783 15.709 15.709.0 003.443 5.686 17.309 17.309.0 006 4.123 20.587 20.587.0 007.983 1.46 20.226 20.226.0 007.669-1.46 19.086 19.086.0 006.261-4.07 19.506 19.506.0 004.226-6.184 18.163 18.163.0 001.153-3.629h.871a18.27 18.27.0 001.151 3.629 19.545 19.545.0 004.226 6.184 19.111 19.111.0 006.261 4.07 20.241 20.241.0 007.671 1.46 20.572 20.572.0 007.981-1.46 17.282 17.282.0 006-4.123 15.717 15.717.0 003.445-5.686 20.726 20.726.0 001.1-6.783A15.259 15.259.0 002380.7 6597.866zm-46.245 5.608a12.1 12.1.0 01-2.766 4.043 12.467 12.467.0 01-4.043 2.583 14.378 14.378.0 01-9.939.052 11.776 11.776.0 01-3.522-2.218 8.459 8.459.0 01-1.8-2.374 13.476 13.476.0 01-1.173-3.208h23.658A11.487 11.487.0 012334.457 6603.475zm38.236 2.086a8.466 8.466.0 01-1.8 2.374 11.771 11.771.0 01-3.522 2.218 14.378 14.378.0 01-9.939-.052 12.491 12.491.0 01-4.044-2.583 12.088 12.088.0 01-2.765-4.043 11.427 11.427.0 01-.415-1.126h11.92v0h11.739A13.509 13.509.0 012372.692 6605.561z" fill="#2f8d46" transform="translate(-2304.273 -6578.666)">
#       </path>
#      </svg>
#      <svg height="21.281" viewbox="0 0 205.805 21.281" width="155" xmlns="http://www.w3.org/2000/svg">
#       <g data-name="Group 156" id="Group_156" transform="translate(26.144 4.527)">
#        <line data-name="Line 1" fill="#0f2b3c" id="Line_1" x1="1.046">
#        </line>
#       </g>
#       <g data-name="Group 157" id="Group_157" transform="translate(56.695 0.004)">
#        <path d="M1352.9 615.759l-6.714-6.771v6.771h-3.09V594.521h3.09v12.53l6.084-6.056h3.909l-6.988 6.988 7.67 7.782z" data-name="Path 243" fill="#0f2b3c" id="Path_243" transform="translate(-1343.095 -594.521)">
#        </path>
#       </g>
#       <g data-name="Group 158" id="Group_158" transform="translate(113.247 6.427)">
#        <path d="M1504.614 627.712V612.948h3.09v2.558a3.7 3.7.0 011.447-1.91 3.9 3.9.0 012.262-.73 5.447 5.447.0 011.208.112l-.7 3a2.449 2.449.0 00-.842-.082 3.044 3.044.0 00-2.388 1.138 4.676 4.676.0 00-.983 3.16v7.515z" data-name="Path 244" fill="#0f2b3c" id="Path_244" transform="translate(-1504.614 -612.865)">
#        </path>
#       </g>
#       <g data-name="Group 159" id="Group_159" transform="translate(70.943 6.509)">
#        <path d="M1385.943 626.817a5.668 5.668.0 01-2.152-2.683l2.669-1.171a3.743 3.743.0 001.376 1.662 3.657 3.657.0 002.029.572 4.049 4.049.0 001.879-.395 1.266 1.266.0 00.763-1.185 1.367 1.367.0 00-.654-1.2 6.492 6.492.0 00-2.016-.763l-1.662-.409a5.974 5.974.0 01-2.752-1.444 3.452 3.452.0 01-1.089-2.615 3.4 3.4.0 01.722-2.152 4.647 4.647.0 011.948-1.43 6.957 6.957.0 012.67-.5 7.191 7.191.0 013.405.776 4.6 4.6.0 012.125 2.247l-2.615 1.144a2.925 2.925.0 00-2.888-1.608 3.231 3.231.0 00-1.689.409 1.213 1.213.0 00-.681 1.063 1.226 1.226.0 00.518 1.021 4.442 4.442.0 001.526.667l2.043.518a6.573 6.573.0 013.092 1.566 3.5 3.5.0 011.049 2.575 3.72 3.72.0 01-.749 2.3 4.829 4.829.0 01-2.057 1.539 7.44 7.44.0 01-2.887.545A6.781 6.781.0 011385.943 626.817z" data-name="Path 245" fill="#0f2b3c" id="Path_245" transform="translate(-1383.791 -613.101)">
#        </path>
#       </g>
#       <g data-name="Group 160" id="Group_160" transform="translate(96.285 6.525)">
#        <path d="M1463.543 613.146a7.374 7.374.0 107.374 7.374A7.374 7.374.0 001463.543 613.146zm0 11.532a4.228 4.228.0 114.228-4.228A4.228 4.228.0 011463.543 624.678z" data-name="Path 246" fill="#0f2b3c" id="Path_246" transform="translate(-1456.169 -613.146)">
#        </path>
#       </g>
#       <g data-name="Group 161" id="Group_161" transform="translate(23.011 6.524)">
#        <path d="M1261.615 621.145c.017-.232.027-.466.024-.7a7.292 7.292.0 00-.212-1.685 7.375 7.375.0 00-14.537 1.84c0 .236.017.47.04.7a7.263 7.263.0 00.673 2.382 7.374 7.374.0 0013.389-.141l-3.267.034a4.617 4.617.0 01-8.014-2.3zm-11.664-2.266a4.614 4.614.0 018.592-.09z" data-name="Path 247" fill="#0f2b3c" id="Path_247" transform="translate(-1246.891 -613.144)">
#        </path>
#       </g>
#       <g data-name="Group 162" id="Group_162" transform="translate(39.461 6.524)">
#        <path d="M1308.6 621.145c.017-.232.027-.466.025-.7a7.375 7.375.0 10-14.749.155c0 .236.017.47.04.7a7.257 7.257.0 00.672 2.382 7.375 7.375.0 0013.39-.141l-3.268.034a4.616 4.616.0 01-8.014-2.3zm-11.663-2.266a4.614 4.614.0 018.592-.09z" data-name="Path 248" fill="#0f2b3c" id="Path_248" transform="translate(-1293.873 -613.144)">
#        </path>
#       </g>
#       <g data-name="Group 163" id="Group_163" transform="translate(85.044 0.245)">
#        <path d="M1430.636 598.566a2.5 2.5.0 011.8-.549 4.2 4.2.0 011.657.281v-2.752a7.24 7.24.0 00-2.3-.337 4.82 4.82.0 00-3.455 1.278 4.666 4.666.0 00-1.349 3.554v1.417h-2.922v2.752h2.922v12.036h3.091V604.209h4.016v-2.752h-4.016V600.4A2.5 2.5.0 011430.636 598.566z" data-name="Path 249" fill="#0f2b3c" id="Path_249" transform="translate(-1424.063 -595.209)">
#        </path>
#       </g>
#       <g data-name="Group 164" id="Group_164" transform="translate(0)">
#        <path d="M1202.443 605.147a10.637 10.637.0 11-2.72-7.1l-1.983 1.982a7.837 7.837.0 101.656 7.09h-6.883v-2.851h9.895Q1202.443 604.7 1202.443 605.147z" data-name="Path 250" fill="#0f2b3c" id="Path_250" transform="translate(-1181.169 -594.51)">
#        </path>
#       </g>
#       <g data-name="Group 165" id="Group_165" transform="translate(179.788 0.004)">
#        <path d="M1704.467 615.759l-6.714-6.771v6.771h-3.09V594.521h3.09v12.53l6.084-6.056h3.909l-6.988 6.988 7.669 7.782z" data-name="Path 251" fill="#0f2b3c" id="Path_251" transform="translate(-1694.663 -594.521)">
#        </path>
#       </g>
#       <g data-name="Group 166" id="Group_166" transform="translate(194.036 6.509)">
#        <path d="M1737.51 626.817a5.667 5.667.0 01-2.152-2.683l2.67-1.171a3.742 3.742.0 001.375 1.662 3.658 3.658.0 002.03.572 4.051 4.051.0 001.88-.395 1.267 1.267.0 00.763-1.185 1.367 1.367.0 00-.654-1.2 6.492 6.492.0 00-2.016-.763l-1.662-.409a5.974 5.974.0 01-2.751-1.444 3.451 3.451.0 01-1.09-2.615 3.4 3.4.0 01.722-2.152 4.651 4.651.0 011.948-1.43 6.96 6.96.0 012.67-.5 7.191 7.191.0 013.405.776 4.6 4.6.0 012.125 2.247l-2.615 1.144a2.926 2.926.0 00-2.888-1.608 3.232 3.232.0 00-1.689.409 1.214 1.214.0 00-.681 1.063 1.227 1.227.0 00.518 1.021 4.443 4.443.0 001.526.667l2.043.518a6.576 6.576.0 013.092 1.566 3.5 3.5.0 011.049 2.575 3.719 3.719.0 01-.749 2.3 4.833 4.833.0 01-2.057 1.539 7.44 7.44.0 01-2.888.545A6.781 6.781.0 011737.51 626.817z" data-name="Path 252" fill="#0f2b3c" id="Path_252" transform="translate(-1735.358 -613.101)">
#        </path>
#       </g>
#       <g data-name="Group 167" id="Group_167" transform="translate(146.104 6.524)">
#        <path d="M1613.182 621.145c.017-.232.027-.466.025-.7a7.375 7.375.0 10-14.749.155c0 .236.017.47.04.7a7.254 7.254.0 00.673 2.382 7.375 7.375.0 0013.389-.141l-3.268.034a4.616 4.616.0 01-8.014-2.3zm-11.663-2.266a4.615 4.615.0 018.592-.09z" data-name="Path 253" fill="#0f2b3c" id="Path_253" transform="translate(-1598.458 -613.144)">
#        </path>
#       </g>
#       <g data-name="Group 168" id="Group_168" transform="translate(162.554 6.524)">
#        <path d="M1660.165 621.145c.017-.232.027-.466.024-.7a7.375 7.375.0 10-14.749.155c0 .236.017.47.04.7a7.266 7.266.0 00.673 2.382 7.375 7.375.0 0013.389-.141l-3.268.034a4.616 4.616.0 01-8.014-2.3zm-11.663-2.266a4.614 4.614.0 018.592-.09z" data-name="Path 254" fill="#0f2b3c" id="Path_254" transform="translate(-1645.44 -613.144)">
#        </path>
#       </g>
#       <g data-name="Group 169" id="Group_169" transform="translate(123.093)">
#        <path d="M1554.01 605.147a10.636 10.636.0 11-2.72-7.1l-1.983 1.982a7.837 7.837.0 101.656 7.09h-6.884v-2.851h9.895Q1554.01 604.7 1554.01 605.147z" data-name="Path 255" fill="#0f2b3c" id="Path_255" transform="translate(-1532.736 -594.51)">
#        </path>
#       </g>
#      </svg>
#     </div>
#    </a>
#    <div class="header-main__container">
#     <span class="hamburger-menu">
#      <span class="gfg-burger-1">
#      </span>
#      <span class="gfg-burger-2">
#      </span>
#      <span class="gfg-burger-3">
#      </span>
#     </span>
#     <ul class="header-main__list">
#      <li aria-expanded="true" class="header-main__list-item" data-expandable="true" data-parent="false">
#       <span>
#        Courses
#       </span>
#       <i class="gfg-icon gfg-icon_arrow-down gfg-icon_header">
#       </i>
#       <ul class="mega-dropdown">
#        <li aria-expanded="true" class="mega-dropdown__list-item" data-expandable="true" data-parent="true">
#         <span>
#          For Working Professionals
#         </span>
#         <i class="gfg-icon gfg-icon_arrow-right">
#         </i>
#         <ul class="mega-dropdown">
#          <li aria-expanded="true" class="mega-dropdown__list-item" data-expandable="true" data-parent="true">
#           <span>
#            LIVE
#           </span>
#           <i class="gfg-icon gfg-icon_arrow-right">
#           </i>
#           <ul class="mega-dropdown">
#            <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#             <a href="https://practice.geeksforgeeks.org/courses/geeks-classes-live?utm_source=gfg&amp;utm_medium=Submenu&amp;utm_campaign=courses-submenu" target="_self">
#              DSA Live Classes
#             </a>
#             <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#              <a href="https://practice.geeksforgeeks.org/courses/system-design-live?utm_source=gfg&amp;utm_medium=Submenu&amp;utm_campaign=courses-submenu" target="_self">
#               System Design
#              </a>
#              <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#               <a href="https://practice.geeksforgeeks.org/courses/java-backend-live?utm_source=gfg&amp;utm_medium=Submenu&amp;utm_campaign=courses-submenu" target="_self">
#                Java Backend Development
#               </a>
#               <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#                <a href="https://practice.geeksforgeeks.org/courses/full-stack-node?utm_source=gfg&amp;utm_medium=Submenu&amp;utm_campaign=courses-submenu" target="_self">
#                 Full Stack LIVE
#                </a>
#                <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#                 <a href="https://practice.geeksforgeeks.org/courses/category/all?courseType=live&amp;utm_source=gfg&amp;utm_medium=Submenu&amp;utm_campaign=courses-submenu" target="_self">
#                  Explore More
#                 </a>
#                </li>
#               </li>
#              </li>
#             </li>
#            </li>
#           </ul>
#           <li aria-expanded="true" class="mega-dropdown__list-item" data-expandable="true" data-parent="true">
#            <span>
#             Self-Paced
#            </span>
#            <i class="gfg-icon gfg-icon_arrow-right">
#            </i>
#            <ul class="mega-dropdown">
#             <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#              <a href="https://practice.geeksforgeeks.org/courses/dsa-self-paced?utm_source=gfg&amp;utm_medium=Submenu&amp;utm_campaign=courses-submenu" target="_self">
#               DSA- Self Paced
#              </a>
#              <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#               <a href="https://practice.geeksforgeeks.org/courses/SDE-theory?utm_source=gfg&amp;utm_medium=Submenu&amp;utm_campaign=courses-submenu" target="_self">
#                SDE Theory
#               </a>
#               <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#                <a href="https://practice.geeksforgeeks.org/courses/Must-Do-Premium?utm_source=gfg&amp;utm_medium=Submenu&amp;utm_campaign=courses-submenu" target="_self">
#                 Must-Do Coding Questions
#                </a>
#                <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#                 <a href="https://practice.geeksforgeeks.org/courses/category/all?courseType=online&amp;utm_source=gfg&amp;utm_medium=Submenu&amp;utm_campaign=courses-submenu" target="_self">
#                  Explore More
#                 </a>
#                </li>
#               </li>
#              </li>
#             </li>
#            </ul>
#           </li>
#          </li>
#         </ul>
#         <li aria-expanded="true" class="mega-dropdown__list-item" data-expandable="true" data-parent="true">
#          <span>
#           For Students
#          </span>
#          <i class="gfg-icon gfg-icon_arrow-right">
#          </i>
#          <ul class="mega-dropdown">
#           <li aria-expanded="true" class="mega-dropdown__list-item" data-expandable="true" data-parent="true">
#            <span>
#             LIVE
#            </span>
#            <i class="gfg-icon gfg-icon_arrow-right">
#            </i>
#            <ul class="mega-dropdown">
#             <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#              <a href="https://practice.geeksforgeeks.org/courses/competitive-programming-live?utm_source=gfg&amp;utm_medium=Submenu&amp;utm_campaign=courses-submenu" target="_self">
#               Competitive Programming
#              </a>
#              <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#               <a href="https://practice.geeksforgeeks.org/courses/dsa-foundation?utm_source=gfg&amp;utm_medium=Submenu&amp;utm_campaign=courses-submenu" target="_self">
#                Data Structures with C++
#               </a>
#               <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#                <a href="https://practice.geeksforgeeks.org/courses/data-science-live?utm_source=gfg&amp;utm_medium=Submenu&amp;utm_campaign=courses-submenu" target="_self">
#                 Data Science
#                </a>
#                <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#                 <a href="https://practice.geeksforgeeks.org/courses/category/all?courseType=live&amp;utm_source=gfg&amp;utm_medium=Submenu&amp;utm_campaign=courses-submenu" target="_self">
#                  Explore More
#                 </a>
#                </li>
#               </li>
#              </li>
#             </li>
#            </ul>
#            <li aria-expanded="true" class="mega-dropdown__list-item" data-expandable="true" data-parent="true">
#             <span>
#              Self-Paced
#             </span>
#             <i class="gfg-icon gfg-icon_arrow-right">
#             </i>
#             <ul class="mega-dropdown">
#              <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#               <a href="https://practice.geeksforgeeks.org/courses/dsa-self-paced?utm_source=gfg&amp;utm_medium=Submenu&amp;utm_campaign=courses-submenu" target="_self">
#                DSA- Self Paced
#               </a>
#               <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#                <a href="https://practice.geeksforgeeks.org/courses/complete-interview-preparation?utm_source=gfg&amp;utm_medium=Submenu&amp;utm_campaign=courses-submenu" target="_self">
#                 CIP
#                </a>
#                <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#                 <a href="https://www.geeksforgeeks.org/a-freshers-guide-to-programming/" target="_self">
#                  JAVA / Python / C++
#                 </a>
#                 <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#                  <a href="https://practice.geeksforgeeks.org/courses/category/all?courseType=online&amp;utm_source=gfg&amp;utm_medium=Submenu&amp;utm_campaign=courses-submenu" target="_self">
#                   Explore More
#                  </a>
#                 </li>
#                </li>
#               </li>
#              </li>
#             </ul>
#            </li>
#           </li>
#          </ul>
#          <li aria-expanded="true" class="mega-dropdown__list-item" data-expandable="true" data-parent="true">
#           <span>
#            School Courses
#           </span>
#           <i class="gfg-icon gfg-icon_arrow-right">
#           </i>
#           <ul class="mega-dropdown">
#            <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#             <a href="https://practice.geeksforgeeks.org/courses/school-guide-course?utm_source=gfg&amp;utm_medium=submenu&amp;utm_campaign=courses-submenu" target="_self">
#              School Guide
#             </a>
#             <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#              <a href="https://practice.geeksforgeeks.org/courses/python-programming-course?utm_source=gfg&amp;utm_medium=submenu&amp;utm_campaign=courses-submenu" target="_self">
#               Python Programming
#              </a>
#              <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#               <a href="https://practice.geeksforgeeks.org/courses/app-lab?utm_source=gfg&amp;utm_medium=submenu&amp;utm_campaign=courses-submenu" target="_self">
#                Learn To Make Apps
#               </a>
#               <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#                <a href="https://practice.geeksforgeeks.org/courses/category/school?utm_source=gfg&amp;utm_medium=submenu&amp;utm_campaign=courses-submenu" target="_self">
#                 Explore more
#                </a>
#               </li>
#              </li>
#             </li>
#            </li>
#           </ul>
#           <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#            <a class="remove-anchor__decoration" href="https://practice.geeksforgeeks.org/courses?utm_source=gfg&amp;utm_medium=submenu&amp;utm_campaign=courses-submenu" target="_self">
#             All Courses
#            </a>
#           </li>
#          </li>
#         </li>
#        </li>
#       </ul>
#       <li aria-expanded="true" class="header-main__list-item" data-expandable="true" data-parent="true">
#        <span>
#         Tutorials
#        </span>
#        <i class="gfg-icon gfg-icon_arrow-down gfg-icon_header">
#        </i>
#        <ul class="mega-dropdown">
#         <li aria-expanded="true" class="mega-dropdown__list-item" data-expandable="true" data-parent="true">
#          <span>
#           Algorithms
#          </span>
#          <i class="gfg-icon gfg-icon_arrow-right">
#          </i>
#          <ul class="mega-dropdown">
#           <li aria-expanded="true" class="mega-dropdown__list-item" data-expandable="true" data-parent="true">
#            <span>
#             Analysis of Algorithms
#            </span>
#            <i class="gfg-icon gfg-icon_arrow-right">
#            </i>
#            <ul class="mega-dropdown">
#             <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#              <a href="https://www.geeksforgeeks.org/analysis-of-algorithms-set-1-asymptotic-analysis/?ref=ghm" target="_self">
#               Asymptotic Analysis
#              </a>
#              <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#               <a href="https://www.geeksforgeeks.org/analysis-of-algorithms-set-2-asymptotic-analysis/?ref=ghm" target="_self">
#                Worst, Average and Best Cases
#               </a>
#               <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#                <a href="https://www.geeksforgeeks.org/analysis-of-algorithms-set-3asymptotic-notations/?ref=ghm" target="_self">
#                 Asymptotic Notations
#                </a>
#                <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#                 <a href="https://www.geeksforgeeks.org/analysis-of-algorithems-little-o-and-little-omega-notations/?ref=ghm" target="_self">
#                  Little o and little omega notations
#                 </a>
#                 <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#                  <a href="https://www.geeksforgeeks.org/lower-and-upper-bound-theory/?ref=ghm" target="_self">
#                   Lower and Upper Bound Theory
#                  </a>
#                  <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#                   <a href="https://www.geeksforgeeks.org/analysis-of-algorithms-set-4-analysis-of-loops/?ref=ghm" target="_self">
#                    Analysis of Loops
#                   </a>
#                   <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#                    <a href="https://www.geeksforgeeks.org/analysis-algorithm-set-4-master-method-solving-recurrences/?ref=ghm" target="_self">
#                     Solving Recurrences
#                    </a>
#                    <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#                     <a href="https://www.geeksforgeeks.org/analysis-algorithm-set-5-amortized-analysis-introduction/?ref=ghm" target="_self">
#                      Amortized Analysis
#                     </a>
#                     <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#                      <a href="https://www.geeksforgeeks.org/g-fact-86/?ref=ghm" target="_self">
#                       What does 'Space Complexity' mean ?
#                      </a>
#                      <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#                       <a href="https://www.geeksforgeeks.org/pseudo-polynomial-in-algorithms/?ref=ghm" target="_self">
#                        Pseudo-polynomial Algorithms
#                       </a>
#                       <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#                        <a href="https://www.geeksforgeeks.org/polynomial-time-approximation-scheme/?ref=ghm" target="_self">
#                         Polynomial Time Approximation Scheme
#                        </a>
#                        <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#                         <a href="https://www.geeksforgeeks.org/a-time-complexity-question/?ref=ghm" target="_self">
#                          A Time Complexity Question
#                         </a>
#                        </li>
#                       </li>
#                      </li>
#                     </li>
#                    </li>
#                   </li>
#                  </li>
#                 </li>
#                </li>
#               </li>
#              </li>
#             </li>
#            </ul>
#            <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#             <a href="https://www.geeksforgeeks.org/searching-algorithms/?ref=ghm" target="_self">
#              Searching Algorithms
#             </a>
#             <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#              <a href="https://www.geeksforgeeks.org/sorting-algorithms/?ref=ghm" target="_self">
#               Sorting Algorithms
#              </a>
#              <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#               <a href="https://www.geeksforgeeks.org/graph-data-structure-and-algorithms/?ref=ghm" target="_self">
#                Graph Algorithms
#               </a>
#               <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#                <a href="https://www.geeksforgeeks.org/algorithms-gq/pattern-searching/?ref=ghm" target="_self">
#                 Pattern Searching
#                </a>
#                <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#                 <a href="https://www.geeksforgeeks.org/geometric-algorithms/?ref=ghm" target="_self">
#                  Geometric Algorithms
#                 </a>
#                 <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#                  <a href="https://www.geeksforgeeks.org/mathematical-algorithms/?ref=ghm" target="_self">
#                   Mathematical
#                  </a>
#                  <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#                   <a href="https://www.geeksforgeeks.org/bitwise-algorithms/?ref=ghm" target="_self">
#                    Bitwise Algorithms
#                   </a>
#                   <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#                    <a href="https://www.geeksforgeeks.org/randomized-algorithms/?ref=ghm" target="_self">
#                     Randomized Algorithms
#                    </a>
#                    <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#                     <a href="https://www.geeksforgeeks.org/greedy-algorithms/?ref=ghm" target="_self">
#                      Greedy Algorithms
#                     </a>
#                     <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#                      <a href="https://www.geeksforgeeks.org/dynamic-programming/?ref=ghm" target="_self">
#                       Dynamic Programming
#                      </a>
#                      <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#                       <a href="https://www.geeksforgeeks.org/divide-and-conquer/?ref=ghm" target="_self">
#                        Divide and Conquer
#                       </a>
#                       <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#                        <a href="https://www.geeksforgeeks.org/backtracking-algorithms/?ref=ghm" target="_self">
#                         Backtracking
#                        </a>
#                        <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#                         <a href="https://www.geeksforgeeks.org/branch-and-bound-algorithm/?ref=ghm" target="_self">
#                          Branch and Bound
#                         </a>
#                         <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#                          <a href="https://www.geeksforgeeks.org/fundamentals-of-algorithms/?ref=ghm" target="_self">
#                           All Algorithms
#                          </a>
#                         </li>
#                        </li>
#                       </li>
#                      </li>
#                     </li>
#                    </li>
#                   </li>
#                  </li>
#                 </li>
#                </li>
#               </li>
#              </li>
#             </li>
#            </li>
#           </li>
#          </ul>
#          <li aria-expanded="true" class="mega-dropdown__list-item" data-expandable="true" data-parent="true">
#           <span>
#            Data Structures
#           </span>
#           <i class="gfg-icon gfg-icon_arrow-right">
#           </i>
#           <ul class="mega-dropdown">
#            <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#             <a href="https://www.geeksforgeeks.org/array-data-structure/?ref=ghm" target="_self">
#              Arrays
#             </a>
#             <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#              <a href="https://www.geeksforgeeks.org/data-structures/linked-list/?ref=ghm" target="_self">
#               Linked List
#              </a>
#              <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#               <a href="https://www.geeksforgeeks.org/stack-data-structure/?ref=ghm" target="_self">
#                Stack
#               </a>
#               <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#                <a href="https://www.geeksforgeeks.org/queue-data-structure/?ref=ghm" target="_self">
#                 Queue
#                </a>
#                <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#                 <a href="https://www.geeksforgeeks.org/binary-tree-data-structure/?ref=ghm" target="_self">
#                  Binary Tree
#                 </a>
#                 <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#                  <a href="https://www.geeksforgeeks.org/binary-search-tree-data-structure/?ref=ghm" target="_self">
#                   Binary Search Tree
#                  </a>
#                  <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#                   <a href="https://www.geeksforgeeks.org/heap-data-structure/?ref=ghm" target="_self">
#                    Heap
#                   </a>
#                   <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#                    <a href="https://www.geeksforgeeks.org/hashing-data-structure/?ref=ghm" target="_self">
#                     Hashing
#                    </a>
#                    <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#                     <a href="https://www.geeksforgeeks.org/graph-data-structure-and-algorithms/?ref=ghm" target="_self">
#                      Graph
#                     </a>
#                     <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#                      <a href="https://www.geeksforgeeks.org/advanced-data-structures/?ref=ghm" target="_self">
#                       Advanced Data Structure
#                      </a>
#                      <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#                       <a href="https://www.geeksforgeeks.org/matrix/?ref=ghm" target="_self">
#                        Matrix
#                       </a>
#                       <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#                        <a href="https://www.geeksforgeeks.org/string-data-structure/?ref=ghm" target="_self">
#                         Strings
#                        </a>
#                        <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#                         <a href="https://www.geeksforgeeks.org/data-structures/?ref=ghm" target="_self">
#                          All Data Structures
#                         </a>
#                        </li>
#                       </li>
#                      </li>
#                     </li>
#                    </li>
#                   </li>
#                  </li>
#                 </li>
#                </li>
#               </li>
#              </li>
#             </li>
#            </li>
#           </ul>
#           <li aria-expanded="true" class="mega-dropdown__list-item" data-expandable="true" data-parent="true">
#            <span>
#             Interview Corner
#            </span>
#            <i class="gfg-icon gfg-icon_arrow-right">
#            </i>
#            <ul class="mega-dropdown">
#             <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#              <a href="https://www.geeksforgeeks.org/company-preparation/?ref=ghm" target="_self">
#               Company Preparation
#              </a>
#              <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#               <a href="https://www.geeksforgeeks.org/interview-preparation-for-software-developer/?ref=ghm" target="_self">
#                Top Topics
#               </a>
#               <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#                <a href="https://practice.geeksforgeeks.org/company-tags/?ref=ghm" target="_self">
#                 Practice Company Questions
#                </a>
#                <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#                 <a href="https://www.geeksforgeeks.org/company-interview-corner/?ref=ghm" target="_self">
#                  Interview Experiences
#                 </a>
#                 <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#                  <a href="https://www.geeksforgeeks.org/experienced-interview-experiences-company-wise/?ref=ghm" target="_self">
#                   Experienced Interviews
#                  </a>
#                  <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#                   <a href="https://www.geeksforgeeks.org/internship-interview-experiences-company-wise/?ref=ghm" target="_self">
#                    Internship Interviews
#                   </a>
#                   <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#                    <a href="https://www.geeksforgeeks.org/competitive-programming-a-complete-guide/?ref=ghm" target="_self">
#                     Competititve Programming
#                    </a>
#                    <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#                     <a href="https://www.geeksforgeeks.org/software-design-patterns/?ref=ghm" target="_self">
#                      Design Patterns
#                     </a>
#                     <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#                      <a href="https://www.geeksforgeeks.org/system-design-tutorial/" target="_self">
#                       System Design Tutorial
#                      </a>
#                      <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
# ...
#           </path>
#          </g>
#          <g data-name="Group 160" id="Group_160" transform="translate(96.285 6.525)">
#           <path d="M1463.543 613.146a7.374 7.374.0 107.374 7.374A7.374 7.374.0 001463.543 613.146zm0 11.532a4.228 4.228.0 114.228-4.228A4.228 4.228.0 011463.543 624.678z" data-name="Path 246" fill="#0f2b3c" id="Path_246" transform="translate(-1456.169 -613.146)">
#           </path>
#          </g>
#          <g data-name="Group 161" id="Group_161" transform="translate(23.011 6.524)">
#           <path d="M1261.615 621.145c.017-.232.027-.466.024-.7a7.292 7.292.0 00-.212-1.685 7.375 7.375.0 00-14.537 1.84c0 .236.017.47.04.7a7.263 7.263.0 00.673 2.382 7.374 7.374.0 0013.389-.141l-3.267.034a4.617 4.617.0 01-8.014-2.3zm-11.664-2.266a4.614 4.614.0 018.592-.09z" data-name="Path 247" fill="#0f2b3c" id="Path_247" transform="translate(-1246.891 -613.144)">
#           </path>
#          </g>
#          <g data-name="Group 162" id="Group_162" transform="translate(39.461 6.524)">
#           <path d="M1308.6 621.145c.017-.232.027-.466.025-.7a7.375 7.375.0 10-14.749.155c0 .236.017.47.04.7a7.257 7.257.0 00.672 2.382 7.375 7.375.0 0013.39-.141l-3.268.034a4.616 4.616.0 01-8.014-2.3zm-11.663-2.266a4.614 4.614.0 018.592-.09z" data-name="Path 248" fill="#0f2b3c" id="Path_248" transform="translate(-1293.873 -613.144)">
#           </path>
#          </g>
#          <g data-name="Group 163" id="Group_163" transform="translate(85.044 0.245)">
#           <path d="M1430.636 598.566a2.5 2.5.0 011.8-.549 4.2 4.2.0 011.657.281v-2.752a7.24 7.24.0 00-2.3-.337 4.82 4.82.0 00-3.455 1.278 4.666 4.666.0 00-1.349 3.554v1.417h-2.922v2.752h2.922v12.036h3.091V604.209h4.016v-2.752h-4.016V600.4A2.5 2.5.0 011430.636 598.566z" data-name="Path 249" fill="#0f2b3c" id="Path_249" transform="translate(-1424.063 -595.209)">
#           </path>
#          </g>
#          <g data-name="Group 164" id="Group_164" transform="translate(0)">
#           <path d="M1202.443 605.147a10.637 10.637.0 11-2.72-7.1l-1.983 1.982a7.837 7.837.0 101.656 7.09h-6.883v-2.851h9.895Q1202.443 604.7 1202.443 605.147z" data-name="Path 250" fill="#0f2b3c" id="Path_250" transform="translate(-1181.169 -594.51)">
#           </path>
#          </g>
#          <g data-name="Group 165" id="Group_165" transform="translate(179.788 0.004)">
#           <path d="M1704.467 615.759l-6.714-6.771v6.771h-3.09V594.521h3.09v12.53l6.084-6.056h3.909l-6.988 6.988 7.669 7.782z" data-name="Path 251" fill="#0f2b3c" id="Path_251" transform="translate(-1694.663 -594.521)">
#           </path>
#          </g>
#          <g data-name="Group 166" id="Group_166" transform="translate(194.036 6.509)">
#           <path d="M1737.51 626.817a5.667 5.667.0 01-2.152-2.683l2.67-1.171a3.742 3.742.0 001.375 1.662 3.658 3.658.0 002.03.572 4.051 4.051.0 001.88-.395 1.267 1.267.0 00.763-1.185 1.367 1.367.0 00-.654-1.2 6.492 6.492.0 00-2.016-.763l-1.662-.409a5.974 5.974.0 01-2.751-1.444 3.451 3.451.0 01-1.09-2.615 3.4 3.4.0 01.722-2.152 4.651 4.651.0 011.948-1.43 6.96 6.96.0 012.67-.5 7.191 7.191.0 013.405.776 4.6 4.6.0 012.125 2.247l-2.615 1.144a2.926 2.926.0 00-2.888-1.608 3.232 3.232.0 00-1.689.409 1.214 1.214.0 00-.681 1.063 1.227 1.227.0 00.518 1.021 4.443 4.443.0 001.526.667l2.043.518a6.576 6.576.0 013.092 1.566 3.5 3.5.0 011.049 2.575 3.719 3.719.0 01-.749 2.3 4.833 4.833.0 01-2.057 1.539 7.44 7.44.0 01-2.888.545A6.781 6.781.0 011737.51 626.817z" data-name="Path 252" fill="#0f2b3c" id="Path_252" transform="translate(-1735.358 -613.101)">
#           </path>
#          </g>
#          <g data-name="Group 167" id="Group_167" transform="translate(146.104 6.524)">
#           <path d="M1613.182 621.145c.017-.232.027-.466.025-.7a7.375 7.375.0 10-14.749.155c0 .236.017.47.04.7a7.254 7.254.0 00.673 2.382 7.375 7.375.0 0013.389-.141l-3.268.034a4.616 4.616.0 01-8.014-2.3zm-11.663-2.266a4.615 4.615.0 018.592-.09z" data-name="Path 253" fill="#0f2b3c" id="Path_253" transform="translate(-1598.458 -613.144)">
#           </path>
#          </g>
#          <g data-name="Group 168" id="Group_168" transform="translate(162.554 6.524)">
#           <path d="M1660.165 621.145c.017-.232.027-.466.024-.7a7.375 7.375.0 10-14.749.155c0 .236.017.47.04.7a7.266 7.266.0 00.673 2.382 7.375 7.375.0 0013.389-.141l-3.268.034a4.616 4.616.0 01-8.014-2.3zm-11.663-2.266a4.614 4.614.0 018.592-.09z" data-name="Path 254" fill="#0f2b3c" id="Path_254" transform="translate(-1645.44 -613.144)">
#           </path>
#          </g>
#          <g data-name="Group 169" id="Group_169" transform="translate(123.093)">
#           <path d="M1554.01 605.147a10.636 10.636.0 11-2.72-7.1l-1.983 1.982a7.837 7.837.0 101.656 7.09h-6.884v-2.851h9.895Q1554.01 604.7 1554.01 605.147z" data-name="Path 255" fill="#0f2b3c" id="Path_255" transform="translate(-1532.736 -594.51)">
#           </path>
#          </g>
#         </g>
#        </g>
#       </svg>
#      </a>
#      <div class="footer-wrapper_branding-address">
#       <i class="gfg-icon gfg-icon_pin">
#       </i>
#       <span>
#        5th Floor, A-118,
#        <br/>
#        Sector-136, Noida, Uttar Pradesh - 201305
#       </span>
#      </div>
#      <div class="footer-wrapper_branding-email">
#       <i class="gfg-icon gfg-icon_mail">
#       </i>
#       <a href="mailto:feedback@geeksforgeeks.org">
#        feedback@geeksforgeeks.org
#       </a>
#      </div>
#      <div class="footer-wrapper_branding-social">
#       <a aria-label="GeeksforGeeks Facebook" href="https://www.facebook.com/geeksforgeeks.org/" rel="noopener noreferrer" target="_blank">
#        <div class="facebook">
#        </div>
#       </a>
#       <a aria-label="GeeksforGeeks Instagram" href="https://www.instagram.com/geeks_for_geeks/" rel="noopener noreferrer" target="_blank">
#        <div class="instagram">
#        </div>
#       </a>
#       <a aria-label="GeeksforGeeks LinkedIn" href="https://in.linkedin.com/company/geeksforgeeks" rel="noopener noreferrer" target="_blank">
#        <div class="linkedin">
#        </div>
#       </a>
#       <a aria-label="GeeksforGeeks Twitter" href="https://twitter.com/geeksforgeeks" rel="noopener noreferrer" target="_blank">
#        <div class="twitter">
#        </div>
#       </a>
#       <a aria-label="GeeksforGeeks YouTube" href="https://www.youtube.com/geeksforgeeksvideos" rel="noopener noreferrer" target="_blank">
#        <div class="youtube">
#        </div>
#       </a>
#       <a aria-label="GeeksforGeeks App" href="https://play.google.com/store/apps/details?id=free.programming.programming" rel="noopener noreferrer" target="_blank">
#        <div class="android">
#        </div>
#       </a>
#      </div>
#     </div>
#     <div class="footer-wrapper_links">
#      <ul class="footer-wrapper_links-list">
#       <li>
#        Company
#        <li>
#         <a href="https://www.geeksforgeeks.org/about/?ref=footer">
#          About Us
#         </a>
#         <li>
#          <a href="https://www.geeksforgeeks.org/careers/?ref=footer">
#           Careers
#          </a>
#          <li>
#           <a href="https://www.geeksforgeeks.org/press-release/?ref=footer">
#            In Media
#           </a>
#           <li>
#            <a href="https://www.geeksforgeeks.org/about/contact-us/?ref=footer">
#             Contact Us
#            </a>
#            <li>
#             <a href="https://www.geeksforgeeks.org/privacy-policy/?ref=footer">
#              Privacy Policy
#             </a>
#             <li>
#              <a href="https://www.geeksforgeeks.org/copyright-information/?ref=footer">
#               Copyright Policy
#              </a>
#             </li>
#            </li>
#           </li>
#          </li>
#         </li>
#        </li>
#       </li>
#      </ul>
#      <ul class="footer-wrapper_links-list">
#       <li>
#        Learn
#        <li>
#         <a href="https://www.geeksforgeeks.org/fundamentals-of-algorithms/?ref=footer">
#          Algorithms
#         </a>
#         <li>
#          <a href="https://www.geeksforgeeks.org/data-structures/?ref=footer">
#           Data Structures
#          </a>
#          <li>
#           <a href="https://www.geeksforgeeks.org/gfg-sde-sheet-a-complete-guide-for-sde-preparation/?ref=footer">
#            SDE Cheat Sheet
#           </a>
#           <li>
#            <a href="https://www.geeksforgeeks.org/machine-learning/?ref=footer">
#             Machine learning
#            </a>
#            <li>
#             <a href="https://www.geeksforgeeks.org/articles-on-computer-science-subjects-gq/?ref=footer">
#              CS Subjects
#             </a>
#             <li>
#              <a href="https://www.geeksforgeeks.org/videos/?ref=footer">
#               Video Tutorials
#              </a>
#             </li>
#            </li>
#           </li>
#          </li>
#         </li>
#        </li>
#       </li>
#      </ul>
#      <ul class="footer-wrapper_links-list">
#       <li>
#        <a class="link-head" href="https://news.geeksforgeeks.org/?ref=footer">
#         News
#        </a>
#        <li>
#         <a href="https://news.geeksforgeeks.org/top?ref=footer">
#          Top News
#         </a>
#         <li>
#          <a href="https://news.geeksforgeeks.org/technology?ref=footer">
#           Technology
#          </a>
#          <li>
#           <a href="https://news.geeksforgeeks.org/work-career?ref=footer">
#            Work &amp; Career
#           </a>
#           <li>
#            <a href="https://news.geeksforgeeks.org/business?ref=footer">
#             Business
#            </a>
#            <li>
#             <a href="https://news.geeksforgeeks.org/finance?ref=footer">
#              Finance
#             </a>
#             <li>
#              <a href="https://news.geeksforgeeks.org/lifestyle?ref=footer">
#               Lifestyle
#              </a>
#             </li>
#            </li>
#           </li>
#          </li>
#         </li>
#        </li>
#       </li>
#      </ul>
#      <ul class="footer-wrapper_links-list">
#       <li>
#        Languages
#        <li>
#         <a href="https://www.geeksforgeeks.org/python-programming-language/?ref=footer">
#          Python
#         </a>
#         <li>
#          <a href="https://www.geeksforgeeks.org/java/?ref=footer">
#           Java
#          </a>
#          <li>
#           <a href="https://www.geeksforgeeks.org/c-plus-plus/?ref=footer">
#            CPP
#           </a>
#           <li>
#            <a href="https://www.geeksforgeeks.org/golang/?ref=footer">
#             Golang
#            </a>
#            <li>
#             <a href="https://www.geeksforgeeks.org/csharp-programming-language/?ref=footer">
#              C#
#             </a>
#             <li>
#              <a href="https://www.geeksforgeeks.org/sql-tutorial/?ref=footer">
#               SQL
#              </a>
#             </li>
#            </li>
#           </li>
#          </li>
#         </li>
#        </li>
#       </li>
#      </ul>
#      <ul class="footer-wrapper_links-list">
#       <li>
#        Web Development
#        <li>
#         <a href="https://www.geeksforgeeks.org/web-development/?ref=footer">
#          Web Tutorials
#         </a>
#         <li>
#          <a href="https://www.geeksforgeeks.org/django-tutorial/?ref=footer">
#           Django Tutorial
#          </a>
#          <li>
#           <a href="https://www.geeksforgeeks.org/html-tutorials/?ref=footer">
#            HTML
#           </a>
#           <li>
#            <a href="https://www.geeksforgeeks.org/css-tutorials/?ref=footer">
#             CSS
#            </a>
#            <li>
#             <a href="https://www.geeksforgeeks.org/javascript-tutorial/?ref=footer">
#              JavaScript
#             </a>
#             <li>
#              <a href="https://www.geeksforgeeks.org/bootstrap-tutorials/?ref=footer">
#               Bootstrap
#              </a>
#             </li>
#            </li>
#           </li>
#          </li>
#         </li>
#        </li>
#       </li>
#      </ul>
#      <ul class="footer-wrapper_links-list">
#       <li>
#        Contribute
#        <li>
#         <a href="https://www.geeksforgeeks.org/contribute/?ref=footer">
#          Write an Article
#         </a>
#         <li>
#          <a href="https://www.geeksforgeeks.org/how-to-improve-an-article/?ref=footer">
#           Improve an Article
#          </a>
#          <li>
#           <a href="https://write.geeksforgeeks.org/pick-article?ref=footer">
#            Pick Topics to Write
#           </a>
#           <li>
#            <a href="https://www.geeksforgeeks.org/write-interview-experience/?ref=footer">
#             Write Interview Experience
#            </a>
#            <li>
#             <a href="https://www.geeksforgeeks.org/careers/?job_type=1&amp;ref=footer">
#              Internships
#             </a>
#             <li>
#              <a href="https://script.geeksforgeeks.org/on-boarding/youtube?ref=footer">
#               Video Internship
#              </a>
#             </li>
#            </li>
#           </li>
#          </li>
#         </li>
#        </li>
#       </li>
#      </ul>
#     </div>
#    </div>
#    <div class="footer-strip">
#     <div class="copyright">
#      <a href="https://www.geeksforgeeks.org/" rel="noopener noreferrer" target="_blank">
#       @geeksforgeeks
#      </a>
#      <span>
#       ,
#       <a href="https://www.geeksforgeeks.org/copyright-information/">
#        Some rights reserved
#       </a>
#      </span>
#     </div>
#     <div class="social-links">
#     </div>
#    </div>
#   </footer>
#   <div class="darkMode-wrap" data-mode="Switch to Dark Mode">
#    <button data-gfg-action="toggleGFGTheme">
#     <i class="gfg-icon gfg-icon_dark-mode">
#     </i>
#    </button>
#   </div>
#   <script src="https://www.geeksforgeeks.org/wp-includes/js/wp-embed.min.js?ver=4.9.8">
#   </script>
#   <div class="cookie-consent hide-consent">
#    <span class="cookie-text">
#     We use cookies to ensure you have the best browsing experience on our website. By using our site, you
# acknowledge that you have read and understood our
#     <a href="https://www.geeksforgeeks.org/cookie-policy/" target="_blank">
#      <u>
#       Cookie Policy
#      </u>
#     </a>
#     &amp;
#     <a href="https://www.geeksforgeeks.org/privacy-policy/" target="_blank">
#      <u>
#       Privacy Policy
#      </u>
#     </a>
#    </span>
#    <button class="consent-btn">
#     Got It !
#    </button>
#   </div>
#   <div class="lightbox-target">
#    <img alt="Lightbox" id="lightbox-image" src=""/>
#    <span class="lightbox-close">
#    </span>
#   </div>
#   <div class="shell">
#    <div class="shell-container">
#     <div class="shell-container_content">
#      <h2>
#       Start Your Coding Journey Now!
#      </h2>
#      <div class="shell-container_actions">
#       <button data-gfg-action="login-modal" title="Login">
#        Login
#       </button>
#       <button data-gfg-action="register-modal" title="Register">
#        Register
#       </button>
#      </div>
#     </div>
#    </div>
#   </div>
#   <link href="https://use.typekit.net/mrg0hpc.css" rel="stylesheet"/>
#   <script>
#    (function(c,l,a,r,i,t,y){
#         c[a]=c[a]||function(){(c[a].q=c[a].q||[]).push(arguments)};
#         t=l.createElement(r);t.async=1;t.src="https://www.clarity.ms/tag/"+i;
#         y=l.getElementsByTagName(r)[0];y.parentNode.insertBefore(t,y);
#     })(window, document, "clarity", "script", "ayc7ypwwuk");
#   </script>
#   <script>
#    try {
#         var isAdblockEnabled = t =>
#             fetch(
#                 new Request('https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js', {
#                     method: 'HEAD',
#                     mode: 'no-cors'
#                 })
#             ).catch(t);
#         isAdblockEnabled(() => {
#             var scr = window.document.createElement('script'),
#                 siteId = 41782;
#             scr.setAttribute('src', 'https://delivery.adrecover.com/'.concat(siteId, '/adRecover.js'));
#             scr.setAttribute('type', 'text/javascript');
#             scr.setAttribute('async', !0);
#             window.document.head.append(scr);
#         });
#     } catch (err) {console.log(err);}
#   </script>
#   <script src="//m.servedby-buysellads.com/monetization.js">
#   </script>
#   <script>
#    (function(){
#     if(typeof _bsa !== 'undefined' && _bsa) {
#         _bsa.init('fancybar', 'C6ADVKE', 'placement:geeksforgeeks');
#     }
# })();
#   </script>
#  </body>
# </html>

# %%
import requests
from bs4 import BeautifulSoup
 
 
# Making a GET request
r = requests.get('https://www.geeksforgeeks.org/python-programming-language/')
 
# Parsing the HTML
soup = BeautifulSoup(r.content, 'html.parser')
 
# Getting the title tag
print(soup.title)
 
# Getting the name of the tag
print(soup.title.name)
 
# Getting the name of parent tag
print(soup.title.parent.name)
 
# use the child attribute to get
# the name of the child tag
# Out:
# <title>Python Programming Language - GeeksforGeeks</title>
# title
# html

# %%
import requests
from bs4 import BeautifulSoup
 
 
# Making a GET request
r = requests.get('https://www.geeksforgeeks.org/python-programming-language/')
 
# Parsing the HTML
soup = BeautifulSoup(r.content, 'html.parser')
 
s = soup.find('div', class_='entry-content')
 
lines = s.find_all('p')
 
for line in lines:
    print(line.text)
# Out:
# Python is a high-level, general-purpose and a very popular programming language. Python programming language (latest Python 3) is being used in web development, Machine Learning applications, along with all cutting edge technology in Software Industry. Python Programming Language is very well suited for Beginners, also for experienced programmers with other programming languages like C++ and Java.This specially designed Python tutorial will help you learn Python Programming Language in most efficient way, with the topics from basics to advanced (like Web-scraping, Django, Deep-Learning, etc.) with examples.Below are some facts about Python Programming Language:Python is currently the most widely used multi-purpose, high-level programming language.Python allows programming in Object-Oriented and Procedural paradigms.Python programs generally are smaller than other programming languages like Java. Programmers have to type relatively less and indentation requirement of the language, makes them readable all the time.Python language is being used by almost all tech-giant companies like – Google, Amazon, Facebook, Instagram, Dropbox, Uber… etc.The biggest strength of Python is huge collection of standard library which can be used for the following:Machine LearningGUI Applications (like Kivy, Tkinter, PyQt etc. )Web frameworks like Django (used by YouTube, Instagram, Dropbox)Image processing (like OpenCV, Pillow)Web scraping (like Scrapy, BeautifulSoup, Selenium)Test frameworksMultimediaScientific computingText processing and many more..Recent Articles on Python !Python Programming ExamplesPython Output & Multiple Choice Questions Basics, Input/Output, Data Types, Variables, Operators, Control Flow, Functions, Object Oriented Concepts, Exception Handling, Python Collections, Django Framework, Data Analysis, Numpy, Pandas, Machine Learning with Python, Python GUI, Modules in Python, Working with Database, Misc, Applications and Projects, Multiple Choice QuestionsPython Tutorial –Python BasicsPython language introductionPython 3 basicsPython The new generation languageImportant difference between python 2.x and python 3.x with exampleKeywords in Python | Set 1, Set 2Namespaces and Scope in PythonStatement, Indentation and Comment in PythonStructuring Python ProgramsHow to check if a string is a valid keyword in Python?How to assign values to variables in Python and other languagesHow to print without newline in Python?Decision makingBasic calculator program using PythonPython Language advantages and applicationsInput/OutputTaking input in PythonTaking input from console in PythonTaking multiple inputs from user in PythonPython Input Methods for Competitive ProgrammingVulnerability in input() function – Python 2.xPython | Output using print() functionHow to print without newline in Python?Python | end parameter in print()Python | sep parameter in print()Python | Output FormattingData TypesIntroduction to DataTypesStringsListTuplesSetsDictionaryArraysVariablesVariables, expression condition and functionMaximum possible value of an integer in python?Global and local variables in pythonPacking and unpacking arguments in pythonType conversion in pythonByte objects vs string in pythonPrint single and multiple variableSwap variablePrivate variables__name__ (A Special variable) in PythonOperatorsBasic operator in pythonLogical and bitwise not operator on booleanTernary operatorDivision operator in pythonOperator Overloading in PythonAny & all in pythonInplace and standard operators in pythonOperator function in python | Set – 1Inplace operator | Set -1Logic Gates in PythonPython | a += b is not always a = a + bDifference between == and is operator in PythonPython Membership and Identity Operators | in, not in, is, is notControl FlowLoopsLoops and Control Statements (continue, break and pass) in PythonLooping technique in pythonrange vs xrange on pythonPrograms for printing pyramid technique in pythonChaining comparison in pythonelse with forsw ...
# arrow_drop_upSave
# This specially designed Python tutorial will help you learn Python Programming Language in most efficient way, with the topics from basics to advanced (like Web-scraping, Django, Deep-Learning, etc.) with examples.Below are some facts about Python Programming Language:Python is currently the most widely used multi-purpose, high-level programming language.Python allows programming in Object-Oriented and Procedural paradigms.Python programs generally are smaller than other programming languages like Java. Programmers have to type relatively less and indentation requirement of the language, makes them readable all the time.Python language is being used by almost all tech-giant companies like – Google, Amazon, Facebook, Instagram, Dropbox, Uber… etc.The biggest strength of Python is huge collection of standard library which can be used for the following:Machine LearningGUI Applications (like Kivy, Tkinter, PyQt etc. )Web frameworks like Django (used by YouTube, Instagram, Dropbox)Image processing (like OpenCV, Pillow)Web scraping (like Scrapy, BeautifulSoup, Selenium)Test frameworksMultimediaScientific computingText processing and many more..Recent Articles on Python !Python Programming ExamplesPython Output & Multiple Choice Questions Basics, Input/Output, Data Types, Variables, Operators, Control Flow, Functions, Object Oriented Concepts, Exception Handling, Python Collections, Django Framework, Data Analysis, Numpy, Pandas, Machine Learning with Python, Python GUI, Modules in Python, Working with Database, Misc, Applications and Projects, Multiple Choice QuestionsPython Tutorial –Python BasicsPython language introductionPython 3 basicsPython The new generation languageImportant difference between python 2.x and python 3.x with exampleKeywords in Python | Set 1, Set 2Namespaces and Scope in PythonStatement, Indentation and Comment in PythonStructuring Python ProgramsHow to check if a string is a valid keyword in Python?How to assign values to variables in Python and other languagesHow to print without newline in Python?Decision makingBasic calculator program using PythonPython Language advantages and applicationsInput/OutputTaking input in PythonTaking input from console in PythonTaking multiple inputs from user in PythonPython Input Methods for Competitive ProgrammingVulnerability in input() function – Python 2.xPython | Output using print() functionHow to print without newline in Python?Python | end parameter in print()Python | sep parameter in print()Python | Output FormattingData TypesIntroduction to DataTypesStringsListTuplesSetsDictionaryArraysVariablesVariables, expression condition and functionMaximum possible value of an integer in python?Global and local variables in pythonPacking and unpacking arguments in pythonType conversion in pythonByte objects vs string in pythonPrint single and multiple variableSwap variablePrivate variables__name__ (A Special variable) in PythonOperatorsBasic operator in pythonLogical and bitwise not operator on booleanTernary operatorDivision operator in pythonOperator Overloading in PythonAny & all in pythonInplace and standard operators in pythonOperator function in python | Set – 1Inplace operator | Set -1Logic Gates in PythonPython | a += b is not always a = a + bDifference between == and is operator in PythonPython Membership and Identity Operators | in, not in, is, is notControl FlowLoopsLoops and Control Statements (continue, break and pass) in PythonLooping technique in pythonrange vs xrange on pythonPrograms for printing pyramid technique in pythonChaining comparison in pythonelse with forswitch functionUsing iteration in python effectivelyPython ItertoolsPython __iter__() and __next__() | Converting an object into an iteratorPython | Difference between iterable and iteratorGenerators in pythonGenerators expression in pythonFunctionsFunctions in Pythonclass method vs static method in PythonWrite an empty function in Python – pass statementYield instead of ReturnReturn Multiple Values ...
# arrow_drop_upSave
# Below are some facts about Python Programming Language:Python is currently the most widely used multi-purpose, high-level programming language.Python allows programming in Object-Oriented and Procedural paradigms.Python programs generally are smaller than other programming languages like Java. Programmers have to type relatively less and indentation requirement of the language, makes them readable all the time.Python language is being used by almost all tech-giant companies like – Google, Amazon, Facebook, Instagram, Dropbox, Uber… etc.The biggest strength of Python is huge collection of standard library which can be used for the following:Machine LearningGUI Applications (like Kivy, Tkinter, PyQt etc. )Web frameworks like Django (used by YouTube, Instagram, Dropbox)Image processing (like OpenCV, Pillow)Web scraping (like Scrapy, BeautifulSoup, Selenium)Test frameworksMultimediaScientific computingText processing and many more..Recent Articles on Python !Python Programming ExamplesPython Output & Multiple Choice Questions Basics, Input/Output, Data Types, Variables, Operators, Control Flow, Functions, Object Oriented Concepts, Exception Handling, Python Collections, Django Framework, Data Analysis, Numpy, Pandas, Machine Learning with Python, Python GUI, Modules in Python, Working with Database, Misc, Applications and Projects, Multiple Choice QuestionsPython Tutorial –Python BasicsPython language introductionPython 3 basicsPython The new generation languageImportant difference between python 2.x and python 3.x with exampleKeywords in Python | Set 1, Set 2Namespaces and Scope in PythonStatement, Indentation and Comment in PythonStructuring Python ProgramsHow to check if a string is a valid keyword in Python?How to assign values to variables in Python and other languagesHow to print without newline in Python?Decision makingBasic calculator program using PythonPython Language advantages and applicationsInput/OutputTaking input in PythonTaking input from console in PythonTaking multiple inputs from user in PythonPython Input Methods for Competitive ProgrammingVulnerability in input() function – Python 2.xPython | Output using print() functionHow to print without newline in Python?Python | end parameter in print()Python | sep parameter in print()Python | Output FormattingData TypesIntroduction to DataTypesStringsListTuplesSetsDictionaryArraysVariablesVariables, expression condition and functionMaximum possible value of an integer in python?Global and local variables in pythonPacking and unpacking arguments in pythonType conversion in pythonByte objects vs string in pythonPrint single and multiple variableSwap variablePrivate variables__name__ (A Special variable) in PythonOperatorsBasic operator in pythonLogical and bitwise not operator on booleanTernary operatorDivision operator in pythonOperator Overloading in PythonAny & all in pythonInplace and standard operators in pythonOperator function in python | Set – 1Inplace operator | Set -1Logic Gates in PythonPython | a += b is not always a = a + bDifference between == and is operator in PythonPython Membership and Identity Operators | in, not in, is, is notControl FlowLoopsLoops and Control Statements (continue, break and pass) in PythonLooping technique in pythonrange vs xrange on pythonPrograms for printing pyramid technique in pythonChaining comparison in pythonelse with forswitch functionUsing iteration in python effectivelyPython ItertoolsPython __iter__() and __next__() | Converting an object into an iteratorPython | Difference between iterable and iteratorGenerators in pythonGenerators expression in pythonFunctionsFunctions in Pythonclass method vs static method in PythonWrite an empty function in Python – pass statementYield instead of ReturnReturn Multiple ValuesPartial Functions in PythonFirst Class functions in PythonPrecision Handling*args and **kwargsPython closuresFunction DecoratorsDecorators in PythonDecorators with parameters in PythonMemoization using decorators i ...
# arrow_drop_upSave
# Below are some facts about Python Programming Language:Python is currently the most widely used multi-purpose, high-level programming language.Python allows programming in Object-Oriented and Procedural paradigms.Python programs generally are smaller than other programming languages like Java. Programmers have to type relatively less and indentation requirement of the language, makes them readable all the time.Python language is being used by almost all tech-giant companies like – Google, Amazon, Facebook, Instagram, Dropbox, Uber… etc.The biggest strength of Python is huge collection of standard library which can be used for the following:Machine LearningGUI Applications (like Kivy, Tkinter, PyQt etc. )Web frameworks like Django (used by YouTube, Instagram, Dropbox)Image processing (like OpenCV, Pillow)Web scraping (like Scrapy, BeautifulSoup, Selenium)Test frameworksMultimediaScientific computingText processing and many more..Recent Articles on Python !Python Programming ExamplesPython Output & Multiple Choice Questions Basics, Input/Output, Data Types, Variables, Operators, Control Flow, Functions, Object Oriented Concepts, Exception Handling, Python Collections, Django Framework, Data Analysis, Numpy, Pandas, Machine Learning with Python, Python GUI, Modules in Python, Working with Database, Misc, Applications and Projects, Multiple Choice QuestionsPython Tutorial –Python BasicsPython language introductionPython 3 basicsPython The new generation languageImportant difference between python 2.x and python 3.x with exampleKeywords in Python | Set 1, Set 2Namespaces and Scope in PythonStatement, Indentation and Comment in PythonStructuring Python ProgramsHow to check if a string is a valid keyword in Python?How to assign values to variables in Python and other languagesHow to print without newline in Python?Decision makingBasic calculator program using PythonPython Language advantages and applicationsInput/OutputTaking input in PythonTaking input from console in PythonTaking multiple inputs from user in PythonPython Input Methods for Competitive ProgrammingVulnerability in input() function – Python 2.xPython | Output using print() functionHow to print without newline in Python?Python | end parameter in print()Python | sep parameter in print()Python | Output FormattingData TypesIntroduction to DataTypesStringsListTuplesSetsDictionaryArraysVariablesVariables, expression condition and functionMaximum possible value of an integer in python?Global and local variables in pythonPacking and unpacking arguments in pythonType conversion in pythonByte objects vs string in pythonPrint single and multiple variableSwap variablePrivate variables__name__ (A Special variable) in PythonOperatorsBasic operator in pythonLogical and bitwise not operator on booleanTernary operatorDivision operator in pythonOperator Overloading in PythonAny & all in pythonInplace and standard operators in pythonOperator function in python | Set – 1Inplace operator | Set -1Logic Gates in PythonPython | a += b is not always a = a + bDifference between == and is operator in PythonPython Membership and Identity Operators | in, not in, is, is notControl FlowLoopsLoops and Control Statements (continue, break and pass) in PythonLooping technique in pythonrange vs xrange on pythonPrograms for printing pyramid technique in pythonChaining comparison in pythonelse with forswitch functionUsing iteration in python effectivelyPython ItertoolsPython __iter__() and __next__() | Converting an object into an iteratorPython | Difference between iterable and iteratorGenerators in pythonGenerators expression in pythonFunctionsFunctions in Pythonclass method vs static method in PythonWrite an empty function in Python – pass statementYield instead of ReturnReturn Multiple ValuesPartial Functions in PythonFirst Class functions in PythonPrecision Handling*args and **kwargsPython closuresFunction DecoratorsDecorators in PythonDecorators with parameters in PythonMemoization using decorators i ...
# arrow_drop_upSave
# Recent Articles on Python !Python Programming ExamplesPython Output & Multiple Choice Questions Basics, Input/Output, Data Types, Variables, Operators, Control Flow, Functions, Object Oriented Concepts, Exception Handling, Python Collections, Django Framework, Data Analysis, Numpy, Pandas, Machine Learning with Python, Python GUI, Modules in Python, Working with Database, Misc, Applications and Projects, Multiple Choice QuestionsPython Tutorial –Python BasicsPython language introductionPython 3 basicsPython The new generation languageImportant difference between python 2.x and python 3.x with exampleKeywords in Python | Set 1, Set 2Namespaces and Scope in PythonStatement, Indentation and Comment in PythonStructuring Python ProgramsHow to check if a string is a valid keyword in Python?How to assign values to variables in Python and other languagesHow to print without newline in Python?Decision makingBasic calculator program using PythonPython Language advantages and applicationsInput/OutputTaking input in PythonTaking input from console in PythonTaking multiple inputs from user in PythonPython Input Methods for Competitive ProgrammingVulnerability in input() function – Python 2.xPython | Output using print() functionHow to print without newline in Python?Python | end parameter in print()Python | sep parameter in print()Python | Output FormattingData TypesIntroduction to DataTypesStringsListTuplesSetsDictionaryArraysVariablesVariables, expression condition and functionMaximum possible value of an integer in python?Global and local variables in pythonPacking and unpacking arguments in pythonType conversion in pythonByte objects vs string in pythonPrint single and multiple variableSwap variablePrivate variables__name__ (A Special variable) in PythonOperatorsBasic operator in pythonLogical and bitwise not operator on booleanTernary operatorDivision operator in pythonOperator Overloading in PythonAny & all in pythonInplace and standard operators in pythonOperator function in python | Set – 1Inplace operator | Set -1Logic Gates in PythonPython | a += b is not always a = a + bDifference between == and is operator in PythonPython Membership and Identity Operators | in, not in, is, is notControl FlowLoopsLoops and Control Statements (continue, break and pass) in PythonLooping technique in pythonrange vs xrange on pythonPrograms for printing pyramid technique in pythonChaining comparison in pythonelse with forswitch functionUsing iteration in python effectivelyPython ItertoolsPython __iter__() and __next__() | Converting an object into an iteratorPython | Difference between iterable and iteratorGenerators in pythonGenerators expression in pythonFunctionsFunctions in Pythonclass method vs static method in PythonWrite an empty function in Python – pass statementYield instead of ReturnReturn Multiple ValuesPartial Functions in PythonFirst Class functions in PythonPrecision Handling*args and **kwargsPython closuresFunction DecoratorsDecorators in PythonDecorators with parameters in PythonMemoization using decorators in PythonHelp function in PythonPython | __import__() functionPython | range() does not return an iteratorCoroutine in PythonPython bit functions on int (bit_length, to_bytes and from_bytes)Object Oriented ConceptsPython3 Intermediate Level TopicsClass, Object and MembersData Hiding and Object PrintingInheritance, examples of object, issubclass and superPolymorphism in PythonClass and static variable in pythonClass method and static method in pythonChanging class membersConstructors in PythonDestructors in PythonFirst class functionMetaprogramming with metaclassesClass and instance attributeReflectionGarbage collectionException HandlingException handlingUser defined ExceptionBuilt-in Exceptionclean up actionNzec errortry and except in PythonPython CollectionsCountersOrderedDictDefaultdictChainMapNamedTupleDeQueHeapCollections.UserDictCollections.UserListCollections.UserStringDjango FrameworkDjango TutorialDjango BasicsDjango Intr ...
# arrow_drop_upSave
# Recent Articles on Python !Python Programming ExamplesPython Output & Multiple Choice Questions Basics, Input/Output, Data Types, Variables, Operators, Control Flow, Functions, Object Oriented Concepts, Exception Handling, Python Collections, Django Framework, Data Analysis, Numpy, Pandas, Machine Learning with Python, Python GUI, Modules in Python, Working with Database, Misc, Applications and Projects, Multiple Choice QuestionsPython Tutorial –Python BasicsPython language introductionPython 3 basicsPython The new generation languageImportant difference between python 2.x and python 3.x with exampleKeywords in Python | Set 1, Set 2Namespaces and Scope in PythonStatement, Indentation and Comment in PythonStructuring Python ProgramsHow to check if a string is a valid keyword in Python?How to assign values to variables in Python and other languagesHow to print without newline in Python?Decision makingBasic calculator program using PythonPython Language advantages and applicationsInput/OutputTaking input in PythonTaking input from console in PythonTaking multiple inputs from user in PythonPython Input Methods for Competitive ProgrammingVulnerability in input() function – Python 2.xPython | Output using print() functionHow to print without newline in Python?Python | end parameter in print()Python | sep parameter in print()Python | Output FormattingData TypesIntroduction to DataTypesStringsListTuplesSetsDictionaryArraysVariablesVariables, expression condition and functionMaximum possible value of an integer in python?Global and local variables in pythonPacking and unpacking arguments in pythonType conversion in pythonByte objects vs string in pythonPrint single and multiple variableSwap variablePrivate variables__name__ (A Special variable) in PythonOperatorsBasic operator in pythonLogical and bitwise not operator on booleanTernary operatorDivision operator in pythonOperator Overloading in PythonAny & all in pythonInplace and standard operators in pythonOperator function in python | Set – 1Inplace operator | Set -1Logic Gates in PythonPython | a += b is not always a = a + bDifference between == and is operator in PythonPython Membership and Identity Operators | in, not in, is, is notControl FlowLoopsLoops and Control Statements (continue, break and pass) in PythonLooping technique in pythonrange vs xrange on pythonPrograms for printing pyramid technique in pythonChaining comparison in pythonelse with forswitch functionUsing iteration in python effectivelyPython ItertoolsPython __iter__() and __next__() | Converting an object into an iteratorPython | Difference between iterable and iteratorGenerators in pythonGenerators expression in pythonFunctionsFunctions in Pythonclass method vs static method in PythonWrite an empty function in Python – pass statementYield instead of ReturnReturn Multiple ValuesPartial Functions in PythonFirst Class functions in PythonPrecision Handling*args and **kwargsPython closuresFunction DecoratorsDecorators in PythonDecorators with parameters in PythonMemoization using decorators in PythonHelp function in PythonPython | __import__() functionPython | range() does not return an iteratorCoroutine in PythonPython bit functions on int (bit_length, to_bytes and from_bytes)Object Oriented ConceptsPython3 Intermediate Level TopicsClass, Object and MembersData Hiding and Object PrintingInheritance, examples of object, issubclass and superPolymorphism in PythonClass and static variable in pythonClass method and static method in pythonChanging class membersConstructors in PythonDestructors in PythonFirst class functionMetaprogramming with metaclassesClass and instance attributeReflectionGarbage collectionException HandlingException handlingUser defined ExceptionBuilt-in Exceptionclean up actionNzec errortry and except in PythonPython CollectionsCountersOrderedDictDefaultdictChainMapNamedTupleDeQueHeapCollections.UserDictCollections.UserListCollections.UserStringDjango FrameworkDjango TutorialDjango BasicsDjango Intr ...
# arrow_drop_upSave
# Basics, Input/Output, Data Types, Variables, Operators, Control Flow, Functions, Object Oriented Concepts, Exception Handling, Python Collections, Django Framework, Data Analysis, Numpy, Pandas, Machine Learning with Python, Python GUI, Modules in Python, Working with Database, Misc, Applications and Projects, Multiple Choice QuestionsPython Tutorial –Python BasicsPython language introductionPython 3 basicsPython The new generation languageImportant difference between python 2.x and python 3.x with exampleKeywords in Python | Set 1, Set 2Namespaces and Scope in PythonStatement, Indentation and Comment in PythonStructuring Python ProgramsHow to check if a string is a valid keyword in Python?How to assign values to variables in Python and other languagesHow to print without newline in Python?Decision makingBasic calculator program using PythonPython Language advantages and applicationsInput/OutputTaking input in PythonTaking input from console in PythonTaking multiple inputs from user in PythonPython Input Methods for Competitive ProgrammingVulnerability in input() function – Python 2.xPython | Output using print() functionHow to print without newline in Python?Python | end parameter in print()Python | sep parameter in print()Python | Output FormattingData TypesIntroduction to DataTypesStringsListTuplesSetsDictionaryArraysVariablesVariables, expression condition and functionMaximum possible value of an integer in python?Global and local variables in pythonPacking and unpacking arguments in pythonType conversion in pythonByte objects vs string in pythonPrint single and multiple variableSwap variablePrivate variables__name__ (A Special variable) in PythonOperatorsBasic operator in pythonLogical and bitwise not operator on booleanTernary operatorDivision operator in pythonOperator Overloading in PythonAny & all in pythonInplace and standard operators in pythonOperator function in python | Set – 1Inplace operator | Set -1Logic Gates in PythonPython | a += b is not always a = a + bDifference between == and is operator in PythonPython Membership and Identity Operators | in, not in, is, is notControl FlowLoopsLoops and Control Statements (continue, break and pass) in PythonLooping technique in pythonrange vs xrange on pythonPrograms for printing pyramid technique in pythonChaining comparison in pythonelse with forswitch functionUsing iteration in python effectivelyPython ItertoolsPython __iter__() and __next__() | Converting an object into an iteratorPython | Difference between iterable and iteratorGenerators in pythonGenerators expression in pythonFunctionsFunctions in Pythonclass method vs static method in PythonWrite an empty function in Python – pass statementYield instead of ReturnReturn Multiple ValuesPartial Functions in PythonFirst Class functions in PythonPrecision Handling*args and **kwargsPython closuresFunction DecoratorsDecorators in PythonDecorators with parameters in PythonMemoization using decorators in PythonHelp function in PythonPython | __import__() functionPython | range() does not return an iteratorCoroutine in PythonPython bit functions on int (bit_length, to_bytes and from_bytes)Object Oriented ConceptsPython3 Intermediate Level TopicsClass, Object and MembersData Hiding and Object PrintingInheritance, examples of object, issubclass and superPolymorphism in PythonClass and static variable in pythonClass method and static method in pythonChanging class membersConstructors in PythonDestructors in PythonFirst class functionMetaprogramming with metaclassesClass and instance attributeReflectionGarbage collectionException HandlingException handlingUser defined ExceptionBuilt-in Exceptionclean up actionNzec errortry and except in PythonPython CollectionsCountersOrderedDictDefaultdictChainMapNamedTupleDeQueHeapCollections.UserDictCollections.UserListCollections.UserStringDjango FrameworkDjango TutorialDjango BasicsDjango Introduction and InstallationDjango FormsViews In DjangoDjango ModelsDjango TemplatesToDo webapp usi ...
# arrow_drop_upSave
#
# Input/OutputTaking input in PythonTaking input from console in PythonTaking multiple inputs from user in PythonPython Input Methods for Competitive ProgrammingVulnerability in input() function – Python 2.xPython | Output using print() functionHow to print without newline in Python?Python | end parameter in print()Python | sep parameter in print()Python | Output FormattingData TypesIntroduction to DataTypesStringsListTuplesSetsDictionaryArraysVariablesVariables, expression condition and functionMaximum possible value of an integer in python?Global and local variables in pythonPacking and unpacking arguments in pythonType conversion in pythonByte objects vs string in pythonPrint single and multiple variableSwap variablePrivate variables__name__ (A Special variable) in PythonOperatorsBasic operator in pythonLogical and bitwise not operator on booleanTernary operatorDivision operator in pythonOperator Overloading in PythonAny & all in pythonInplace and standard operators in pythonOperator function in python | Set – 1Inplace operator | Set -1Logic Gates in PythonPython | a += b is not always a = a + bDifference between == and is operator in PythonPython Membership and Identity Operators | in, not in, is, is notControl FlowLoopsLoops and Control Statements (continue, break and pass) in PythonLooping technique in pythonrange vs xrange on pythonPrograms for printing pyramid technique in pythonChaining comparison in pythonelse with forswitch functionUsing iteration in python effectivelyPython ItertoolsPython __iter__() and __next__() | Converting an object into an iteratorPython | Difference between iterable and iteratorGenerators in pythonGenerators expression in pythonFunctionsFunctions in Pythonclass method vs static method in PythonWrite an empty function in Python – pass statementYield instead of ReturnReturn Multiple ValuesPartial Functions in PythonFirst Class functions in PythonPrecision Handling*args and **kwargsPython closuresFunction DecoratorsDecorators in PythonDecorators with parameters in PythonMemoization using decorators in PythonHelp function in PythonPython | __import__() functionPython | range() does not return an iteratorCoroutine in PythonPython bit functions on int (bit_length, to_bytes and from_bytes)Object Oriented ConceptsPython3 Intermediate Level TopicsClass, Object and MembersData Hiding and Object PrintingInheritance, examples of object, issubclass and superPolymorphism in PythonClass and static variable in pythonClass method and static method in pythonChanging class membersConstructors in PythonDestructors in PythonFirst class functionMetaprogramming with metaclassesClass and instance attributeReflectionGarbage collectionException HandlingException handlingUser defined ExceptionBuilt-in Exceptionclean up actionNzec errortry and except in PythonPython CollectionsCountersOrderedDictDefaultdictChainMapNamedTupleDeQueHeapCollections.UserDictCollections.UserListCollections.UserString
# Data TypesIntroduction to DataTypesStringsListTuplesSetsDictionaryArraysVariablesVariables, expression condition and functionMaximum possible value of an integer in python?Global and local variables in pythonPacking and unpacking arguments in pythonType conversion in pythonByte objects vs string in pythonPrint single and multiple variableSwap variablePrivate variables__name__ (A Special variable) in PythonOperatorsBasic operator in pythonLogical and bitwise not operator on booleanTernary operatorDivision operator in pythonOperator Overloading in PythonAny & all in pythonInplace and standard operators in pythonOperator function in python | Set – 1Inplace operator | Set -1Logic Gates in PythonPython | a += b is not always a = a + bDifference between == and is operator in PythonPython Membership and Identity Operators | in, not in, is, is notControl FlowLoopsLoops and Control Statements (continue, break and pass) in PythonLooping technique in pythonrange vs xrange on pythonPrograms for printing pyramid technique in pythonChaining comparison in pythonelse with forswitch functionUsing iteration in python effectivelyPython ItertoolsPython __iter__() and __next__() | Converting an object into an iteratorPython | Difference between iterable and iteratorGenerators in pythonGenerators expression in pythonFunctionsFunctions in Pythonclass method vs static method in PythonWrite an empty function in Python – pass statementYield instead of ReturnReturn Multiple ValuesPartial Functions in PythonFirst Class functions in PythonPrecision Handling*args and **kwargsPython closuresFunction DecoratorsDecorators in PythonDecorators with parameters in PythonMemoization using decorators in PythonHelp function in PythonPython | __import__() functionPython | range() does not return an iteratorCoroutine in PythonPython bit functions on int (bit_length, to_bytes and from_bytes)Object Oriented ConceptsPython3 Intermediate Level TopicsClass, Object and MembersData Hiding and Object PrintingInheritance, examples of object, issubclass and superPolymorphism in PythonClass and static variable in pythonClass method and static method in pythonChanging class membersConstructors in PythonDestructors in PythonFirst class functionMetaprogramming with metaclassesClass and instance attributeReflectionGarbage collectionException HandlingException handlingUser defined ExceptionBuilt-in Exceptionclean up actionNzec errortry and except in PythonPython CollectionsCountersOrderedDictDefaultdictChainMapNamedTupleDeQueHeapCollections.UserDictCollections.UserListCollections.UserString
#
# VariablesVariables, expression condition and functionMaximum possible value of an integer in python?Global and local variables in pythonPacking and unpacking arguments in pythonType conversion in pythonByte objects vs string in pythonPrint single and multiple variableSwap variablePrivate variables__name__ (A Special variable) in PythonOperatorsBasic operator in pythonLogical and bitwise not operator on booleanTernary operatorDivision operator in pythonOperator Overloading in PythonAny & all in pythonInplace and standard operators in pythonOperator function in python | Set – 1Inplace operator | Set -1Logic Gates in PythonPython | a += b is not always a = a + bDifference between == and is operator in PythonPython Membership and Identity Operators | in, not in, is, is notControl FlowLoopsLoops and Control Statements (continue, break and pass) in PythonLooping technique in pythonrange vs xrange on pythonPrograms for printing pyramid technique in pythonChaining comparison in pythonelse with forswitch functionUsing iteration in python effectivelyPython ItertoolsPython __iter__() and __next__() | Converting an object into an iteratorPython | Difference between iterable and iteratorGenerators in pythonGenerators expression in pythonFunctionsFunctions in Pythonclass method vs static method in PythonWrite an empty function in Python – pass statementYield instead of ReturnReturn Multiple ValuesPartial Functions in PythonFirst Class functions in PythonPrecision Handling*args and **kwargsPython closuresFunction DecoratorsDecorators in PythonDecorators with parameters in PythonMemoization using decorators in PythonHelp function in PythonPython | __import__() functionPython | range() does not return an iteratorCoroutine in PythonPython bit functions on int (bit_length, to_bytes and from_bytes)Object Oriented ConceptsPython3 Intermediate Level TopicsClass, Object and MembersData Hiding and Object PrintingInheritance, examples of object, issubclass and superPolymorphism in PythonClass and static variable in pythonClass method and static method in pythonChanging class membersConstructors in PythonDestructors in PythonFirst class functionMetaprogramming with metaclassesClass and instance attributeReflectionGarbage collectionException HandlingException handlingUser defined ExceptionBuilt-in Exceptionclean up actionNzec errortry and except in PythonPython CollectionsCountersOrderedDictDefaultdictChainMapNamedTupleDeQueHeapCollections.UserDictCollections.UserListCollections.UserString
#
# OperatorsBasic operator in pythonLogical and bitwise not operator on booleanTernary operatorDivision operator in pythonOperator Overloading in PythonAny & all in pythonInplace and standard operators in pythonOperator function in python | Set – 1Inplace operator | Set -1Logic Gates in PythonPython | a += b is not always a = a + bDifference between == and is operator in PythonPython Membership and Identity Operators | in, not in, is, is notControl FlowLoopsLoops and Control Statements (continue, break and pass) in PythonLooping technique in pythonrange vs xrange on pythonPrograms for printing pyramid technique in pythonChaining comparison in pythonelse with forswitch functionUsing iteration in python effectivelyPython ItertoolsPython __iter__() and __next__() | Converting an object into an iteratorPython | Difference between iterable and iteratorGenerators in pythonGenerators expression in pythonFunctionsFunctions in Pythonclass method vs static method in PythonWrite an empty function in Python – pass statementYield instead of ReturnReturn Multiple ValuesPartial Functions in PythonFirst Class functions in PythonPrecision Handling*args and **kwargsPython closuresFunction DecoratorsDecorators in PythonDecorators with parameters in PythonMemoization using decorators in PythonHelp function in PythonPython | __import__() functionPython | range() does not return an iteratorCoroutine in PythonPython bit functions on int (bit_length, to_bytes and from_bytes)Object Oriented ConceptsPython3 Intermediate Level TopicsClass, Object and MembersData Hiding and Object PrintingInheritance, examples of object, issubclass and superPolymorphism in PythonClass and static variable in pythonClass method and static method in pythonChanging class membersConstructors in PythonDestructors in PythonFirst class functionMetaprogramming with metaclassesClass and instance attributeReflectionGarbage collectionException HandlingException handlingUser defined ExceptionBuilt-in Exceptionclean up actionNzec errortry and except in PythonPython CollectionsCountersOrderedDictDefaultdictChainMapNamedTupleDeQueHeapCollections.UserDictCollections.UserListCollections.UserString
#
# Control FlowLoopsLoops and Control Statements (continue, break and pass) in PythonLooping technique in pythonrange vs xrange on pythonPrograms for printing pyramid technique in pythonChaining comparison in pythonelse with forswitch functionUsing iteration in python effectivelyPython ItertoolsPython __iter__() and __next__() | Converting an object into an iteratorPython | Difference between iterable and iteratorGenerators in pythonGenerators expression in pythonFunctionsFunctions in Pythonclass method vs static method in PythonWrite an empty function in Python – pass statementYield instead of ReturnReturn Multiple ValuesPartial Functions in PythonFirst Class functions in PythonPrecision Handling*args and **kwargsPython closuresFunction DecoratorsDecorators in PythonDecorators with parameters in PythonMemoization using decorators in PythonHelp function in PythonPython | __import__() functionPython | range() does not return an iteratorCoroutine in PythonPython bit functions on int (bit_length, to_bytes and from_bytes)Object Oriented ConceptsPython3 Intermediate Level TopicsClass, Object and MembersData Hiding and Object PrintingInheritance, examples of object, issubclass and superPolymorphism in PythonClass and static variable in pythonClass method and static method in pythonChanging class membersConstructors in PythonDestructors in PythonFirst class functionMetaprogramming with metaclassesClass and instance attributeReflectionGarbage collectionException HandlingException handlingUser defined ExceptionBuilt-in Exceptionclean up actionNzec errortry and except in PythonPython CollectionsCountersOrderedDictDefaultdictChainMapNamedTupleDeQueHeapCollections.UserDictCollections.UserListCollections.UserString
#
# FunctionsFunctions in Pythonclass method vs static method in PythonWrite an empty function in Python – pass statementYield instead of ReturnReturn Multiple ValuesPartial Functions in PythonFirst Class functions in PythonPrecision Handling*args and **kwargsPython closuresFunction DecoratorsDecorators in PythonDecorators with parameters in PythonMemoization using decorators in PythonHelp function in PythonPython | __import__() functionPython | range() does not return an iteratorCoroutine in PythonPython bit functions on int (bit_length, to_bytes and from_bytes)Object Oriented ConceptsPython3 Intermediate Level TopicsClass, Object and MembersData Hiding and Object PrintingInheritance, examples of object, issubclass and superPolymorphism in PythonClass and static variable in pythonClass method and static method in pythonChanging class membersConstructors in PythonDestructors in PythonFirst class functionMetaprogramming with metaclassesClass and instance attributeReflectionGarbage collectionException HandlingException handlingUser defined ExceptionBuilt-in Exceptionclean up actionNzec errortry and except in PythonPython CollectionsCountersOrderedDictDefaultdictChainMapNamedTupleDeQueHeapCollections.UserDictCollections.UserListCollections.UserString
#
# Object Oriented ConceptsPython3 Intermediate Level TopicsClass, Object and MembersData Hiding and Object PrintingInheritance, examples of object, issubclass and superPolymorphism in PythonClass and static variable in pythonClass method and static method in pythonChanging class membersConstructors in PythonDestructors in PythonFirst class functionMetaprogramming with metaclassesClass and instance attributeReflectionGarbage collectionException HandlingException handlingUser defined ExceptionBuilt-in Exceptionclean up actionNzec errortry and except in PythonPython CollectionsCountersOrderedDictDefaultdictChainMapNamedTupleDeQueHeapCollections.UserDictCollections.UserListCollections.UserString
#
# Exception HandlingException handlingUser defined ExceptionBuilt-in Exceptionclean up actionNzec errortry and except in PythonPython CollectionsCountersOrderedDictDefaultdictChainMapNamedTupleDeQueHeapCollections.UserDictCollections.UserListCollections.UserString
#
# Python CollectionsCountersOrderedDictDefaultdictChainMapNamedTupleDeQueHeapCollections.UserDictCollections.UserListCollections.UserString
#
#
# Data AnalysisData visualization using BokehExploratory Data Analysis in PythonData visualization with different Charts in PythonData analysis and Visualization with PythonData Analysis & Visualization with Python | Set 2Math operations for Data analysisGetting started with Jupyter Notebook | PythonNumpyPython NumpyNumpy | ndarrayNumpy | Array CreationNumpy | Data Type ObjectsData type Object (dtype) in NumPyNumpy | IndexingNumpy | Basic Slicing and Advanced IndexingNumpy | Iterating Over ArrayNumpy | Binary OperationsNumpy | Linear AlgebraNumpy | Sorting, Searching and CountingPandasPandas TutorialPython | Pandas DataFrameCreating a Pandas DataFrameDealing with Rows and Columns in Pandas DataFrameIndexing and Selecting Data with PandasBoolean Indexing in PandasConversion Functions in Pandas DataFrameIterating over rows and columns in Pandas DataFrameWorking with Missing Data in PandasPython | Pandas SeriesData analysis using PandasRead csv using pandas.read_csv()Machine Learning with PythonMachine Learning TutorialLinear RegressionUnderstanding Logistic RegressionK means ClusteringPython | Image Classification using kerascreating a simple machine learning modelPython | Implementation of Movie Recommender SystemML | Boston Housing Kaggle Challenge with Linear RegressionCancer cell classification using Scikit-learnSaving a machine learning ModelApplying Convolutional Neural Network on mnist datasetPython | NLP analysis of Restaurant reviewsLearning Model Building in Scikit-learnImplementing Artificial Neural Network training processA single neuron neural network in PythonPython | How and where to apply Feature Scaling?Identifying handwritten digits using Logistic Regression in PyTorchPython GUITkinter TutorialKivy TutorialPython GUI – tkinterSimple GUI calculator using TkinterSimple registration form using TkinterCreate a stopwatch using pythonDesigning GUI applications Using PyQtColor game using Tkinter in PythonMake Notepad using TkinterMessage Encode-Decode using TkinterReal time currency convertor using TkinterModules in PythonIntroduction of ModulesOS moduleCalendar ModulePython Urllib ModulepprintTimit functionImport moduleWorking With DatabaseMongoDB and PythonSQL using Python | Set 1SQL using Python and SQLite | Set 2SQL using Python | Set 3 (Handling large data)Inserting variables to database table using PythonMYSQLdb Connection in PythonDatabase management in PostgreSQLOracle Database Connection in PythonMisc10 Essential Python Tips And Tricks For ProgrammersAmazing hacks of PythonInput method for comptetive programmingOptimization Tips for Python CodeWhy import star in Python is a bad ideaWhy is python best suited for Competitive Coding?Python trics for Competitive CodingApplications and ProjectsPython | Program to crawl a web page and get most frequent wordsFacebook login using pythonFB Chatting through pythonC/C++ code formating toolFind Live running status and PNR of any train using Railway APIFetching top news using News APIFetching text from Wikipedia’s Infobox in PythonGet emotions of images using Microsoft emotion API in PythonWebsite blockerSend SMS updates to mobile phone using pythonPython Desktop News Notifier in 20 linesMorse Code Translator In PythonPerforming Google Search using Python codeReading and generating qr codeBirthday reminder application in pythonProgram to display Astrological sign or Zodiac sign for given date of birthTrack bird migrationNews notifierwhatsapp using pythonPython | Automating Happy Birthday post on Facebook using SeleniumDesign a Keylogger in PythonPython | Implementation of Movie Recommender SystemRecommended Python TutorialsPython TutorialMachine Learning TutorialDjango TutorialPandas TutorialOpenCV Python TutorialSelenium Python TutorialPython Tkinter TutorialGeeksforGeeks CoursesPython Programming Foundation – Self Paced CourseWant to become a programmer? Want to learn Game Development, Data Visualisation, Web Development and much more? If you’re looking to learn Python fo ...
# arrow_drop_upSave
#
# ...
#
# Machine Learning with PythonMachine Learning TutorialLinear RegressionUnderstanding Logistic RegressionK means ClusteringPython | Image Classification using kerascreating a simple machine learning modelPython | Implementation of Movie Recommender SystemML | Boston Housing Kaggle Challenge with Linear RegressionCancer cell classification using Scikit-learnSaving a machine learning ModelApplying Convolutional Neural Network on mnist datasetPython | NLP analysis of Restaurant reviewsLearning Model Building in Scikit-learnImplementing Artificial Neural Network training processA single neuron neural network in PythonPython | How and where to apply Feature Scaling?Identifying handwritten digits using Logistic Regression in PyTorchPython GUITkinter TutorialKivy TutorialPython GUI – tkinterSimple GUI calculator using TkinterSimple registration form using TkinterCreate a stopwatch using pythonDesigning GUI applications Using PyQtColor game using Tkinter in PythonMake Notepad using TkinterMessage Encode-Decode using TkinterReal time currency convertor using TkinterModules in PythonIntroduction of ModulesOS moduleCalendar ModulePython Urllib ModulepprintTimit functionImport moduleWorking With DatabaseMongoDB and PythonSQL using Python | Set 1SQL using Python and SQLite | Set 2SQL using Python | Set 3 (Handling large data)Inserting variables to database table using PythonMYSQLdb Connection in PythonDatabase management in PostgreSQLOracle Database Connection in PythonMisc10 Essential Python Tips And Tricks For ProgrammersAmazing hacks of PythonInput method for comptetive programmingOptimization Tips for Python CodeWhy import star in Python is a bad ideaWhy is python best suited for Competitive Coding?Python trics for Competitive CodingApplications and ProjectsPython | Program to crawl a web page and get most frequent wordsFacebook login using pythonFB Chatting through pythonC/C++ code formating toolFind Live running status and PNR of any train using Railway APIFetching top news using News APIFetching text from Wikipedia’s Infobox in PythonGet emotions of images using Microsoft emotion API in PythonWebsite blockerSend SMS updates to mobile phone using pythonPython Desktop News Notifier in 20 linesMorse Code Translator In PythonPerforming Google Search using Python codeReading and generating qr codeBirthday reminder application in pythonProgram to display Astrological sign or Zodiac sign for given date of birthTrack bird migrationNews notifierwhatsapp using pythonPython | Automating Happy Birthday post on Facebook using SeleniumDesign a Keylogger in PythonPython | Implementation of Movie Recommender SystemRecommended Python TutorialsPython TutorialMachine Learning TutorialDjango TutorialPandas TutorialOpenCV Python TutorialSelenium Python TutorialPython Tkinter Tutorial
#
# Python GUITkinter TutorialKivy TutorialPython GUI – tkinterSimple GUI calculator using TkinterSimple registration form using TkinterCreate a stopwatch using pythonDesigning GUI applications Using PyQtColor game using Tkinter in PythonMake Notepad using TkinterMessage Encode-Decode using TkinterReal time currency convertor using TkinterModules in PythonIntroduction of ModulesOS moduleCalendar ModulePython Urllib ModulepprintTimit functionImport moduleWorking With DatabaseMongoDB and PythonSQL using Python | Set 1SQL using Python and SQLite | Set 2SQL using Python | Set 3 (Handling large data)Inserting variables to database table using PythonMYSQLdb Connection in PythonDatabase management in PostgreSQLOracle Database Connection in PythonMisc10 Essential Python Tips And Tricks For ProgrammersAmazing hacks of PythonInput method for comptetive programmingOptimization Tips for Python CodeWhy import star in Python is a bad ideaWhy is python best suited for Competitive Coding?Python trics for Competitive CodingApplications and ProjectsPython | Program to crawl a web page and get most frequent wordsFacebook login using pythonFB Chatting through pythonC/C++ code formating toolFind Live running status and PNR of any train using Railway APIFetching top news using News APIFetching text from Wikipedia’s Infobox in PythonGet emotions of images using Microsoft emotion API in PythonWebsite blockerSend SMS updates to mobile phone using pythonPython Desktop News Notifier in 20 linesMorse Code Translator In PythonPerforming Google Search using Python codeReading and generating qr codeBirthday reminder application in pythonProgram to display Astrological sign or Zodiac sign for given date of birthTrack bird migrationNews notifierwhatsapp using pythonPython | Automating Happy Birthday post on Facebook using SeleniumDesign a Keylogger in PythonPython | Implementation of Movie Recommender SystemRecommended Python TutorialsPython TutorialMachine Learning TutorialDjango TutorialPandas TutorialOpenCV Python TutorialSelenium Python TutorialPython Tkinter Tutorial
#
# Modules in PythonIntroduction of ModulesOS moduleCalendar ModulePython Urllib ModulepprintTimit functionImport moduleWorking With DatabaseMongoDB and PythonSQL using Python | Set 1SQL using Python and SQLite | Set 2SQL using Python | Set 3 (Handling large data)Inserting variables to database table using PythonMYSQLdb Connection in PythonDatabase management in PostgreSQLOracle Database Connection in PythonMisc10 Essential Python Tips And Tricks For ProgrammersAmazing hacks of PythonInput method for comptetive programmingOptimization Tips for Python CodeWhy import star in Python is a bad ideaWhy is python best suited for Competitive Coding?Python trics for Competitive CodingApplications and ProjectsPython | Program to crawl a web page and get most frequent wordsFacebook login using pythonFB Chatting through pythonC/C++ code formating toolFind Live running status and PNR of any train using Railway APIFetching top news using News APIFetching text from Wikipedia’s Infobox in PythonGet emotions of images using Microsoft emotion API in PythonWebsite blockerSend SMS updates to mobile phone using pythonPython Desktop News Notifier in 20 linesMorse Code Translator In PythonPerforming Google Search using Python codeReading and generating qr codeBirthday reminder application in pythonProgram to display Astrological sign or Zodiac sign for given date of birthTrack bird migrationNews notifierwhatsapp using pythonPython | Automating Happy Birthday post on Facebook using SeleniumDesign a Keylogger in PythonPython | Implementation of Movie Recommender System
#
# Working With DatabaseMongoDB and PythonSQL using Python | Set 1SQL using Python and SQLite | Set 2SQL using Python | Set 3 (Handling large data)Inserting variables to database table using PythonMYSQLdb Connection in PythonDatabase management in PostgreSQLOracle Database Connection in PythonMisc10 Essential Python Tips And Tricks For ProgrammersAmazing hacks of PythonInput method for comptetive programmingOptimization Tips for Python CodeWhy import star in Python is a bad ideaWhy is python best suited for Competitive Coding?Python trics for Competitive CodingApplications and ProjectsPython | Program to crawl a web page and get most frequent wordsFacebook login using pythonFB Chatting through pythonC/C++ code formating toolFind Live running status and PNR of any train using Railway APIFetching top news using News APIFetching text from Wikipedia’s Infobox in PythonGet emotions of images using Microsoft emotion API in PythonWebsite blockerSend SMS updates to mobile phone using pythonPython Desktop News Notifier in 20 linesMorse Code Translator In PythonPerforming Google Search using Python codeReading and generating qr codeBirthday reminder application in pythonProgram to display Astrological sign or Zodiac sign for given date of birthTrack bird migrationNews notifierwhatsapp using pythonPython | Automating Happy Birthday post on Facebook using SeleniumDesign a Keylogger in PythonPython | Implementation of Movie Recommender System
#
# Misc10 Essential Python Tips And Tricks For ProgrammersAmazing hacks of PythonInput method for comptetive programmingOptimization Tips for Python CodeWhy import star in Python is a bad ideaWhy is python best suited for Competitive Coding?Python trics for Competitive CodingApplications and ProjectsPython | Program to crawl a web page and get most frequent wordsFacebook login using pythonFB Chatting through pythonC/C++ code formating toolFind Live running status and PNR of any train using Railway APIFetching top news using News APIFetching text from Wikipedia’s Infobox in PythonGet emotions of images using Microsoft emotion API in PythonWebsite blockerSend SMS updates to mobile phone using pythonPython Desktop News Notifier in 20 linesMorse Code Translator In PythonPerforming Google Search using Python codeReading and generating qr codeBirthday reminder application in pythonProgram to display Astrological sign or Zodiac sign for given date of birthTrack bird migrationNews notifierwhatsapp using pythonPython | Automating Happy Birthday post on Facebook using SeleniumDesign a Keylogger in PythonPython | Implementation of Movie Recommender System
#
# Applications and ProjectsPython | Program to crawl a web page and get most frequent wordsFacebook login using pythonFB Chatting through pythonC/C++ code formating toolFind Live running status and PNR of any train using Railway APIFetching top news using News APIFetching text from Wikipedia’s Infobox in PythonGet emotions of images using Microsoft emotion API in PythonWebsite blockerSend SMS updates to mobile phone using pythonPython Desktop News Notifier in 20 linesMorse Code Translator In PythonPerforming Google Search using Python codeReading and generating qr codeBirthday reminder application in pythonProgram to display Astrological sign or Zodiac sign for given date of birthTrack bird migrationNews notifierwhatsapp using pythonPython | Automating Happy Birthday post on Facebook using SeleniumDesign a Keylogger in PythonPython | Implementation of Movie Recommender System
#
# GeeksforGeeks CoursesPython Programming Foundation – Self Paced CourseWant to become a programmer? Want to learn Game Development, Data Visualisation, Web Development and much more? If you’re looking to learn Python for the very first time, this is the course for you! A beginner-friendly Python Programming Foundation -Self Paced Course designed to help start learning Python language from scratch. Learn Python basics, Variables & Data types, Input & Output, Operators, and more. So what are you waiting for? Kickstart your programming journey and dive into the world of Python by enrolling in this course today!DS Using Python Programming – Self Paced CourseIt’s time to level up your Python skills with our most complete DS Using Python Programming – Self Paced Course on the internet, This course will help you better understand every detail of Data Structures and how algorithms are implemented in a high-level programming language, designed by leading industry experts who will teach you, in-depth, effective and efficient ways to implement data structures like Heaps, Stacks, Linked List and many other such concepts. So, what are you waiting for? Advance your Python skills today and become a better programmer.My Personal Notes
# arrow_drop_upSave
# Want to become a programmer? Want to learn Game Development, Data Visualisation, Web Development and much more? If you’re looking to learn Python for the very first time, this is the course for you! A beginner-friendly Python Programming Foundation -Self Paced Course designed to help start learning Python language from scratch. Learn Python basics, Variables & Data types, Input & Output, Operators, and more. So what are you waiting for? Kickstart your programming journey and dive into the world of Python by enrolling in this course today!DS Using Python Programming – Self Paced CourseIt’s time to level up your Python skills with our most complete DS Using Python Programming – Self Paced Course on the internet, This course will help you better understand every detail of Data Structures and how algorithms are implemented in a high-level programming language, designed by leading industry experts who will teach you, in-depth, effective and efficient ways to implement data structures like Heaps, Stacks, Linked List and many other such concepts. So, what are you waiting for? Advance your Python skills today and become a better programmer.
# It’s time to level up your Python skills with our most complete DS Using Python Programming – Self Paced Course on the internet, This course will help you better understand every detail of Data Structures and how algorithms are implemented in a high-level programming language, designed by leading industry experts who will teach you, in-depth, effective and efficient ways to implement data structures like Heaps, Stacks, Linked List and many other such concepts. So, what are you waiting for? Advance your Python skills today and become a better programmer.

# %%
import requests
from bs4 import BeautifulSoup as bs
import csv
 
URL = 'https://www.chick-fil-a.com/locations/browse/al'
 
soup = bs(req.text, 'html.parser')
 
titles = soup.find_all('div', attrs={'class', 'head'})
titles_list = []
 
count = 1
for title in titles:
    d = {}
    d['Title Number'] = f'Title {count}'
    d['Title Name'] = title.text
    count += 1
    titles_list.append(d)
 
filename = 'titles.csv'
with open(filename, 'w', newline='') as f:
    w = csv.DictWriter(f,['Title Number','Title Name'])
    w.writeheader()
     
    w.writerows(titles_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24208/3392034037.py in <module>
#       5 URL = 'https://www.chick-fil-a.com/locations/browse/al'
#       6
# ----> 7 soup = bs(req.text, 'html.parser')
#       8
#       9 titles = soup.find_all('div', attrs={'class', 'head'})
#
# NameError: name 'req' is not defined

# %%
import requests
from bs4 import BeautifulSoup as bs
from selenium import webdriver
import pandas as pd


URL = [
    'https://www.chick-fil-a.com/locations/browse/al',
    'https://www.chick-fil-a.com/locations/browse/az',
    'https://www.chick-fil-a.com/locations/browse/ar',
    'https://www.chick-fil-a.com/locations/browse/ca',
    'https://www.chick-fil-a.com/locations/browse/co',
    'https://www.chick-fil-a.com/locations/browse/ct',
    'https://www.chick-fil-a.com/locations/browse/de',
    'https://www.chick-fil-a.com/locations/browse/fl',
    'https://www.chick-fil-a.com/locations/browse/ga',
    'https://www.chick-fil-a.com/locations/browse/id',
    'https://www.chick-fil-a.com/locations/browse/il',
    'https://www.chick-fil-a.com/locations/browse/in',
    'https://www.chick-fil-a.com/locations/browse/ia',
    'https://www.chick-fil-a.com/locations/browse/ks',
    'https://www.chick-fil-a.com/locations/browse/ky',
    'https://www.chick-fil-a.com/locations/browse/la',
    'https://www.chick-fil-a.com/locations/browse/me',
    'https://www.chick-fil-a.com/locations/browse/md',
    'https://www.chick-fil-a.com/locations/browse/ma',
    'https://www.chick-fil-a.com/locations/browse/mi',
    'https://www.chick-fil-a.com/locations/browse/mn',
    'https://www.chick-fil-a.com/locations/browse/ms',
    'https://www.chick-fil-a.com/locations/browse/mo',
    'https://www.chick-fil-a.com/locations/browse/mt',
    'https://www.chick-fil-a.com/locations/browse/ne',
    'https://www.chick-fil-a.com/locations/browse/nv',
    'https://www.chick-fil-a.com/locations/browse/nh',
    'https://www.chick-fil-a.com/locations/browse/nj',
    'https://www.chick-fil-a.com/locations/browse/nm',
    'https://www.chick-fil-a.com/locations/browse/ny',
    'https://www.chick-fil-a.com/locations/browse/nc',
    'https://www.chick-fil-a.com/locations/browse/nd',
    'https://www.chick-fil-a.com/locations/browse/oh',
    'https://www.chick-fil-a.com/locations/browse/ok',
    'https://www.chick-fil-a.com/locations/browse/or',
    'https://www.chick-fil-a.com/locations/browse/pa',
    'https://www.chick-fil-a.com/locations/browse/ri',
    'https://www.chick-fil-a.com/locations/browse/sc',
    'https://www.chick-fil-a.com/locations/browse/sd',
    'https://www.chick-fil-a.com/locations/browse/tn',
    'https://www.chick-fil-a.com/locations/browse/tx',
    'https://www.chick-fil-a.com/locations/browse/ut',
    'https://www.chick-fil-a.com/locations/browse/va',
    'https://www.chick-fil-a.com/locations/browse/dc',
    'https://www.chick-fil-a.com/locations/browse/wa',
    'https://www.chick-fil-a.com/locations/browse/wv',
    'https://www.chick-fil-a.com/locations/browse/wi',
    'https://www.chick-fil-a.com/locations/browse/wy',  
    
]

req = requests.get(URL[0])
content = req.text

soup = bs(content, 'lxml')

locations = soup.findAll('div', attrs = {'class': 'location'})

data = []
for para in locations:
    data += para.find('p').text

data.remove('\t')
data.remove('\n')
data.remove('\r')
data.remove(' ')

data = ''.join(map(str,data))

print(data)


"""for i in data[:]:
    if data[i] == '\r' or data[i] == '\t' or data[i] == '\n':
        del data[i]
    else:
         data.append(data[i])"""

"""df  = pd.DataFrame(data, columns="address")

df.drop(df[df[0] == '\t'].index, inplace=True)
df.drop(df[df[0] == '\r'].index, inplace=True)
df.drop(df[df[0] == '\n'].index, inplace=True)
#df.drop(df[df[0] == ' '].index, inplace=True)

for index in range(df.shape[0]):
    print(index)


df.head(20)"""
# Out:
# 														2000Highland Ave S
# 															Birmingham, AL 35205
#
# (205) 930-8000
# 															4707 Airport Blvd
# 															Mobile, AL 36608
#
# (251) 461-9933
# 															4900 Meridian St NW
# 															Huntsville, AL 35762
#
# 															600 18th St N
# 															Birmingham, AL 35203
#
# (205) 257-1688
# 															1055 Tullibody Dr
#
# John Garrick Hardy Student Center															Montgomery, AL 36104
#
# (334) 497-0292
# 															125 Colonial Promenade Pkwy
# 															Alabaster, AL 35007
#
# (205) 685-1190
# 															3899 Hwy 280
# 															Alexander City, AL 35010
#
# (938) 867-4825
# 															915 Ann St
# 															Montgomery, AL 36107
#
# (334) 262-2017
# 															1291 US Highway 72 E
# 															Athens, AL 35611
#
# (256) 233-8900
# 															326 W Magnolia Ave
# 															Auburn, AL 36832
#
# (334) 826-7630
# 															1627 Opelika Rd Ste 54
# 															Auburn, AL 36830
#
# (334) 887-5429
# 															255 Heisman Dr
#
# Stdent Center															Auburn, AL 36849
#
# (334) 844-1284
# 															250 Beard-Eves Ct
#
# Aurburn Arena															Auburn, AL 36849
#
# (334) 844-8815
# 															230 Beard-Eaves Ct
#
# The Village View Dining Facility															Auburn, AL 36849
#
# (334) 844-1284
# 															3215C Bel Air Mall
# 															Mobile, AL 36606
#
# (251) 476-8361
# 															5900 Messer Airport Hwy
#
# Suite #0034															Birmingham, AL 35212
#
# (205) 592-4362
# 															3949 Crosshaven Dr
# 															Vestavia, AL 35243
#
# (205) 871-1398
# 															64 Highway 304
# 															Calera, AL 35040
#
# (205) 668-7483
# 															1830 Cherokee Ave SW
# 															Cullman, AL 35055
#
# (256) 735-1650
# 															1682 US Highway 98
# 															Daphne, AL 36526
#
# (251) 621-3215
# 															3244 Dauphin St
# 															Mobile, AL 36606
#
# (251) 476-0320
# 															1905 E Main St
# 															Dothan, AL 36301
#
# (334) 792-2498
# 															6921 Eastchase Loop
# 															Montgomery, AL 36117
#
# (334) 271-1095
# 															1648 Montclair Rd
# 															Irondale, AL 35210
#
# (205) 957-2229
# 															626 Boll Weevil Cir
# 															Enterprise, AL 36330
#
# (334) 347-4747
# 															900 S Eufaula Ave
# 															Eufaula, AL 36027
#
# (334) 687-8999
# 															341 Cox Creek Pkwy
# 															Florence, AL 35630
#
# (256) 764-0535
# 															3013 S McKenzie St
# 															Foley, AL 36535
#
# (251) 971-6505
# 															1824 Glenn Blvd SW
# 															Fort Payne, AL 35968
#
# (256) 844-8384
# 															215 Howell St
# 															Fultondale, AL 35068
#
# (205) 841-1777
# 															1008 S 4th St
# 															Gadsden, AL 35901
#
# (256) 543-7770
# 															1001 Rainbow Dr Ste 61
# 															Gadsden, AL 35901
#
# (256) 547-4447
# 															385 Fieldstown Rd
# 															Gardendale, AL 35071
#
# (205) 608-3488
# 															402 Governors Dr SW
# 															Huntsville, AL 35801
#
# (256) 536-5150
# 															5375 Highway 280
# 															Birmingham, AL 35242
#
# (205) 995-8333
# 															11488 US Highway 431
# 															Guntersville, AL 35976
#
# (256) 894-8303
# 															6599 Highway 431 S
# 															Owens Cross Roads, AL 35763
#
# (256) 288-0007
# 															2432 Helena Rd
# 															Helena, AL 35080
#
# (205) 922-1153
# 															1609 Montgomery Hwy
# 															Hoover, AL 35216
#
# (205) 979-9990
# 															4620 US 280 South
# 															Birmingham, AL 35242
#
# (205) 995-9925
# 															500 Pelham Rd S
# 															Jacksonville, AL 36265
#
# (256) 782-0900
# 															700 Pelham Rd N
# 															Jacksonville, AL 36265
#
# (256) 782-5554
# 															1812 Highway 78 E
# 															Jasper, AL 35501
#
# (205) 221-0308
# 															1808 Ashville Rd
# 															Leeds, AL 35094
#
# (205) 699-1118
# 															8300 Highway 72 W
# 															Madison, AL 35758
#
# (256) 837-7020
# 															6000 Harris Ln
# 															Bessemer, AL 35022
#
# (205) 426-3190
# 															1913 5th Ave N
# 															Birmingham, AL 35203
#
# (205) 324-6161
# 															2682 Eastern Blvd
# 															Montgomery, AL 36117
#
# (334) 271-0104
# 															511 Avalon Ave
# 															Muscle Shoals, AL 35661
#
# (256) 386-5442
# 															1620 McFarland Blvd
# 															Northport, AL 35476
#
# (205) 330-1110
# 															320 Cahaba Valley Rd
# 															Pelham, AL 35124
#
# (205) 403-3223
# 															201 Oxford Exchange Blvd
# 															Oxford, AL 36203
#
# (256) 835-6009
# 															700 Quintard Dr Ste FC8
# 															Oxford, AL 36203
#
# (256) 835-1887
# 															9345 Parkway E
# 															Birmingham, AL 35215
#
# (205) 836-0003
# 															2801 Memorial Pkwy SW Ste 70
# 															Huntsville, AL 35801
#
# (256) 533-9206
# 															3020 John Hawkins Pkwy
# 															Hoover, AL 35244
#
# (205) 987-7568
# 															1653 Martin St N
# 															Pell City, AL 35125
#
# (205) 525-0539
# 															3711 U S Hwy 280
# 															Phenix City, AL 36867
#
# (334) 214-5599
# 															1967 Cobbs Ford Rd
# 															Prattville, AL 36066
#
# (334) 365-8222
# 															2000 Riverchase Galleria Ste 158B
# 															Hoover, AL 35244
#
# (205) 987-2244
# 															3418 Ross Clark Cir
# 															Dothan, AL 36303
#
# (334) 712-4849
# 															12 N Royal St
# 															Mobile, AL 36602
#
# (251) 434-9768
# 															201 Monroe St
#
# Suite 162															Montgomery, AL 36104
#
# (334) 293-4773
# 															800 Lakeshore Dr
# 															Birmingham, AL 35229
#
# (205) 726-2637
# 															435 Schillinger Rd S
# 															Mobile, AL 36695
#
# (251) 639-1163
# 															11820 Memorial Pkwy SW
# 															Huntsville, AL 35803
#
# (256) 650-7014
# 															2502 Highway 31 S
# 															Decatur, AL 35603
#
# (256) 822-1014
# 															1809 Beltline Rd SW
# 															Decatur, AL 35601
#
# (256) 355-3035
# 															30500 SR 181 Suite B
# 															Spanish Fort, AL 36527
#
# (251) 621-3020
# 															75 MCS Blvd
# 															Sylacauga, AL 35150
#
# (256) 245-0096
# 															5658 Grove Blvd
# 															Hoover, AL 35226
#
# (205) 989-1701
# 															2052 Tiger Town Pkwy
# 															Opelika, AL 36801
#
# (334) 741-7112
# 															1121 Highway 231 S
# 															Troy, AL 36081
#
# (334) 566-0505
# 															214 Adams Ctr
# 															Troy, AL 36082
#
# (334) 670-5858
# 															5886 Trussville Crossings Pkwy
# 															Birmingham, AL 35235
#
# (205) 661-0544
# 															2014 McFarland Blvd E
# 															Tuscaloosa, AL 35404
#
# (205) 752-9999
# 															4900 Old Greensboro Rd
# 															Tuscaloosa, AL 35405
#
# (205) 247-9980
# 															1200 W Montgomery Rd
# 															Tuskegee Institute, AL 36088
#
# 															4733 University Dr NW
# 															Huntsville, AL 35816
#
# (256) 837-1315
# 															1701 McFarland Blvd E Ste 190
# 															Tuscaloosa, AL 35404
#
# (205) 553-9195
# 															Bama Dining Services
#
# Ferguson Center															Tuscaloosa, AL 35487
#
# (205) 348-6816
# 															507 John Wright Dr
# 															Huntsville, AL 35805
#
# (256) 824-5124
# 															1000 14th Ave S
# 															Birmingham, AL 35205
#
# 															625 19th St S
#
# Jefferson Tower															Birmingham, AL 35233
#
# (205) 502-7005
# 															503 6th Ave
#
# Lloyd Hall															Tuscaloosa, AL 35404
#
# (205) 348-6429
# 															1 Harrison Plz
#
# Student Commons Building															Florence, AL 35632
#
# (256) 765-5667
# 															350 Campus Dr
#
# Student Center															Mobile, AL 36608
#
# (251) 460-6296
# 															513 Montgomery Hwy
# 															Vestavia Hills, AL 35216
#
# (205) 824-3540
# 															4751 Whitesburg Dr SE
# 															Huntsville, AL 35802
#
# (256) 880-4080
# 															211 Lakeshore Pkwy
# 															Homewood, AL 35209
#
# (205) 945-6062
# 'df  = pd.DataFrame(data, columns="address")\n\ndf.drop(df[df[0] == \'\t\'].index, inplace=True)\ndf.drop(df[df[0] == \'\r\'].index, inplace=True)\ndf.drop(df[df[0] == \'\n\'].index, inplace=True)\n#df.drop(df[df[0] == \' \'].index, inplace=True)\n\nfor index in range(df.shape[0]):\n    print(index)\n\n\ndf.head(20)'

# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import numpy as np
import re

URL = [
    'https://www.chick-fil-a.com/locations/browse/al',
    'https://www.chick-fil-a.com/locations/browse/az',
    'https://www.chick-fil-a.com/locations/browse/ar',
    'https://www.chick-fil-a.com/locations/browse/ca',
    'https://www.chick-fil-a.com/locations/browse/co',
    'https://www.chick-fil-a.com/locations/browse/ct',
    'https://www.chick-fil-a.com/locations/browse/de',
    'https://www.chick-fil-a.com/locations/browse/fl',
    'https://www.chick-fil-a.com/locations/browse/ga',
    'https://www.chick-fil-a.com/locations/browse/id',
    'https://www.chick-fil-a.com/locations/browse/il',
    'https://www.chick-fil-a.com/locations/browse/in',
    'https://www.chick-fil-a.com/locations/browse/ia',
    'https://www.chick-fil-a.com/locations/browse/ks',
    'https://www.chick-fil-a.com/locations/browse/ky',
    'https://www.chick-fil-a.com/locations/browse/la',
    'https://www.chick-fil-a.com/locations/browse/me',
    'https://www.chick-fil-a.com/locations/browse/md',
    'https://www.chick-fil-a.com/locations/browse/ma',
    'https://www.chick-fil-a.com/locations/browse/mi',
    'https://www.chick-fil-a.com/locations/browse/mn',
    'https://www.chick-fil-a.com/locations/browse/ms',
    'https://www.chick-fil-a.com/locations/browse/mo',
    'https://www.chick-fil-a.com/locations/browse/mt',
    'https://www.chick-fil-a.com/locations/browse/ne',
    'https://www.chick-fil-a.com/locations/browse/nv',
    'https://www.chick-fil-a.com/locations/browse/nh',
    'https://www.chick-fil-a.com/locations/browse/nj',
    'https://www.chick-fil-a.com/locations/browse/nm',
    'https://www.chick-fil-a.com/locations/browse/ny',
    'https://www.chick-fil-a.com/locations/browse/nc',
    'https://www.chick-fil-a.com/locations/browse/nd',
    'https://www.chick-fil-a.com/locations/browse/oh',
    'https://www.chick-fil-a.com/locations/browse/ok',
    'https://www.chick-fil-a.com/locations/browse/or',
    'https://www.chick-fil-a.com/locations/browse/pa',
    'https://www.chick-fil-a.com/locations/browse/ri',
    'https://www.chick-fil-a.com/locations/browse/sc',
    'https://www.chick-fil-a.com/locations/browse/sd',
    'https://www.chick-fil-a.com/locations/browse/tn',
    'https://www.chick-fil-a.com/locations/browse/tx',
    'https://www.chick-fil-a.com/locations/browse/ut',
    'https://www.chick-fil-a.com/locations/browse/va',
    'https://www.chick-fil-a.com/locations/browse/dc',
    'https://www.chick-fil-a.com/locations/browse/wa',
    'https://www.chick-fil-a.com/locations/browse/wv',
    'https://www.chick-fil-a.com/locations/browse/wi',
    'https://www.chick-fil-a.com/locations/browse/wy',  
    
]

page = requests.get(URL[0])

soup = bs(page.content, 'html.parser')

results = soup.find(id="LocationFrameId")
#print(results.prettify())

#state = results.find_all("div", class_="state-locations-list")
stores = results.find_all("div", class_="location")
#print(stores)
loc=""
for element in stores:
    loc += element.find('p').text
    loc.strip()
    
#data = re.findall([], loc)
#loc = loc.split()
#print(loc)
#data





def find_phone_num(text):
    regex = '.[0-9]{3}..[0-9]{3}.[0-9]{4}'
    data = re.findall(regex, str(text))
    return data

phones = find_phone_num(loc)


def find_st_address(text):
    # street address
    regex = '[0-9]+.[0-9a-zA-Z]+.[0-9a-zA-Z]+.[0-9a-zA-Z]+.[0-9a-zA-Z]+\s+[a-zA-Z]+.[a-zA-Z]+..[A-Z]{2}.[0-9]{5}'
    data = re.findall(regex, str(text))
    d = re.sub(r'\s+', ' ', str(data))
    return d

street = find_st_address(loc)


def find_city_zip(text):
    # fidning city and zip code
    regex = '[a-zA-Z]+.[a-zA-Z]+..[A-Z]{2}.[0-9]{5}'
    data = re.findall(regex, str(text))
    return data

city = find_city_zip(loc)

#print(len(phones))
#print(len(street))
#print(len(city))
print(street)

#loc = print(re.split(r"\s+", loc))
# Out:
# ['2000 Highland Ave S\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tBirmingham, AL 35205', '4707 Airport Blvd\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tMobile, AL 36608', '4900 Meridian St NW\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tHuntsville, AL 35762', '600 18th St N\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tBirmingham, AL 35203', '125 Colonial Promenade Pkwy\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tAlabaster, AL 35007', '3899 Hwy 280\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tAlexander City, AL 35010', '915 Ann St\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tMontgomery, AL 36107', '1291 US Highway 72 E\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tAthens, AL 35611', '326 W Magnolia Ave\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tAuburn, AL 36832', '1627 Opelika Rd Ste 54\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tAuburn, AL 36830', '3215C Bel Air Mall\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tMobile, AL 36606', '3949 Crosshaven Dr\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tVestavia, AL 35243', '64 Highway 304\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tCalera, AL 35040', '1830 Cherokee Ave SW\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tCullman, AL 35055', '1682 US Highway 98\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tDaphne, AL 36526', '3244 Dauphin St\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tMobile, AL 36606', '1905 E Main St\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tDothan, AL 36301', '6921 Eastchase Loop\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tMontgomery, AL 36117', '1648 Montclair Rd\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tIrondale, AL 35210', '626 Boll Weevil Cir\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tEnterprise, AL 36330', '900 S Eufaula Ave\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tEufaula, AL 36027', '341 Cox Creek Pkwy\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tFlorence, AL 35630', '3013 S McKenzie St\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tFoley, AL 36535', '1824 Glenn Blvd SW\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tFort Payne, AL 35968', '215 Howell St\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tFultondale, AL 35068', '1008 S 4th St\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tGadsden, AL 35901', '1001 Rainbow Dr Ste 61\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tGadsden, AL 35901', '385 Fieldstown Rd\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tGardendale, AL 35071', '402 Governors Dr SW\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tHuntsville, AL 35801', '5375 Highway 280\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tBirmingham, AL 35242', '11488 US Highway 431\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tGuntersville, AL 35976', '2432 Helena Rd\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tHelena, AL 35080', '1609 Montgomery Hwy\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tHoover, AL 35216', '4620 US 280 South\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tBirmingham, AL 35242', '500 Pelham Rd S\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tJacksonville, AL 36265', '700 Pelham Rd N\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tJacksonville, AL 36265', '1812 Highway 78 E\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tJasper, AL 35501', '1808 Ashville Rd\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tLeeds, AL 35094', '8300 Highway 72 W\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tMadison, AL 35758', '6000 Harris Ln\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tBessemer, AL 35022', '1913 5th Ave N\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tBirmingham, AL 35203', '2682 Eastern Blvd\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tMontgomery, AL 36117', '511 Avalon Ave\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tMuscle Shoals, AL 35661', '1620 McFarland Blvd\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tNorthport, AL 35476', '320 Cahaba Valley Rd\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tPelham, AL 35124', '201 Oxford Exchange Blvd\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tOxford, AL 36203', '700 Quintard Dr Ste FC8\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tOxford, AL 36203', '9345 Parkway E\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tBirmingham, AL 35215', '3020 John Hawkins Pkwy\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tHoover, AL 35244', '1653 Martin St N\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tPell City, AL 35125', '3711 U S Hwy 280\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tPhenix City, AL 36867', '1967 Cobbs Ford Rd\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tPrattville, AL 36066', '2000 Riverchase Galleria Ste 158B\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tHoover, AL 35244', '3418 Ross Clark Cir\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tDothan, AL 36303', '12 N Ro ...
